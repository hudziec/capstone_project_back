# %% [markdown]
# **Description of the Ames Iowa Housing Data columns:**

# %% [markdown]
# SOURCE: https://rdrr.io/cran/AmesHousing/man/ames_raw.html
#
# Order: Observation number
#
# PID: Parcel identification number - can be used with city web site for parcel review.
#
# MS SubClass: Identifies the type of dwelling involved in the sale.
#
# MS Zoning: Identifies the general zoning classification of the sale.
#
# Lot Frontage: Linear feet of street connected to property
#
# Lot Area: Lot size in square feet
#
# Street: Type of road access to property
#
# Alley: Type of alley access to property
#
# Lot Shape: General shape of property
#
# Land Contour: Flatness of the property
#
# Utilities: Type of utilities available
#
# Lot Config: Lot configuration
#
# Land Slope: Slope of property
#
# Neighborhood: Physical locations within Ames city limits (map available)
#
# Condition 1: Proximity to various conditions
#
# Condition 2: Proximity to various conditions (if more than one is present)
#
# Bldg Type: Type of dwelling
#
# House Style: Style of dwelling
#
# Overall Qual: Rates the overall material and finish of the house
#
# Overall Cond: Rates the overall condition of the house
#
# Year Built: Original construction date
#
# Year Remod/Add: Remodel date (same as construction date if no remodeling or additions)
#
# Roof Style: Type of roof
#
# Roof Matl: Roof material
#
# Exterior 1: Exterior covering on house
#
# Exterior 2: Exterior covering on house (if more than one material)
#
# Mas Vnr Type: Masonry veneer type
#
# Mas Vnr Area: Masonry veneer area in square feet
#
# Exter Qual: Evaluates the quality of the material on the exterior
#
# Exter Cond: Evaluates the present condition of the material on the exterior
#
# Foundation: Type of foundation
#
# Bsmt Qual: Evaluates the height of the basement
#
# Bsmt Cond: Evaluates the general condition of the basement
#
# Bsmt Exposure: Refers to walkout or garden level walls
#
# BsmtFin Type 1: Rating of basement finished area
#
# BsmtFin SF 1: Type 1 finished square feet
#
# BsmtFinType 2: Rating of basement finished area (if multiple types)
#
# BsmtFin SF 2: Type 2 finished square feet
#
# Bsmt Unf SF: Unfinished square feet of basement area
#
# Total Bsmt SF: Total square feet of basement area
#
# Heating: Type of heating
#
# HeatingQC: Heating quality and condition
#
# Central Air: Central air conditioning
#
# Electrical: Electrical system
#
# 1st Flr SF: First Floor square feet
#
# 2nd Flr SF: Second floor square feet
#
# Low Qual Fin SF: Low quality finished square feet (all floors)
#
# Gr Liv Area: Above grade (ground) living area square feet
#
# Bsmt Full Bath: Basement full bathrooms
#
# Bsmt Half Bath: Basement half bathrooms
#
# Full Bath: Full bathrooms above grade
#
# Half Bath: Half baths above grade
#
# Bedroom: Bedrooms above grade (does NOT include basement bedrooms)
#
# Kitchen: Kitchens above grade
#
# KitchenQual: Kitchen quality
#
# TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
#
# Functional: Home functionality (Assume typical unless deductions are warranted)
#
# Fireplaces: Number of fireplaces
#
# FireplaceQu: Fireplace quality
#
# Garage Type: Garage location
#
# Garage Yr Blt: Year garage was built
#
# Garage Finish: Interior finish of the garage
#
# Garage Cars: Size of garage in car capacity
#
# Garage Area: Size of garage in square feet
#
# Garage Qual: Garage quality
#
# Garage Cond: Garage condition
#
# Paved Drive: Paved driveway
#
# Wood Deck SF: Wood deck area in square feet
#
# Open Porch SF: Open porch area in square feet
#
# Enclosed Porch: Enclosed porch area in square feet
#
# 3-Ssn Porch: Three season porch area in square feet
#
# Screen Porch: Screen porch area in square feet
#
# Pool Area: Pool area in square feet
#
# Pool QC: Pool quality
#
# Fence: Fence quality
#
# Misc Feature: Miscellaneous feature not covered in other categories
#
# Misc Val: $Value of miscellaneous feature
#
# Mo Sold: Month Sold
#
# Yr Sold: Year Sold
#
# Sale Type: Type of sale
#
# Sale Condition: Condition of sale

# %% [markdown]
# **Load packages:**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
#  **Load the data:**

# %%
ames_file_test = '../data/test.csv'

# %%
df = pd.read_csv(ames_file_test)

# %% [markdown]
# **Change Index type and start at #1:**

# %%
df.index = df.index.astype(int, copy = False)

# %%
df.index = df.index + 1

# %%
df.head(5)
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 1  2658  902301120          190        RM          69.0      9142   Pave
# 2  2718  905108090           90        RL           NaN      9662   Pave
# 3  2414  528218130           60        RL          58.0     17104   Pave
# 4  1989  902207150           30        RM          60.0      8520   Pave
# 5   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour  ... 3Ssn Porch Screen Porch Pool Area Pool QC  \
# 1  Grvl       Reg          Lvl  ...          0            0         0     NaN
# 2   NaN       IR1          Lvl  ...          0            0         0     NaN
# 3   NaN       IR1          Lvl  ...          0            0         0     NaN
# 4   NaN       Reg          Lvl  ...          0            0         0     NaN
# 5   NaN       IR1          Lvl  ...          0          185         0     NaN
#
#   Fence Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type
# 1   NaN          NaN        0       4     2006        WD
# 2   NaN          NaN        0       8     2006        WD
# 3   NaN          NaN        0       9     2006        New
# 4   NaN          NaN        0       7     2007        WD
# 5   NaN          NaN        0       7     2009        WD
#
# [5 rows x 80 columns]

# %% [markdown]
# **Describe the basic format:**

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
df.dtypes
# Out:
# Id                   int64
# PID                  int64
# MS SubClass          int64
# MS Zoning           object
# Lot Frontage       float64
# Lot Area             int64
# Street              object
# Alley               object
# Lot Shape           object
# Land Contour        object
# Utilities           object
# Lot Config          object
# Land Slope          object
# Neighborhood        object
# Condition 1         object
# Condition 2         object
# Bldg Type           object
# House Style         object
# Overall Qual         int64
# Overall Cond         int64
# Year Built           int64
# Year Remod/Add       int64
# Roof Style          object
# Roof Matl           object
# Exterior 1st        object
# Exterior 2nd        object
# Mas Vnr Type        object
# Mas Vnr Area       float64
# Exter Qual          object
# Exter Cond          object
# Foundation          object
# Bsmt Qual           object
# Bsmt Cond           object
# Bsmt Exposure       object
# BsmtFin Type 1      object
# BsmtFin SF 1         int64
# BsmtFin Type 2      object
# BsmtFin SF 2         int64
# Bsmt Unf SF          int64
# Total Bsmt SF        int64
# Heating             object
# Heating QC          object
# Central Air         object
# Electrical          object
# 1st Flr SF           int64
# 2nd Flr SF           int64
# Low Qual Fin SF      int64
# Gr Liv Area          int64
# Bsmt Full Bath       int64
# Bsmt Half Bath       int64
# Full Bath            int64
# Half Bath            int64
# Bedroom AbvGr        int64
# Kitchen AbvGr        int64
# Kitchen Qual        object
# TotRms AbvGrd        int64
# Functional          object
# Fireplaces           int64
# Fireplace Qu        object
# Garage Type         object
# Garage Yr Blt      float64
# Garage Finish       object
# Garage Cars          int64
# Garage Area          int64
# Garage Qual         object
# Garage Cond         object
# Paved Drive         object
# Wood Deck SF         int64
# Open Porch SF        int64
# Enclosed Porch       int64
# 3Ssn Porch           int64
# Screen Porch         int64
# Pool Area            int64
# Pool QC             object
# Fence               object
# Misc Feature        object
# Misc Val             int64
# Mo Sold              int64
# Yr Sold              int64
# Sale Type           object
# dtype: object

# %%
df.shape
# Out:
# (879, 80)

# %% [markdown]
# **Drop unwanted columns:**

# %% [markdown]
# * Preliminary look through data, more columns to be dropped in Analyze & Evaluate section.

# %%
df.drop(columns=['PID', 'Id'], inplace=True)

# %% [markdown]
# - 'PID' & 'Id' column are for identification purposes only. Not relevant to predicting housing costs.

# %%
df.head(5)
# Out:
#    MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 1          190        RM          69.0      9142   Pave  Grvl       Reg
# 2           90        RL           NaN      9662   Pave   NaN       IR1
# 3           60        RL          58.0     17104   Pave   NaN       IR1
# 4           30        RM          60.0      8520   Pave   NaN       Reg
# 5           20        RL           NaN      9500   Pave   NaN       IR1
#
#   Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
# 1          Lvl    AllPub     Inside        Gtl      OldTown        Norm
# 2          Lvl    AllPub     Inside        Gtl       Sawyer        Norm
# 3          Lvl    AllPub     Inside        Gtl      Gilbert        Norm
# 4          Lvl    AllPub     Inside        Gtl      OldTown        Norm
# 5          Lvl    AllPub     Inside        Gtl        NAmes        Norm
#
#   Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  Year Built  \
# 1        Norm    2fmCon      2Story             6             8        1910
# 2        Norm    Duplex      1Story             5             4        1977
# 3        Norm      1Fam      2Story             7             5        2006
# 4        Norm      1Fam      1Story             5             6        1923
# 5        Norm      1Fam      1Story             6             5        1963
#
#    Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd Mas Vnr Type  \
# 1            1950      Gable   CompShg      AsbShng      AsbShng         None
# 2            1977      Gable   CompShg      Plywood      Plywood         None
# 3            2006      Gable   CompShg      VinylSd      VinylSd         None
# 4            2006      Gable   CompShg      Wd Sdng      Wd Sdng         None
# 5            1963      Gable   CompShg      Plywood      Plywood      BrkFace
#
#    Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual Bsmt Cond  \
# 1           0.0         TA         Fa      Stone        Fa        TA
# 2           0.0         TA         TA     CBlock        Gd        TA
# 3           0.0         Gd         TA      PConc        Gd        Gd
# 4           0.0         Gd         TA     CBlock        TA        TA
# 5         247.0         TA         TA     CBlock        Gd        TA
#
#   Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  \
# 1            No            Unf             0            Unf             0
# 2            No            Unf             0            Unf             0
# 3            Av            GLQ           554            Unf             0
# 4            No            Unf             0            Unf             0
# 5            No            BLQ           609            Unf             0
#
#    Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air Electrical  \
# 1         1020           1020    GasA         Gd           N      FuseP
# 2         1967           1967    GasA         TA           Y      SBrkr
# 3          100            654    GasA         Ex           Y      SBrkr
# 4          968            968    GasA         TA           Y      SBrkr
# 5          785           1394    GasA         Gd           Y      SBrkr
#
#    1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  \
# 1         908        1020                0         1928               0
# 2        1967           0                0         1967               0
# 3         664         832                0         1496               1
# 4         968           0                0          968               0
# 5        1394           0                0         1394               1
#
#    Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  Kitchen AbvGr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#   Kitchen Qual  TotRms AbvGrd Functional  Fireplaces Fireplace Qu Garage Type  \
# 1           Fa              9        Typ           0          NaN      Detchd
# 2           TA             10        Typ           0          NaN      Attchd
# 3           Gd              7        Typ           1           Gd      Attchd
# 4           TA              5        Typ           0          NaN      Detchd
# 5           TA              6        Typ           2           Gd      Attchd
#
#    Garage Yr Blt Garage Finish  Garage Cars  Garage Area Garage Qual  \
# 1         1910.0           Unf            1          440          Po
# 2         1977.0           Fin            2          580          TA
# 3         2006.0           RFn            2          426          TA
# 4         1935.0           Unf            2          480          Fa
# 5         1963.0           RFn            2          514          TA
#
#   Garage Cond Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  \
# 1          Po           Y             0             60             112
# 2          TA           Y           170              0               0
# 3          TA           Y           100             24               0
# 4          TA           N             0              0             184
# 5          TA           Y             0             76               0
#
#    3Ssn Porch  Screen Porch  Pool Area Pool QC Fence Misc Feature  Misc Val  \
# 1           0             0          0     NaN   NaN          NaN         0
# 2           0             0          0     NaN   NaN          NaN         0
# 3           0             0          0     NaN   NaN          NaN         0
# 4           0             0          0     NaN   NaN          NaN         0
# 5           0           185          0     NaN   NaN          NaN         0
#
#    Mo Sold  Yr Sold Sale Type
# 1        4     2006       WD
# 2        8     2006       WD
# 3        9     2006       New
# 4        7     2007       WD
# 5        7     2009       WD

# %% [markdown]
# **Determine missing observations:**

# %%
df.isnull().sum()
# Out:
# MS SubClass          0
# MS Zoning            0
# Lot Frontage       160
# Lot Area             0
# Street               0
# Alley              821
# Lot Shape            0
# Land Contour         0
# Utilities            0
# Lot Config           0
# Land Slope           0
# Neighborhood         0
# Condition 1          0
# Condition 2          0
# Bldg Type            0
# House Style          0
# Overall Qual         0
# Overall Cond         0
# Year Built           0
# Year Remod/Add       0
# Roof Style           0
# Roof Matl            0
# Exterior 1st         0
# Exterior 2nd         0
# Mas Vnr Type         1
# Mas Vnr Area         1
# Exter Qual           0
# Exter Cond           0
# Foundation           0
# Bsmt Qual           25
# Bsmt Cond           25
# Bsmt Exposure       25
# BsmtFin Type 1      25
# BsmtFin SF 1         0
# BsmtFin Type 2      25
# BsmtFin SF 2         0
# Bsmt Unf SF          0
# Total Bsmt SF        0
# Heating              0
# Heating QC           0
# Central Air          0
# Electrical           1
# 1st Flr SF           0
# 2nd Flr SF           0
# Low Qual Fin SF      0
# Gr Liv Area          0
# Bsmt Full Bath       0
# Bsmt Half Bath       0
# Full Bath            0
# Half Bath            0
# Bedroom AbvGr        0
# Kitchen AbvGr        0
# Kitchen Qual         0
# TotRms AbvGrd        0
# Functional           0
# Fireplaces           0
# Fireplace Qu       422
# Garage Type         44
# Garage Yr Blt       45
# Garage Finish       45
# Garage Cars          0
# Garage Area          0
# Garage Qual         45
# Garage Cond         45
# Paved Drive          0
# Wood Deck SF         0
# Open Porch SF        0
# Enclosed Porch       0
# 3Ssn Porch           0
# Screen Porch         0
# Pool Area            0
# Pool QC            875
# Fence              707
# Misc Feature       838
# Misc Val             0
# Mo Sold              0
# Yr Sold              0
# Sale Type            0
# dtype: int64

# %% [markdown]
# **Make the column names searchable**

# %%
df.columns = df.columns.str.lower()

# %%
df.columns = df.columns.str.replace(' ','_')

# %%
df.columns = df.columns.str.replace('/','_')

# %%
df.columns = df.columns.str.replace('3','three')

# %%
df.columns = df.columns.str.replace('1st','first')

# %%
df.columns = df.columns.str.replace('2nd','second')

# %%
df.dtypes
# Out:
# ms_subclass          int64
# ms_zoning           object
# lot_frontage       float64
# lot_area             int64
# street              object
# alley               object
# lot_shape           object
# land_contour        object
# utilities           object
# lot_config          object
# land_slope          object
# neighborhood        object
# condition_1         object
# condition_2         object
# bldg_type           object
# house_style         object
# overall_qual         int64
# overall_cond         int64
# year_built           int64
# year_remod_add       int64
# roof_style          object
# roof_matl           object
# exterior_first      object
# exterior_second     object
# mas_vnr_type        object
# mas_vnr_area       float64
# exter_qual          object
# exter_cond          object
# foundation          object
# bsmt_qual           object
# bsmt_cond           object
# bsmt_exposure       object
# bsmtfin_type_1      object
# bsmtfin_sf_1         int64
# bsmtfin_type_2      object
# bsmtfin_sf_2         int64
# bsmt_unf_sf          int64
# total_bsmt_sf        int64
# heating             object
# heating_qc          object
# central_air         object
# electrical          object
# first_flr_sf         int64
# second_flr_sf        int64
# low_qual_fin_sf      int64
# gr_liv_area          int64
# bsmt_full_bath       int64
# bsmt_half_bath       int64
# full_bath            int64
# half_bath            int64
# bedroom_abvgr        int64
# kitchen_abvgr        int64
# kitchen_qual        object
# totrms_abvgrd        int64
# functional          object
# fireplaces           int64
# fireplace_qu        object
# garage_type         object
# garage_yr_blt      float64
# garage_finish       object
# garage_cars          int64
# garage_area          int64
# garage_qual         object
# garage_cond         object
# paved_drive         object
# wood_deck_sf         int64
# open_porch_sf        int64
# enclosed_porch       int64
# threessn_porch       int64
# screen_porch         int64
# pool_area            int64
# pool_qc             object
# fence               object
# misc_feature        object
# misc_val             int64
# mo_sold              int64
# yr_sold              int64
# sale_type           object
# dtype: object

# %% [markdown]
# **Analyze & Evaluate Columns**

# %% [markdown]
# * I will try and predict housing prices, any data that could by useful in this task will be kept.

# %%
# COLUMN:		ms_subclass
# DEFINITION:	Identifies the type of dwelling involved in the
#               sale.
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.ms_subclass.unique()
# EVALUATION: COLUMN READY TO GO... DATA TYPE GOOD, NO MISSING
# VALUES!
# Out:
# array([190,  90,  60,  30,  20, 160, 120,  70,  80,  50,  85,  45,  75,
#        180,  40])

# %%
# COLUMN:		ms_zoning
# DEFINITION:	Identifies the general zoning classification of
#               the sale.
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df. ms_zoning.unique()
# EVALUATION: COLUMN NEEDS TO BE CONVERTED TO INTERGER, NO
# MISSING VALUES!
# Out:
# array(['RM', 'RL', 'FV', 'RH', 'C (all)', 'I (all)'], dtype=object)

# %%
ms_zoning = {'RL':'0', 'FV':'1', 'RH':'2', 'RM':'3', 'C (all)':'4', 'I (all)':'5', 'A (agr)':'6'}
df.ms_zoning = [ms_zoning[item] for item in df.ms_zoning] 
df.ms_zoning.unique()
# Out:
# array(['3', '0', '1', '2', '4', '5'], dtype=object)

# %%
df["ms_zoning"] = df["ms_zoning"].astype(dtype=np.int)
df['ms_zoning'].dtype
# Out:
# dtype('int64')

# %%
# COLUMN:		lot_frontage
# DEFINITION:	Linear feet of street connected to property
# DATA TYPE:	float64
# MISSING VALUES:	330
# UNIQUE VALUES:	
df.lot_frontage.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE, MISSING
# VALUES, COLUMN TO BE DROPPED!
# Out:
# array([ 69.,  nan,  58.,  60.,  21.,  52.,  39.,  75.,  50.,  68.,  80.,
#        121.,  51.,  65.,  74.,  73.,  40.,  46.,  61.,  85., 136.,  34.,
#         70.,  59., 130., 100.,  77., 131.,  67.,  79.,  98.,  53.,  95.,
#         37., 106.,  90., 120.,  72.,  76., 118.,  24.,  78.,  86., 102.,
#         66., 112.,  63.,  57., 110.,  89., 103., 105.,  48.,  43., 160.,
#         31.,  55.,  84.,  44., 150.,  35.,  64.,  71., 122., 174.,  49.,
#         47.,  93.,  56., 149.,  87., 168.,  82.,  36.,  41.,  96.,  88.,
#         83.,  45.,  94.,  54.,  30., 124.,  81.,  42., 152., 115., 113.,
#        101., 104., 116.,  62., 114., 107.,  33.,  99.,  91.,  97., 126.,
#         28., 108., 133.,  32.,  92., 182.])

# %%
df = df.drop(columns=['lot_frontage'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  lot_area street alley lot_shape land_contour  \
# 1          190          3      9142   Pave  Grvl       Reg          Lvl
# 2           90          0      9662   Pave   NaN       IR1          Lvl
# 3           60          0     17104   Pave   NaN       IR1          Lvl
# 4           30          3      8520   Pave   NaN       Reg          Lvl
# 5           20          0      9500   Pave   NaN       IR1          Lvl
#
#   utilities lot_config land_slope neighborhood condition_1 condition_2  \
# 1    AllPub     Inside        Gtl      OldTown        Norm        Norm
# 2    AllPub     Inside        Gtl       Sawyer        Norm        Norm
# 3    AllPub     Inside        Gtl      Gilbert        Norm        Norm
# 4    AllPub     Inside        Gtl      OldTown        Norm        Norm
# 5    AllPub     Inside        Gtl        NAmes        Norm        Norm
#
#   bldg_type house_style  overall_qual  overall_cond  year_built  \
# 1    2fmCon      2Story             6             8        1910
# 2    Duplex      1Story             5             4        1977
# 3      1Fam      2Story             7             5        2006
# 4      1Fam      1Story             5             6        1923
# 5      1Fam      1Story             6             5        1963
#
#    year_remod_add roof_style roof_matl exterior_first exterior_second  \
# 1            1950      Gable   CompShg        AsbShng         AsbShng
# 2            1977      Gable   CompShg        Plywood         Plywood
# 3            2006      Gable   CompShg        VinylSd         VinylSd
# 4            2006      Gable   CompShg        Wd Sdng         Wd Sdng
# 5            1963      Gable   CompShg        Plywood         Plywood
#
#   mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation bsmt_qual  \
# 1         None           0.0         TA         Fa      Stone        Fa
# 2         None           0.0         TA         TA     CBlock        Gd
# 3         None           0.0         Gd         TA      PConc        Gd
# 4         None           0.0         Gd         TA     CBlock        TA
# 5      BrkFace         247.0         TA         TA     CBlock        Gd
#
#   bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  \
# 1        TA            No            Unf             0            Unf
# 2        TA            No            Unf             0            Unf
# 3        Gd            Av            GLQ           554            Unf
# 4        TA            No            Unf             0            Unf
# 5        TA            No            BLQ           609            Unf
#
#    bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air  \
# 1             0         1020           1020    GasA         Gd           N
# 2             0         1967           1967    GasA         TA           Y
# 3             0          100            654    GasA         Ex           Y
# 4             0          968            968    GasA         TA           Y
# 5             0          785           1394    GasA         Gd           Y
#
#   electrical  first_flr_sf  second_flr_sf  low_qual_fin_sf  gr_liv_area  \
# 1      FuseP           908           1020                0         1928
# 2      SBrkr          1967              0                0         1967
# 3      SBrkr           664            832                0         1496
# 4      SBrkr           968              0                0          968
# 5      SBrkr          1394              0                0         1394
#
#    bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  \
# 1               0               0          2          0              4
# 2               0               0          2          0              6
# 3               1               0          2          1              3
# 4               0               0          1          0              2
# 5               1               0          1          1              3
#
#    kitchen_abvgr kitchen_qual  totrms_abvgrd functional  fireplaces  \
# 1              2           Fa              9        Typ           0
# 2              2           TA             10        Typ           0
# 3              1           Gd              7        Typ           1
# 4              1           TA              5        Typ           0
# 5              1           TA              6        Typ           2
#
#   fireplace_qu garage_type  garage_yr_blt garage_finish  garage_cars  \
# 1          NaN      Detchd         1910.0           Unf            1
# 2          NaN      Attchd         1977.0           Fin            2
# 3           Gd      Attchd         2006.0           RFn            2
# 4          NaN      Detchd         1935.0           Unf            2
# 5           Gd      Attchd         1963.0           RFn            2
#
#    garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 1          440          Po          Po           Y             0
# 2          580          TA          TA           Y           170
# 3          426          TA          TA           Y           100
# 4          480          Fa          TA           N             0
# 5          514          TA          TA           Y             0
#
#    open_porch_sf  enclosed_porch  threessn_porch  screen_porch  pool_area  \
# 1             60             112               0             0          0
# 2              0               0               0             0          0
# 3             24               0               0             0          0
# 4              0             184               0             0          0
# 5             76               0               0           185          0
#
#   pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1     NaN   NaN          NaN         0        4     2006       WD
# 2     NaN   NaN          NaN         0        8     2006       WD
# 3     NaN   NaN          NaN         0        9     2006       New
# 4     NaN   NaN          NaN         0        7     2007       WD
# 5     NaN   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		lot_area
# DEFINITION:	Lot size in square feet
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.lot_area.unique()
# EVALUATION: COLUMN READY TO GO... DATA TYPE GOOD, NO MISSING
# VALUES! DECISION TO DROP DROP DATA.
# Out:
# array([  9142,   9662,  17104,   8520,   9500,   1890,   8516,   9286,
#          3515,  10125,   7175,   7200,  11310,   7976,  11737,   9060,
#         10800,   9571,  17671,   8246,   8499,   8012,  21453,   9605,
#          7180,  12513,   9000,   8800,   3500,   7340,   6240,  11700,
#         10000,  11166,  13204,   5520,   8892,   7321,   3951,  11214,
#          7388,  14559,   4054,   1533,  11250,   7800,   5868,   7500,
#          9439,   9345,   6000,   7930,   9120,   9503,  11050,  10316,
#         11675,  12900,  13770,  13355,   7153,  10750,   8125,   3903,
#          4270,   4426,   5825,  23303,  25485,  10784,   8510,  17871,
#         40094,  21750,   9510,   8339,  14828,   8749,   9140,   3600,
#          8777,  12798,  12704,   7480,  16500,  16669,   8064,   7758,
#         11767,   6900,   4671,   6125,   9863,   4590,   8450,   8400,
#         14694,  14250,   6951,  12720,  11988,   3880,   7685,  18837,
#         11136,  10773,  10200,  11800,  17217,  16196,  35760,   7630,
#          2016,  10816,   9978,  12291,  11065,   8147,  13869,   6204,
#         12151,   9560,   8923,  12606,   8660,   9042,  11227,  11380,
#          2280,  10452,   9910,  13072,   3901,  11625,   9360,   9717,
#         10320,  31220,   8050,   7596,   8094,  10900,  15417,  11645,
#         10512,   5586,   7838,   9022,   7390,   1900,   8760,  13125,
#          9240,   9250,  13693,   6472,  10206,  13695,   3203,   9512,
#          9750,  15623,   8072,  11679,   2544,  10832,   9786,   5400,
#          8235,   1894,   7903,   9839,   9900,  17542,   9073,  10140,
#          8965,   7793,   2394,  10267,   6360,  10237,   7540,   9428,
#         10164,  13825,   7700,  17433,   6300,  10366,   9291,   5775,
#          2179,   6442,  14598,   8637,   5142, 215245,   4109,   8285,
#         20355,   3378,   5160,   3735,   6979,   7056,  11911,   7890,
#         14680,  10208,  19550,   1491,   4800,   8172,  25419,  13031,
#          5633,  14257,  20896,   4230,  15611,  10960,  11999,  11060,
#         13214,  10235,  13008,   7436,   8123,   7820,   5568,   9828,
#          9375,  11457,   6120,  20431,  10560,  19958,  11084,  10266,
#         23257,   7570,   9317,   9020,   3675,  14100,   7038,  16133,
#          4435,  16157,  10463,  12155,  10712,   9143,  29959,  16560,
#          1953,   8700,   8927,   7000,  14175,   9316,   9085,  11202,
#          9650,   7136,   7064, 164660,   6762,  10547,  13052,  15600,
#          4920,  13253,  11631,  11394,  10159,   6264,   8738,   7015,
#          8405,   5000,  12883,   4928,   8712,   3010,   9780,   9462,
#          9482,  14067,  11345,   3760,   7588,  14190,  11664,   4420,
#         33983,  10134,  12144,   8750,  11134,   7379,   9783,   9477,
#         15384,  11327,   5852,   1680,  10182,  11275,   9720,   9017,
#          8500,   9490,  27697,  10632,  11475,  11049,   4750,  35133,
#         12984,   9157,   5820,   9671,  13515,   9233,  15306,   7642,
#          3842,   5063,   4235,  15576,  10120,  13514,  13440,  11500,
#          7609,  26142,   9184,   9416,  10402,   3300,   8334,  11207,
#          7252,  18000,  12134,  14450,   7681,  11146,   7910,   8000,
#          6048,   9548,  10927,   7350,   5925,  12388,   8838,  12203,
#         21286,  11170,  10500,  12671,  13600,  21281,   5870,  13704,
#         12220,   3782,  11248,   8128,   9600,  11388,  14215,   6792,
#          4447,  13560,   9453,  10355,  10464,  25095,  11340,  11787,
#         13700,  10130,   6371,   8470,   6860,  10041,   6400,   1488,
#          8176,   7590,  21535,  11796,  16698,  10400,   8314,   9180,
#         11210,   8803,   8665,  13474,  10950,  10793,   9800,  13006,
#          7875,  12168,   9200,   4438,  13068,   4217,   6600,   8990,
#          7755,  10382,  11924,   3072,  11075,  10682,  12589,  16219,
#          7892,  13377,  10570,   8854,   2665,  18600,   2160,   9743,
#          7311,  10032,  10226,  16059,  56600,   3940,  13641,   3640,
#          9825,   2104,   9729,   7360,   1526,  12392,  14217,   4113,
#          8816,   9353,   1477,   6710,  11287,  12099,  11556,   9660,
#         28698,  12274,   4388,   3869,   2308,   4400,  14210,   9758,
#          4017,  11249,   4043,   3830,   7227,   7155,  11875,   8540,
#          6410,  11105,  13200,  11040,  16779,  10440,  10836,  13384,
#         13751,   4480,  11382,  11782,   6970,  11422,  15660,   6723,
#          9144,  14601,  12732,   8472,  12469,  18800,   4045,  10594,
#         10420,  12180,   9965,   8696,  13108,   8899,  10566,   6882,
#          7750,   7314,   7018,   8145,   7296,   9638,  15523,   8212,
#          9735,   2980,   2522,  12898,   8740,  10991,   8723,   7030,
#          2572,  24682,   7635,   6380,   6627,   8200,  10307,  10944,
#         19296,  10395,  23920,  16659,  13418,  11003,   9724,   7804,
#         20000,  10386,   8640,   2880,  11949,   7010,  10441,  11409,
#          1974,  21780,  12191,  11358,   9649,  11957,  11613,  18261,
#          9100,   8304,   5470,   8169,  16158,   8263,   5271,  11850,
#         13159,  11643,   9350,  10635,   7024,   8250,  11622,  12000,
#         11160,  11333,  10434,  11520,   8736,   4456,  15870,  45600,
#         26178,   2645,  21299,   8385,  14260,  11900,  16163,  10261,
#         12334,  10530,  11765,  14115,  12936,   8414,  10725,  12803,
#         10304,   8562,   8239,   9765,  15584,   9337,   3950,  11443,
#         11194,  12095,  25286,   2058,  13891,   5150,   7023,  11235,
#         14442,  13618,   8769,  12244,   7250,   9920,  11650,  10624,
#         12925,   9260,  12018,  12772,  10890,   2117,  15922,   6402,
#          4712,  13284,   9178,   1879,  12822,   9840,  10625,  11200,
#         13143,  15263,   3840,   3907,   9541,   8814,  11339,   7560,
#          7848,   6449,  12104,  10928,   8969,  10236,  11616,  13260,
#          7301,  17500,  10921,  10274,   7094,  11025,   7745,  13758,
#         13162,  11332,  12640,   3182,  11600,  12782,   7801,  11302,
#          9759,   2268,  23595,  10021,  19900,   1733,  10385,   4500,
#          9790,   7332,   7032,   5790,   7380,  11317,   8780,  12378,
#          4058,   2368,   7040,   7777,   5062,  36500,  14572,  11844,
#          8810,  14670])

# %%
df = df.drop(columns=['lot_area'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning street alley lot_shape land_contour utilities  \
# 1          190          3   Pave  Grvl       Reg          Lvl    AllPub
# 2           90          0   Pave   NaN       IR1          Lvl    AllPub
# 3           60          0   Pave   NaN       IR1          Lvl    AllPub
# 4           30          3   Pave   NaN       Reg          Lvl    AllPub
# 5           20          0   Pave   NaN       IR1          Lvl    AllPub
#
#   lot_config land_slope neighborhood condition_1 condition_2 bldg_type  \
# 1     Inside        Gtl      OldTown        Norm        Norm    2fmCon
# 2     Inside        Gtl       Sawyer        Norm        Norm    Duplex
# 3     Inside        Gtl      Gilbert        Norm        Norm      1Fam
# 4     Inside        Gtl      OldTown        Norm        Norm      1Fam
# 5     Inside        Gtl        NAmes        Norm        Norm      1Fam
#
#   house_style  overall_qual  overall_cond  year_built  year_remod_add  \
# 1      2Story             6             8        1910            1950
# 2      1Story             5             4        1977            1977
# 3      2Story             7             5        2006            2006
# 4      1Story             5             6        1923            2006
# 5      1Story             6             5        1963            1963
#
#   roof_style roof_matl exterior_first exterior_second mas_vnr_type  \
# 1      Gable   CompShg        AsbShng         AsbShng         None
# 2      Gable   CompShg        Plywood         Plywood         None
# 3      Gable   CompShg        VinylSd         VinylSd         None
# 4      Gable   CompShg        Wd Sdng         Wd Sdng         None
# 5      Gable   CompShg        Plywood         Plywood      BrkFace
#
#    mas_vnr_area exter_qual exter_cond foundation bsmt_qual bsmt_cond  \
# 1           0.0         TA         Fa      Stone        Fa        TA
# 2           0.0         TA         TA     CBlock        Gd        TA
# 3           0.0         Gd         TA      PConc        Gd        Gd
# 4           0.0         Gd         TA     CBlock        TA        TA
# 5         247.0         TA         TA     CBlock        Gd        TA
#
#   bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  \
# 1            No            Unf             0            Unf             0
# 2            No            Unf             0            Unf             0
# 3            Av            GLQ           554            Unf             0
# 4            No            Unf             0            Unf             0
# 5            No            BLQ           609            Unf             0
#
#    bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air electrical  \
# 1         1020           1020    GasA         Gd           N      FuseP
# 2         1967           1967    GasA         TA           Y      SBrkr
# 3          100            654    GasA         Ex           Y      SBrkr
# 4          968            968    GasA         TA           Y      SBrkr
# 5          785           1394    GasA         Gd           Y      SBrkr
#
#    first_flr_sf  second_flr_sf  low_qual_fin_sf  gr_liv_area  bsmt_full_bath  \
# 1           908           1020                0         1928               0
# 2          1967              0                0         1967               0
# 3           664            832                0         1496               1
# 4           968              0                0          968               0
# 5          1394              0                0         1394               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#   kitchen_qual  totrms_abvgrd functional  fireplaces fireplace_qu garage_type  \
# 1           Fa              9        Typ           0          NaN      Detchd
# 2           TA             10        Typ           0          NaN      Attchd
# 3           Gd              7        Typ           1           Gd      Attchd
# 4           TA              5        Typ           0          NaN      Detchd
# 5           TA              6        Typ           2           Gd      Attchd
#
#    garage_yr_blt garage_finish  garage_cars  garage_area garage_qual  \
# 1         1910.0           Unf            1          440          Po
# 2         1977.0           Fin            2          580          TA
# 3         2006.0           RFn            2          426          TA
# 4         1935.0           Unf            2          480          Fa
# 5         1963.0           RFn            2          514          TA
#
#   garage_cond paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  \
# 1          Po           Y             0             60             112
# 2          TA           Y           170              0               0
# 3          TA           Y           100             24               0
# 4          TA           N             0              0             184
# 5          TA           Y             0             76               0
#
#    threessn_porch  screen_porch  pool_area pool_qc fence misc_feature  \
# 1               0             0          0     NaN   NaN          NaN
# 2               0             0          0     NaN   NaN          NaN
# 3               0             0          0     NaN   NaN          NaN
# 4               0             0          0     NaN   NaN          NaN
# 5               0           185          0     NaN   NaN          NaN
#
#    misc_val  mo_sold  yr_sold sale_type
# 1         0        4     2006       WD
# 2         0        8     2006       WD
# 3         0        9     2006       New
# 4         0        7     2007       WD
# 5         0        7     2009       WD

# %%
# COLUMN:		street
# DEFINITION:	Type of road access to property
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.street.unique()
# COLUMN NEEDS TO BE CONVERTED TO INTERGER, NO
# MISSING VALUES!
# Out:
# array(['Pave', 'Grvl'], dtype=object)

# %%
street = {'Pave':'0', 'Grvl':'1'}
df.street = [street[item] for item in df.street] 
df.street.unique()
# Out:
# array(['0', '1'], dtype=object)

# %%
df["street"] = df["street"].astype(dtype=np.int)
df['street'].dtype
# Out:
# dtype('int64')

# %%
# COLUMN:		Alley
# DEFINITION:	Type of alley access to property
# DATA TYPE:	object
# MISSING VALUES:	1911
# UNIQUE VALUES:	
df.alley.unique()
# EVALUATION: LOT WITH MORE THAN ONE POINT OF ENTRY, COULD
# EFFECT PRICE. MISSING DATA CAUSE, LOT DOESN'T ABUT ALLEY.
# COLUMN NEEDS TO BE CONVERTED TO INTERGER!
# Out:
# array(['Grvl', nan, 'Pave'], dtype=object)

# %%
alley = {np.nan:'0', 'Pave':'1', 'Grvl':'1'}
df.alley = [alley[item] for item in df.alley]
df.alley.unique()
# Out:
# array(['1', '0'], dtype=object)

# %%
df['alley'] = pd.to_numeric(df['alley'], errors='coerce')
df['alley'].dtype
# Out:
# dtype('int64')

# %%
# COLUMN:		lot_shape
# DEFINITION:	General shape of property
# DATA TYPE:	object
# MISSING VALUES:	1911
# UNIQUE VALUES:	
df.lot_shape.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE, MISSING
# VALUES, COLUMN TO BE DROPPED!
# Out:
# array(['Reg', 'IR1', 'IR3', 'IR2'], dtype=object)

# %%
df=df.drop(columns=['lot_shape'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley land_contour utilities lot_config  \
# 1          190          3       0      1          Lvl    AllPub     Inside
# 2           90          0       0      0          Lvl    AllPub     Inside
# 3           60          0       0      0          Lvl    AllPub     Inside
# 4           30          3       0      0          Lvl    AllPub     Inside
# 5           20          0       0      0          Lvl    AllPub     Inside
#
#   land_slope neighborhood condition_1 condition_2 bldg_type house_style  \
# 1        Gtl      OldTown        Norm        Norm    2fmCon      2Story
# 2        Gtl       Sawyer        Norm        Norm    Duplex      1Story
# 3        Gtl      Gilbert        Norm        Norm      1Fam      2Story
# 4        Gtl      OldTown        Norm        Norm      1Fam      1Story
# 5        Gtl        NAmes        Norm        Norm      1Fam      1Story
#
#    overall_qual  overall_cond  year_built  year_remod_add roof_style  \
# 1             6             8        1910            1950      Gable
# 2             5             4        1977            1977      Gable
# 3             7             5        2006            2006      Gable
# 4             5             6        1923            2006      Gable
# 5             6             5        1963            1963      Gable
#
#   roof_matl exterior_first exterior_second mas_vnr_type  mas_vnr_area  \
# 1   CompShg        AsbShng         AsbShng         None           0.0
# 2   CompShg        Plywood         Plywood         None           0.0
# 3   CompShg        VinylSd         VinylSd         None           0.0
# 4   CompShg        Wd Sdng         Wd Sdng         None           0.0
# 5   CompShg        Plywood         Plywood      BrkFace         247.0
#
#   exter_qual exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure  \
# 1         TA         Fa      Stone        Fa        TA            No
# 2         TA         TA     CBlock        Gd        TA            No
# 3         Gd         TA      PConc        Gd        Gd            Av
# 4         Gd         TA     CBlock        TA        TA            No
# 5         TA         TA     CBlock        Gd        TA            No
#
#   bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  \
# 1            Unf             0            Unf             0         1020
# 2            Unf             0            Unf             0         1967
# 3            GLQ           554            Unf             0          100
# 4            Unf             0            Unf             0          968
# 5            BLQ           609            Unf             0          785
#
#    total_bsmt_sf heating heating_qc central_air electrical  first_flr_sf  \
# 1           1020    GasA         Gd           N      FuseP           908
# 2           1967    GasA         TA           Y      SBrkr          1967
# 3            654    GasA         Ex           Y      SBrkr           664
# 4            968    GasA         TA           Y      SBrkr           968
# 5           1394    GasA         Gd           Y      SBrkr          1394
#
#    second_flr_sf  low_qual_fin_sf  gr_liv_area  bsmt_full_bath  \
# 1           1020                0         1928               0
# 2              0                0         1967               0
# 3            832                0         1496               1
# 4              0                0          968               0
# 5              0                0         1394               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#   kitchen_qual  totrms_abvgrd functional  fireplaces fireplace_qu garage_type  \
# 1           Fa              9        Typ           0          NaN      Detchd
# 2           TA             10        Typ           0          NaN      Attchd
# 3           Gd              7        Typ           1           Gd      Attchd
# 4           TA              5        Typ           0          NaN      Detchd
# 5           TA              6        Typ           2           Gd      Attchd
#
#    garage_yr_blt garage_finish  garage_cars  garage_area garage_qual  \
# 1         1910.0           Unf            1          440          Po
# 2         1977.0           Fin            2          580          TA
# 3         2006.0           RFn            2          426          TA
# 4         1935.0           Unf            2          480          Fa
# 5         1963.0           RFn            2          514          TA
#
#   garage_cond paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  \
# 1          Po           Y             0             60             112
# 2          TA           Y           170              0               0
# 3          TA           Y           100             24               0
# 4          TA           N             0              0             184
# 5          TA           Y             0             76               0
#
#    threessn_porch  screen_porch  pool_area pool_qc fence misc_feature  \
# 1               0             0          0     NaN   NaN          NaN
# 2               0             0          0     NaN   NaN          NaN
# 3               0             0          0     NaN   NaN          NaN
# 4               0             0          0     NaN   NaN          NaN
# 5               0           185          0     NaN   NaN          NaN
#
#    misc_val  mo_sold  yr_sold sale_type
# 1         0        4     2006       WD
# 2         0        8     2006       WD
# 3         0        9     2006       New
# 4         0        7     2007       WD
# 5         0        7     2009       WD

# %%
# COLUMN:		land_contour
# DEFINITION:	Land Contour: Flatness of the property
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.land_contour.unique()
# EVALUATION: LOT CONTOUR COULD EFFECT PRICE, HOUSE HAS VIEW 
# AND IS WORTH MORE. COLUMN NEEDS TO BE CONVERTED TO INTERGER,
# NO MISSING VALUES!
# Out:
# array(['Lvl', 'Bnk', 'Low', 'HLS'], dtype=object)

# %%
land_contour = {'Lvl':'0', 'HLS':'1', 'Bnk':'2', 'Low':'3'}
df.land_contour = [land_contour[item] for item in df.land_contour] 
df.land_contour.unique()
# Out:
# array(['0', '2', '3', '1'], dtype=object)

# %%
df["land_contour"] = df["land_contour"].astype(dtype=np.int)
df['land_contour'].dtype
# Out:
# dtype('int64')

# %%
# COLUMN:		utilities
# DEFINITION:	Type of utilities available
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.utilities.unique()
# EVALUATION: COLUMN NEEDS TO BE CONVERTED TO INTERGER, NO
# MISSING VALUES!
# Out:
# array(['AllPub', 'NoSewr'], dtype=object)

# %%
utilities = {'AllPub':'0', 'NoSewr':'1', 'NoSeWa':'2'}
df.utilities = [utilities[item] for item in df.utilities] 
df.utilities.unique()
# Out:
# array(['0', '1'], dtype=object)

# %%
df["utilities"] = df["utilities"].astype(dtype=np.int)
df['utilities'].dtype
# Out:
# dtype('int64')

# %%
# COLUMN:		lot_config
# DEFINITION:	Lot configuration
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.lot_config.unique()
# EVALUATION: COLUMN NEEDS TO BE CONVERTED TO INTERGER, NO
# MISSING VALUES!
# Out:
# array(['Inside', 'CulDSac', 'Corner', 'FR2', 'FR3'], dtype=object)

# %%
lot_config = {'Corner':'0', 'Inside':'1', 'CulDSac':'2', 'FR2':'3', 'FR3':'4'}
df.lot_config = [lot_config[item] for item in df.lot_config] 
df.lot_config.unique()
# Out:
# array(['1', '2', '0', '3', '4'], dtype=object)

# %%
df["lot_config"] = df["lot_config"].astype(dtype=np.int)
df['lot_config'].dtype
# Out:
# dtype('int64')

# %%
# COLUMN:		land_slope
# DEFINITION:	Slope of property
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.land_slope.unique()
# EVALUATION: COLUMN IS SIMILAR TO LAND CONTOUR, ONLY
# DESCRIBING DEGREE OF SLOPE. COLUMN DOES NOT PERTAIN TO
# HOUSING PRICE, COLUMN TO BE DROPPED!
# Out:
# array(['Gtl', 'Mod', 'Sev'], dtype=object)

# %%
df = df.drop(columns=['land_slope'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#   neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 1      OldTown        Norm        Norm    2fmCon      2Story             6
# 2       Sawyer        Norm        Norm    Duplex      1Story             5
# 3      Gilbert        Norm        Norm      1Fam      2Story             7
# 4      OldTown        Norm        Norm      1Fam      1Story             5
# 5        NAmes        Norm        Norm      1Fam      1Story             6
#
#    overall_cond  year_built  year_remod_add roof_style roof_matl  \
# 1             8        1910            1950      Gable   CompShg
# 2             4        1977            1977      Gable   CompShg
# 3             5        2006            2006      Gable   CompShg
# 4             6        1923            2006      Gable   CompShg
# 5             5        1963            1963      Gable   CompShg
#
#   exterior_first exterior_second mas_vnr_type  mas_vnr_area exter_qual  \
# 1        AsbShng         AsbShng         None           0.0         TA
# 2        Plywood         Plywood         None           0.0         TA
# 3        VinylSd         VinylSd         None           0.0         Gd
# 4        Wd Sdng         Wd Sdng         None           0.0         Gd
# 5        Plywood         Plywood      BrkFace         247.0         TA
#
#   exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  \
# 1         Fa      Stone        Fa        TA            No            Unf
# 2         TA     CBlock        Gd        TA            No            Unf
# 3         TA      PConc        Gd        Gd            Av            GLQ
# 4         TA     CBlock        TA        TA            No            Unf
# 5         TA     CBlock        Gd        TA            No            BLQ
#
#    bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf  \
# 1             0            Unf             0         1020           1020
# 2             0            Unf             0         1967           1967
# 3           554            Unf             0          100            654
# 4             0            Unf             0          968            968
# 5           609            Unf             0          785           1394
#
#   heating heating_qc central_air electrical  first_flr_sf  second_flr_sf  \
# 1    GasA         Gd           N      FuseP           908           1020
# 2    GasA         TA           Y      SBrkr          1967              0
# 3    GasA         Ex           Y      SBrkr           664            832
# 4    GasA         TA           Y      SBrkr           968              0
# 5    GasA         Gd           Y      SBrkr          1394              0
#
#    low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1                0         1928               0               0          2
# 2                0         1967               0               0          2
# 3                0         1496               1               0          2
# 4                0          968               0               0          1
# 5                0         1394               1               0          1
#
#    half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1          0              4              2           Fa              9
# 2          0              6              2           TA             10
# 3          1              3              1           Gd              7
# 4          0              2              1           TA              5
# 5          1              3              1           TA              6
#
#   functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 1        Typ           0          NaN      Detchd         1910.0
# 2        Typ           0          NaN      Attchd         1977.0
# 3        Typ           1           Gd      Attchd         2006.0
# 4        Typ           0          NaN      Detchd         1935.0
# 5        Typ           2           Gd      Attchd         1963.0
#
#   garage_finish  garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 1           Unf            1          440          Po          Po           Y
# 2           Fin            2          580          TA          TA           Y
# 3           RFn            2          426          TA          TA           Y
# 4           Unf            2          480          Fa          TA           N
# 5           RFn            2          514          TA          TA           Y
#
#    wood_deck_sf  open_porch_sf  enclosed_porch  threessn_porch  screen_porch  \
# 1             0             60             112               0             0
# 2           170              0               0               0             0
# 3           100             24               0               0             0
# 4             0              0             184               0             0
# 5             0             76               0               0           185
#
#    pool_area pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1          0     NaN   NaN          NaN         0        4     2006       WD
# 2          0     NaN   NaN          NaN         0        8     2006       WD
# 3          0     NaN   NaN          NaN         0        9     2006       New
# 4          0     NaN   NaN          NaN         0        7     2007       WD
# 5          0     NaN   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		neighborhood
# DEFINITION:	Physical locations within Ames city limits
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.neighborhood.unique()
# EVALUATION: COLUMN NEEDS TO BE CONVERTED TO INTERGER, NO
# MISSING VALUES!
# Out:
# array(['OldTown', 'Sawyer', 'Gilbert', 'NAmes', 'MeadowV', 'CollgCr',
#        'Somerst', 'Mitchel', 'SawyerW', 'IDOTRR', 'BrkSide', 'Edwards',
#        'ClearCr', 'NWAmes', 'Timber', 'NoRidge', 'NridgHt', 'Crawfor',
#        'StoneBr', 'Veenker', 'BrDale', 'SWISU', 'Blmngtn', 'NPkVill',
#        'Greens', 'Blueste'], dtype=object)

# %%
neighborhood = {'NAmes':'0', 'Gilbert':'1', 'StoneBr':'2', 'NWAmes':'3', 'Somerst':'4', 'BrDale':'5', 'NPkVill':'6','NridgHt':'7', 'Blmngtn':'8', 'NoRidge':'9', 'SawyerW':'10', 'Sawyer':'11', 'Greens':'12', 'BrkSide':'13','OldTown':'14', 'IDOTRR':'15', 'ClearCr':'16', 'SWISU':'17', 'Edwards':'18', 'CollgCr':'19', 'Crawfor':'20','Blueste':'21', 'Mitchel':'22', 'Timber':'23', 'MeadowV':'10', 'Veenker':'24', 'GrnHill':'25', 'Landmrk':'26'}
df.neighborhood = [neighborhood[item] for item in df.neighborhood] 
df.neighborhood.unique()
# Out:
# array(['14', '11', '1', '0', '10', '19', '4', '22', '15', '13', '18',
#        '16', '3', '23', '9', '7', '20', '2', '24', '5', '17', '8', '6',
#        '12', '21'], dtype=object)

# %%
df["neighborhood"] = df["neighborhood"].astype(dtype=np.int)
df['neighborhood'].dtype
# Out:
# dtype('int64')

# %%
# COLUMN:		condition_1
# DEFINITION:	Proximity to various conditions
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df. condition_1.unique()
# COLUMN NEEDS TO BE CONVERTED TO INTERGER, NO
# MISSING VALUES!
# Out:
# array(['Norm', 'Feedr', 'Artery', 'PosA', 'RRAn', 'PosN', 'RRNn', 'RRAe',
#        'RRNe'], dtype=object)

# %%
condition_1 = {'Norm':'0', 'RRAe':'1', 'RRNe':'2', 'Feedr':'3', 'Artery':'4', 'PosA':'5', 'PosN':'6', 'RRAn':'7','RRNn':'8'}
df.condition_1 = [condition_1[item] for item in df.condition_1] 
df.condition_1.unique()
# Out:
# array(['0', '3', '4', '5', '7', '6', '8', '1', '2'], dtype=object)

# %%
df["condition_1"] = df["condition_1"].astype(dtype=np.int)
df['condition_1'].dtype
# Out:
# dtype('int64')

# %%
# COLUMN:		condition_2
# DEFINITION:	Proximity to various conditions (if more than one is present)
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.condition_2.unique()
# EVALUATION: REDUNDANT INFORMATION. COLUMN DOES NOT PERTAIN TO HOUSING PRICE, COLUMN
# TO BE DROPPED!
# Out:
# array(['Norm', 'PosN', 'Feedr', 'PosA'], dtype=object)

# %%
df = df.drop(columns=['condition_2'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1 bldg_type house_style  overall_qual  \
# 1            14            0    2fmCon      2Story             6
# 2            11            0    Duplex      1Story             5
# 3             1            0      1Fam      2Story             7
# 4            14            0      1Fam      1Story             5
# 5             0            0      1Fam      1Story             6
#
#    overall_cond  year_built  year_remod_add roof_style roof_matl  \
# 1             8        1910            1950      Gable   CompShg
# 2             4        1977            1977      Gable   CompShg
# 3             5        2006            2006      Gable   CompShg
# 4             6        1923            2006      Gable   CompShg
# 5             5        1963            1963      Gable   CompShg
#
#   exterior_first exterior_second mas_vnr_type  mas_vnr_area exter_qual  \
# 1        AsbShng         AsbShng         None           0.0         TA
# 2        Plywood         Plywood         None           0.0         TA
# 3        VinylSd         VinylSd         None           0.0         Gd
# 4        Wd Sdng         Wd Sdng         None           0.0         Gd
# 5        Plywood         Plywood      BrkFace         247.0         TA
#
#   exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  \
# 1         Fa      Stone        Fa        TA            No            Unf
# 2         TA     CBlock        Gd        TA            No            Unf
# 3         TA      PConc        Gd        Gd            Av            GLQ
# 4         TA     CBlock        TA        TA            No            Unf
# 5         TA     CBlock        Gd        TA            No            BLQ
#
#    bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf  \
# 1             0            Unf             0         1020           1020
# 2             0            Unf             0         1967           1967
# 3           554            Unf             0          100            654
# 4             0            Unf             0          968            968
# 5           609            Unf             0          785           1394
#
#   heating heating_qc central_air electrical  first_flr_sf  second_flr_sf  \
# 1    GasA         Gd           N      FuseP           908           1020
# 2    GasA         TA           Y      SBrkr          1967              0
# 3    GasA         Ex           Y      SBrkr           664            832
# 4    GasA         TA           Y      SBrkr           968              0
# 5    GasA         Gd           Y      SBrkr          1394              0
#
#    low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1                0         1928               0               0          2
# 2                0         1967               0               0          2
# 3                0         1496               1               0          2
# 4                0          968               0               0          1
# 5                0         1394               1               0          1
#
#    half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1          0              4              2           Fa              9
# 2          0              6              2           TA             10
# 3          1              3              1           Gd              7
# 4          0              2              1           TA              5
# 5          1              3              1           TA              6
#
#   functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 1        Typ           0          NaN      Detchd         1910.0
# 2        Typ           0          NaN      Attchd         1977.0
# 3        Typ           1           Gd      Attchd         2006.0
# 4        Typ           0          NaN      Detchd         1935.0
# 5        Typ           2           Gd      Attchd         1963.0
#
#   garage_finish  garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 1           Unf            1          440          Po          Po           Y
# 2           Fin            2          580          TA          TA           Y
# 3           RFn            2          426          TA          TA           Y
# 4           Unf            2          480          Fa          TA           N
# 5           RFn            2          514          TA          TA           Y
#
#    wood_deck_sf  open_porch_sf  enclosed_porch  threessn_porch  screen_porch  \
# 1             0             60             112               0             0
# 2           170              0               0               0             0
# 3           100             24               0               0             0
# 4             0              0             184               0             0
# 5             0             76               0               0           185
#
#    pool_area pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1          0     NaN   NaN          NaN         0        4     2006       WD
# 2          0     NaN   NaN          NaN         0        8     2006       WD
# 3          0     NaN   NaN          NaN         0        9     2006       New
# 4          0     NaN   NaN          NaN         0        7     2007       WD
# 5          0     NaN   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		bldg_type
# DEFINITION:	Type of dwelling
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.bldg_type.unique()
# COLUMN NEEDS TO BE CONVERTED TO INTERGER, NO
# MISSING VALUES!
# Out:
# array(['2fmCon', 'Duplex', '1Fam', 'TwnhsE', 'Twnhs'], dtype=object)

# %%
bldg_type = {'1Fam':'0', 'TwnhsE':'1', 'Twnhs':'2', 'Duplex':'3', '2fmCon':'4'}
df.bldg_type = [bldg_type[item] for item in df.bldg_type] 
df.bldg_type.unique()
# Out:
# array(['4', '3', '0', '1', '2'], dtype=object)

# %%
df["bldg_type"] = df["bldg_type"].astype(dtype=np.int)
df['bldg_type'].dtype
# Out:
# dtype('int64')

# %%
# COLUMN:		house_style 
# DEFINITION:	Style of dwelling
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.house_style.unique()
# COLUMN NEEDS TO BE CONVERTED TO INTERGER, NO
# MISSING VALUES!
# Out:
# array(['2Story', '1Story', '1.5Fin', 'SLvl', 'SFoyer', '2.5Fin', '2.5Unf',
#        '1.5Unf'], dtype=object)

# %%
house_style = {'1Story':'0', '2Story':'1', 'SLvl':'2', '1.5Fin':'3', 'SFoyer':'4', '2.5Unf':'5', '1.5Unf':'6','2.5Fin':'7'}
df.house_style = [house_style[item] for item in df.house_style] 
df.house_style.unique()
# Out:
# array(['1', '0', '3', '2', '4', '7', '5', '6'], dtype=object)

# %%
df["house_style"] = df["house_style"].astype(dtype=np.int)
df['house_style'].dtype
# Out:
# dtype('int64')

# %%
# COLUMN:		overall_qual
# DEFINITION:	Rates the overall material and finish of the
# house
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.overall_qual.unique()
# EVALUATION: COLUMN READY TO GO... DATA TYPE GOOD, NO MISSING
# VALUES!
# Out:
# array([ 6,  5,  7,  4,  8,  3, 10,  9,  2])

# %%
# COLUMN:		overall_cond        
# DEFINITION:	Rates the overall condition of the house
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df. overall_cond.unique()
# EVALUATION: REDUNDANT INFORMATION. COLUMN DOES NOT PERTAIN TO HOUSING PRICE, COLUMN
# TO BE DROPPED!
# Out:
# array([8, 4, 5, 6, 7, 9, 3, 2, 1])

# %%
df = df.drop(columns=['overall_cond'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    year_built  year_remod_add roof_style roof_matl exterior_first  \
# 1        1910            1950      Gable   CompShg        AsbShng
# 2        1977            1977      Gable   CompShg        Plywood
# 3        2006            2006      Gable   CompShg        VinylSd
# 4        1923            2006      Gable   CompShg        Wd Sdng
# 5        1963            1963      Gable   CompShg        Plywood
#
#   exterior_second mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 1         AsbShng         None           0.0         TA         Fa      Stone
# 2         Plywood         None           0.0         TA         TA     CBlock
# 3         VinylSd         None           0.0         Gd         TA      PConc
# 4         Wd Sdng         None           0.0         Gd         TA     CBlock
# 5         Plywood      BrkFace         247.0         TA         TA     CBlock
#
#   bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 1        Fa        TA            No            Unf             0
# 2        Gd        TA            No            Unf             0
# 3        Gd        Gd            Av            GLQ           554
# 4        TA        TA            No            Unf             0
# 5        Gd        TA            No            BLQ           609
#
#   bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc  \
# 1            Unf             0         1020           1020    GasA         Gd
# 2            Unf             0         1967           1967    GasA         TA
# 3            Unf             0          100            654    GasA         Ex
# 4            Unf             0          968            968    GasA         TA
# 5            Unf             0          785           1394    GasA         Gd
#
#   central_air electrical  first_flr_sf  second_flr_sf  low_qual_fin_sf  \
# 1           N      FuseP           908           1020                0
# 2           Y      SBrkr          1967              0                0
# 3           Y      SBrkr           664            832                0
# 4           Y      SBrkr           968              0                0
# 5           Y      SBrkr          1394              0                0
#
#    gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  \
# 1         1928               0               0          2          0
# 2         1967               0               0          2          0
# 3         1496               1               0          2          1
# 4          968               0               0          1          0
# 5         1394               1               0          1          1
#
#    bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd functional  \
# 1              4              2           Fa              9        Typ
# 2              6              2           TA             10        Typ
# 3              3              1           Gd              7        Typ
# 4              2              1           TA              5        Typ
# 5              3              1           TA              6        Typ
#
#    fireplaces fireplace_qu garage_type  garage_yr_blt garage_finish  \
# 1           0          NaN      Detchd         1910.0           Unf
# 2           0          NaN      Attchd         1977.0           Fin
# 3           1           Gd      Attchd         2006.0           RFn
# 4           0          NaN      Detchd         1935.0           Unf
# 5           2           Gd      Attchd         1963.0           RFn
#
#    garage_cars  garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 1            1          440          Po          Po           Y             0
# 2            2          580          TA          TA           Y           170
# 3            2          426          TA          TA           Y           100
# 4            2          480          Fa          TA           N             0
# 5            2          514          TA          TA           Y             0
#
#    open_porch_sf  enclosed_porch  threessn_porch  screen_porch  pool_area  \
# 1             60             112               0             0          0
# 2              0               0               0             0          0
# 3             24               0               0             0          0
# 4              0             184               0             0          0
# 5             76               0               0           185          0
#
#   pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1     NaN   NaN          NaN         0        4     2006       WD
# 2     NaN   NaN          NaN         0        8     2006       WD
# 3     NaN   NaN          NaN         0        9     2006       New
# 4     NaN   NaN          NaN         0        7     2007       WD
# 5     NaN   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		year_built
# DEFINITION:	Original construction date
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.year_built.unique()
# EVALUATION: COLUMN READY TO GO... DATA TYPE GOOD, NO MISSING
# VALUES! MODELS DON'T DO WELL WITH THIS MANY UNIQUE VALUES.
# DROP COLUMN.
# Out:
# array([1910, 1977, 2006, 1923, 1963, 1972, 1958, 2004, 1991, 1925, 1954,
#        2000, 1924, 1957, 1940, 1956, 1961, 1882, 1968, 1993, 1969, 2007,
#        1920, 1880, 1945, 1971, 1973, 2001, 1953, 1999, 2009, 1998, 1959,
#        1951, 1987, 1970, 1965, 1930, 1890, 1938, 1975, 1992, 1994, 2005,
#        1931, 1926, 1960, 1967, 1962, 2002, 1921, 1997, 2008, 1981, 1948,
#        1988, 1939, 1927, 1984, 2003, 1978, 1964, 1974, 1949, 1995, 1900,
#        1912, 1976, 1966, 1941, 1983, 1950, 1906, 1952, 1947, 1915, 1955,
#        1946, 1996, 1922, 1918, 1980, 1935, 1932, 1928, 2010, 1902, 1919,
#        1917, 1982, 1979, 1937, 1990, 1916, 1934, 1892, 1936, 1989, 1905,
#        1914, 1904, 1986, 1908, 1985, 1907, 1885])

# %%
df = df.drop(columns=['year_built'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    year_remod_add roof_style roof_matl exterior_first exterior_second  \
# 1            1950      Gable   CompShg        AsbShng         AsbShng
# 2            1977      Gable   CompShg        Plywood         Plywood
# 3            2006      Gable   CompShg        VinylSd         VinylSd
# 4            2006      Gable   CompShg        Wd Sdng         Wd Sdng
# 5            1963      Gable   CompShg        Plywood         Plywood
#
#   mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation bsmt_qual  \
# 1         None           0.0         TA         Fa      Stone        Fa
# 2         None           0.0         TA         TA     CBlock        Gd
# 3         None           0.0         Gd         TA      PConc        Gd
# 4         None           0.0         Gd         TA     CBlock        TA
# 5      BrkFace         247.0         TA         TA     CBlock        Gd
#
#   bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  \
# 1        TA            No            Unf             0            Unf
# 2        TA            No            Unf             0            Unf
# 3        Gd            Av            GLQ           554            Unf
# 4        TA            No            Unf             0            Unf
# 5        TA            No            BLQ           609            Unf
#
#    bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air  \
# 1             0         1020           1020    GasA         Gd           N
# 2             0         1967           1967    GasA         TA           Y
# 3             0          100            654    GasA         Ex           Y
# 4             0          968            968    GasA         TA           Y
# 5             0          785           1394    GasA         Gd           Y
#
#   electrical  first_flr_sf  second_flr_sf  low_qual_fin_sf  gr_liv_area  \
# 1      FuseP           908           1020                0         1928
# 2      SBrkr          1967              0                0         1967
# 3      SBrkr           664            832                0         1496
# 4      SBrkr           968              0                0          968
# 5      SBrkr          1394              0                0         1394
#
#    bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  \
# 1               0               0          2          0              4
# 2               0               0          2          0              6
# 3               1               0          2          1              3
# 4               0               0          1          0              2
# 5               1               0          1          1              3
#
#    kitchen_abvgr kitchen_qual  totrms_abvgrd functional  fireplaces  \
# 1              2           Fa              9        Typ           0
# 2              2           TA             10        Typ           0
# 3              1           Gd              7        Typ           1
# 4              1           TA              5        Typ           0
# 5              1           TA              6        Typ           2
#
#   fireplace_qu garage_type  garage_yr_blt garage_finish  garage_cars  \
# 1          NaN      Detchd         1910.0           Unf            1
# 2          NaN      Attchd         1977.0           Fin            2
# 3           Gd      Attchd         2006.0           RFn            2
# 4          NaN      Detchd         1935.0           Unf            2
# 5           Gd      Attchd         1963.0           RFn            2
#
#    garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 1          440          Po          Po           Y             0
# 2          580          TA          TA           Y           170
# 3          426          TA          TA           Y           100
# 4          480          Fa          TA           N             0
# 5          514          TA          TA           Y             0
#
#    open_porch_sf  enclosed_porch  threessn_porch  screen_porch  pool_area  \
# 1             60             112               0             0          0
# 2              0               0               0             0          0
# 3             24               0               0             0          0
# 4              0             184               0             0          0
# 5             76               0               0           185          0
#
#   pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1     NaN   NaN          NaN         0        4     2006       WD
# 2     NaN   NaN          NaN         0        8     2006       WD
# 3     NaN   NaN          NaN         0        9     2006       New
# 4     NaN   NaN          NaN         0        7     2007       WD
# 5     NaN   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		year_remod_add      
# DEFINITION:	Remodel date (same as construction date if no remodeling or additions)
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.year_remod_add.unique()
# EVALUATION: COLUMN READY TO GO... DATA TYPE GOOD, NO MISSING
# VALUES!
# Out:
# array([1950, 1977, 2006, 1963, 1972, 1989, 2004, 1991, 1992, 1954, 2000,
#        1996, 1956, 1986, 2001, 1961, 1994, 1969, 2007, 1971, 2003, 1980,
#        2009, 1999, 2002, 1987, 2008, 1965, 1995, 2005, 1983, 1975, 1998,
#        1953, 1960, 1976, 1985, 1959, 1997, 1981, 1957, 1978, 1964, 1967,
#        1974, 1970, 1968, 1952, 1993, 1955, 1962, 1973, 1990, 1984, 1988,
#        2010, 1958, 1966, 1982, 1979, 1951])

# %%
df = df.drop(columns=['year_remod_add'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual roof_style  \
# 1            14            0          4            1             6      Gable
# 2            11            0          3            0             5      Gable
# 3             1            0          0            1             7      Gable
# 4            14            0          0            0             5      Gable
# 5             0            0          0            0             6      Gable
#
#   roof_matl exterior_first exterior_second mas_vnr_type  mas_vnr_area  \
# 1   CompShg        AsbShng         AsbShng         None           0.0
# 2   CompShg        Plywood         Plywood         None           0.0
# 3   CompShg        VinylSd         VinylSd         None           0.0
# 4   CompShg        Wd Sdng         Wd Sdng         None           0.0
# 5   CompShg        Plywood         Plywood      BrkFace         247.0
#
#   exter_qual exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure  \
# 1         TA         Fa      Stone        Fa        TA            No
# 2         TA         TA     CBlock        Gd        TA            No
# 3         Gd         TA      PConc        Gd        Gd            Av
# 4         Gd         TA     CBlock        TA        TA            No
# 5         TA         TA     CBlock        Gd        TA            No
#
#   bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  \
# 1            Unf             0            Unf             0         1020
# 2            Unf             0            Unf             0         1967
# 3            GLQ           554            Unf             0          100
# 4            Unf             0            Unf             0          968
# 5            BLQ           609            Unf             0          785
#
#    total_bsmt_sf heating heating_qc central_air electrical  first_flr_sf  \
# 1           1020    GasA         Gd           N      FuseP           908
# 2           1967    GasA         TA           Y      SBrkr          1967
# 3            654    GasA         Ex           Y      SBrkr           664
# 4            968    GasA         TA           Y      SBrkr           968
# 5           1394    GasA         Gd           Y      SBrkr          1394
#
#    second_flr_sf  low_qual_fin_sf  gr_liv_area  bsmt_full_bath  \
# 1           1020                0         1928               0
# 2              0                0         1967               0
# 3            832                0         1496               1
# 4              0                0          968               0
# 5              0                0         1394               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#   kitchen_qual  totrms_abvgrd functional  fireplaces fireplace_qu garage_type  \
# 1           Fa              9        Typ           0          NaN      Detchd
# 2           TA             10        Typ           0          NaN      Attchd
# 3           Gd              7        Typ           1           Gd      Attchd
# 4           TA              5        Typ           0          NaN      Detchd
# 5           TA              6        Typ           2           Gd      Attchd
#
#    garage_yr_blt garage_finish  garage_cars  garage_area garage_qual  \
# 1         1910.0           Unf            1          440          Po
# 2         1977.0           Fin            2          580          TA
# 3         2006.0           RFn            2          426          TA
# 4         1935.0           Unf            2          480          Fa
# 5         1963.0           RFn            2          514          TA
#
#   garage_cond paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  \
# 1          Po           Y             0             60             112
# 2          TA           Y           170              0               0
# 3          TA           Y           100             24               0
# 4          TA           N             0              0             184
# 5          TA           Y             0             76               0
#
#    threessn_porch  screen_porch  pool_area pool_qc fence misc_feature  \
# 1               0             0          0     NaN   NaN          NaN
# 2               0             0          0     NaN   NaN          NaN
# 3               0             0          0     NaN   NaN          NaN
# 4               0             0          0     NaN   NaN          NaN
# 5               0           185          0     NaN   NaN          NaN
#
#    misc_val  mo_sold  yr_sold sale_type
# 1         0        4     2006       WD
# 2         0        8     2006       WD
# 3         0        9     2006       New
# 4         0        7     2007       WD
# 5         0        7     2009       WD

# %%
# COLUMN:		roof_style         
# DEFINITION:	Type of roof
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.roof_style.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE,
# COLUMN TO BE DROPPED!
# Out:
# array(['Gable', 'Hip', 'Gambrel', 'Flat', 'Mansard', 'Shed'], dtype=object)

# %%
df = df.drop(columns=['roof_style'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual roof_matl  \
# 1            14            0          4            1             6   CompShg
# 2            11            0          3            0             5   CompShg
# 3             1            0          0            1             7   CompShg
# 4            14            0          0            0             5   CompShg
# 5             0            0          0            0             6   CompShg
#
#   exterior_first exterior_second mas_vnr_type  mas_vnr_area exter_qual  \
# 1        AsbShng         AsbShng         None           0.0         TA
# 2        Plywood         Plywood         None           0.0         TA
# 3        VinylSd         VinylSd         None           0.0         Gd
# 4        Wd Sdng         Wd Sdng         None           0.0         Gd
# 5        Plywood         Plywood      BrkFace         247.0         TA
#
#   exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  \
# 1         Fa      Stone        Fa        TA            No            Unf
# 2         TA     CBlock        Gd        TA            No            Unf
# 3         TA      PConc        Gd        Gd            Av            GLQ
# 4         TA     CBlock        TA        TA            No            Unf
# 5         TA     CBlock        Gd        TA            No            BLQ
#
#    bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf  \
# 1             0            Unf             0         1020           1020
# 2             0            Unf             0         1967           1967
# 3           554            Unf             0          100            654
# 4             0            Unf             0          968            968
# 5           609            Unf             0          785           1394
#
#   heating heating_qc central_air electrical  first_flr_sf  second_flr_sf  \
# 1    GasA         Gd           N      FuseP           908           1020
# 2    GasA         TA           Y      SBrkr          1967              0
# 3    GasA         Ex           Y      SBrkr           664            832
# 4    GasA         TA           Y      SBrkr           968              0
# 5    GasA         Gd           Y      SBrkr          1394              0
#
#    low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1                0         1928               0               0          2
# 2                0         1967               0               0          2
# 3                0         1496               1               0          2
# 4                0          968               0               0          1
# 5                0         1394               1               0          1
#
#    half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1          0              4              2           Fa              9
# 2          0              6              2           TA             10
# 3          1              3              1           Gd              7
# 4          0              2              1           TA              5
# 5          1              3              1           TA              6
#
#   functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 1        Typ           0          NaN      Detchd         1910.0
# 2        Typ           0          NaN      Attchd         1977.0
# 3        Typ           1           Gd      Attchd         2006.0
# 4        Typ           0          NaN      Detchd         1935.0
# 5        Typ           2           Gd      Attchd         1963.0
#
#   garage_finish  garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 1           Unf            1          440          Po          Po           Y
# 2           Fin            2          580          TA          TA           Y
# 3           RFn            2          426          TA          TA           Y
# 4           Unf            2          480          Fa          TA           N
# 5           RFn            2          514          TA          TA           Y
#
#    wood_deck_sf  open_porch_sf  enclosed_porch  threessn_porch  screen_porch  \
# 1             0             60             112               0             0
# 2           170              0               0               0             0
# 3           100             24               0               0             0
# 4             0              0             184               0             0
# 5             0             76               0               0           185
#
#    pool_area pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1          0     NaN   NaN          NaN         0        4     2006       WD
# 2          0     NaN   NaN          NaN         0        8     2006       WD
# 3          0     NaN   NaN          NaN         0        9     2006       New
# 4          0     NaN   NaN          NaN         0        7     2007       WD
# 5          0     NaN   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		roof_matl                  
# DEFINITION:	Roof material
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.roof_matl.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE,
# COLUMN TO BE DROPPED!
# Out:
# array(['CompShg', 'Metal', 'WdShake', 'Tar&Grv', 'WdShngl', 'Roll'],
#       dtype=object)

# %%
df = df.drop(columns=['roof_matl'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#   exterior_first exterior_second mas_vnr_type  mas_vnr_area exter_qual  \
# 1        AsbShng         AsbShng         None           0.0         TA
# 2        Plywood         Plywood         None           0.0         TA
# 3        VinylSd         VinylSd         None           0.0         Gd
# 4        Wd Sdng         Wd Sdng         None           0.0         Gd
# 5        Plywood         Plywood      BrkFace         247.0         TA
#
#   exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  \
# 1         Fa      Stone        Fa        TA            No            Unf
# 2         TA     CBlock        Gd        TA            No            Unf
# 3         TA      PConc        Gd        Gd            Av            GLQ
# 4         TA     CBlock        TA        TA            No            Unf
# 5         TA     CBlock        Gd        TA            No            BLQ
#
#    bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf  \
# 1             0            Unf             0         1020           1020
# 2             0            Unf             0         1967           1967
# 3           554            Unf             0          100            654
# 4             0            Unf             0          968            968
# 5           609            Unf             0          785           1394
#
#   heating heating_qc central_air electrical  first_flr_sf  second_flr_sf  \
# 1    GasA         Gd           N      FuseP           908           1020
# 2    GasA         TA           Y      SBrkr          1967              0
# 3    GasA         Ex           Y      SBrkr           664            832
# 4    GasA         TA           Y      SBrkr           968              0
# 5    GasA         Gd           Y      SBrkr          1394              0
#
#    low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1                0         1928               0               0          2
# 2                0         1967               0               0          2
# 3                0         1496               1               0          2
# 4                0          968               0               0          1
# 5                0         1394               1               0          1
#
#    half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1          0              4              2           Fa              9
# 2          0              6              2           TA             10
# 3          1              3              1           Gd              7
# 4          0              2              1           TA              5
# 5          1              3              1           TA              6
#
#   functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 1        Typ           0          NaN      Detchd         1910.0
# 2        Typ           0          NaN      Attchd         1977.0
# 3        Typ           1           Gd      Attchd         2006.0
# 4        Typ           0          NaN      Detchd         1935.0
# 5        Typ           2           Gd      Attchd         1963.0
#
#   garage_finish  garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 1           Unf            1          440          Po          Po           Y
# 2           Fin            2          580          TA          TA           Y
# 3           RFn            2          426          TA          TA           Y
# 4           Unf            2          480          Fa          TA           N
# 5           RFn            2          514          TA          TA           Y
#
#    wood_deck_sf  open_porch_sf  enclosed_porch  threessn_porch  screen_porch  \
# 1             0             60             112               0             0
# 2           170              0               0               0             0
# 3           100             24               0               0             0
# 4             0              0             184               0             0
# 5             0             76               0               0           185
#
#    pool_area pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1          0     NaN   NaN          NaN         0        4     2006       WD
# 2          0     NaN   NaN          NaN         0        8     2006       WD
# 3          0     NaN   NaN          NaN         0        9     2006       New
# 4          0     NaN   NaN          NaN         0        7     2007       WD
# 5          0     NaN   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		exterior_first                        
# DEFINITION:	Exterior covering on house
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.exterior_first.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE,
# COLUMN TO BE DROPPED!
# Out:
# array(['AsbShng', 'Plywood', 'VinylSd', 'Wd Sdng', 'CemntBd', 'MetalSd',
#        'HdBoard', 'BrkComm', 'Stucco', 'WdShing', 'BrkFace', 'PreCast',
#        'AsphShn'], dtype=object)

# %%
df = df.drop(columns=['exterior_first'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#   exterior_second mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 1         AsbShng         None           0.0         TA         Fa      Stone
# 2         Plywood         None           0.0         TA         TA     CBlock
# 3         VinylSd         None           0.0         Gd         TA      PConc
# 4         Wd Sdng         None           0.0         Gd         TA     CBlock
# 5         Plywood      BrkFace         247.0         TA         TA     CBlock
#
#   bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 1        Fa        TA            No            Unf             0
# 2        Gd        TA            No            Unf             0
# 3        Gd        Gd            Av            GLQ           554
# 4        TA        TA            No            Unf             0
# 5        Gd        TA            No            BLQ           609
#
#   bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc  \
# 1            Unf             0         1020           1020    GasA         Gd
# 2            Unf             0         1967           1967    GasA         TA
# 3            Unf             0          100            654    GasA         Ex
# 4            Unf             0          968            968    GasA         TA
# 5            Unf             0          785           1394    GasA         Gd
#
#   central_air electrical  first_flr_sf  second_flr_sf  low_qual_fin_sf  \
# 1           N      FuseP           908           1020                0
# 2           Y      SBrkr          1967              0                0
# 3           Y      SBrkr           664            832                0
# 4           Y      SBrkr           968              0                0
# 5           Y      SBrkr          1394              0                0
#
#    gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  \
# 1         1928               0               0          2          0
# 2         1967               0               0          2          0
# 3         1496               1               0          2          1
# 4          968               0               0          1          0
# 5         1394               1               0          1          1
#
#    bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd functional  \
# 1              4              2           Fa              9        Typ
# 2              6              2           TA             10        Typ
# 3              3              1           Gd              7        Typ
# 4              2              1           TA              5        Typ
# 5              3              1           TA              6        Typ
#
#    fireplaces fireplace_qu garage_type  garage_yr_blt garage_finish  \
# 1           0          NaN      Detchd         1910.0           Unf
# 2           0          NaN      Attchd         1977.0           Fin
# 3           1           Gd      Attchd         2006.0           RFn
# 4           0          NaN      Detchd         1935.0           Unf
# 5           2           Gd      Attchd         1963.0           RFn
#
#    garage_cars  garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 1            1          440          Po          Po           Y             0
# 2            2          580          TA          TA           Y           170
# 3            2          426          TA          TA           Y           100
# 4            2          480          Fa          TA           N             0
# 5            2          514          TA          TA           Y             0
#
#    open_porch_sf  enclosed_porch  threessn_porch  screen_porch  pool_area  \
# 1             60             112               0             0          0
# 2              0               0               0             0          0
# 3             24               0               0             0          0
# 4              0             184               0             0          0
# 5             76               0               0           185          0
#
#   pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1     NaN   NaN          NaN         0        4     2006       WD
# 2     NaN   NaN          NaN         0        8     2006       WD
# 3     NaN   NaN          NaN         0        9     2006       New
# 4     NaN   NaN          NaN         0        7     2007       WD
# 5     NaN   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		exterior_second                              
# DEFINITION:	Exterior covering on house (if more than one
# material)
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.exterior_second.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE,
# COLUMN TO BE DROPPED!
# Out:
# array(['AsbShng', 'Plywood', 'VinylSd', 'Wd Sdng', 'CmentBd', 'MetalSd',
#        'BrkFace', 'Stucco', 'HdBoard', 'Wd Shng', 'ImStucc', 'Brk Cmn',
#        'PreCast', 'CBlock', 'AsphShn', 'Other'], dtype=object)

# %%
df = df.drop(columns=['exterior_second'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#   mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation bsmt_qual  \
# 1         None           0.0         TA         Fa      Stone        Fa
# 2         None           0.0         TA         TA     CBlock        Gd
# 3         None           0.0         Gd         TA      PConc        Gd
# 4         None           0.0         Gd         TA     CBlock        TA
# 5      BrkFace         247.0         TA         TA     CBlock        Gd
#
#   bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  \
# 1        TA            No            Unf             0            Unf
# 2        TA            No            Unf             0            Unf
# 3        Gd            Av            GLQ           554            Unf
# 4        TA            No            Unf             0            Unf
# 5        TA            No            BLQ           609            Unf
#
#    bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air  \
# 1             0         1020           1020    GasA         Gd           N
# 2             0         1967           1967    GasA         TA           Y
# 3             0          100            654    GasA         Ex           Y
# 4             0          968            968    GasA         TA           Y
# 5             0          785           1394    GasA         Gd           Y
#
#   electrical  first_flr_sf  second_flr_sf  low_qual_fin_sf  gr_liv_area  \
# 1      FuseP           908           1020                0         1928
# 2      SBrkr          1967              0                0         1967
# 3      SBrkr           664            832                0         1496
# 4      SBrkr           968              0                0          968
# 5      SBrkr          1394              0                0         1394
#
#    bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  \
# 1               0               0          2          0              4
# 2               0               0          2          0              6
# 3               1               0          2          1              3
# 4               0               0          1          0              2
# 5               1               0          1          1              3
#
#    kitchen_abvgr kitchen_qual  totrms_abvgrd functional  fireplaces  \
# 1              2           Fa              9        Typ           0
# 2              2           TA             10        Typ           0
# 3              1           Gd              7        Typ           1
# 4              1           TA              5        Typ           0
# 5              1           TA              6        Typ           2
#
#   fireplace_qu garage_type  garage_yr_blt garage_finish  garage_cars  \
# 1          NaN      Detchd         1910.0           Unf            1
# 2          NaN      Attchd         1977.0           Fin            2
# 3           Gd      Attchd         2006.0           RFn            2
# 4          NaN      Detchd         1935.0           Unf            2
# 5           Gd      Attchd         1963.0           RFn            2
#
#    garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 1          440          Po          Po           Y             0
# 2          580          TA          TA           Y           170
# 3          426          TA          TA           Y           100
# 4          480          Fa          TA           N             0
# 5          514          TA          TA           Y             0
#
#    open_porch_sf  enclosed_porch  threessn_porch  screen_porch  pool_area  \
# 1             60             112               0             0          0
# 2              0               0               0             0          0
# 3             24               0               0             0          0
# 4              0             184               0             0          0
# 5             76               0               0           185          0
#
#   pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1     NaN   NaN          NaN         0        4     2006       WD
# 2     NaN   NaN          NaN         0        8     2006       WD
# 3     NaN   NaN          NaN         0        9     2006       New
# 4     NaN   NaN          NaN         0        7     2007       WD
# 5     NaN   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		mas_vnr_type                                     
# DEFINITION:	Masonry veneer type
# DATA TYPE:	object
# MISSING VALUES:	22
# UNIQUE VALUES:	
df.mas_vnr_type.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE, MISSING
# VALUES, COLUMN TO BE DROPPED!
# Out:
# array(['None', 'BrkFace', 'Stone', 'BrkCmn', 'CBlock', nan], dtype=object)

# %%
df = df.drop(columns=['mas_vnr_type'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    mas_vnr_area exter_qual exter_cond foundation bsmt_qual bsmt_cond  \
# 1           0.0         TA         Fa      Stone        Fa        TA
# 2           0.0         TA         TA     CBlock        Gd        TA
# 3           0.0         Gd         TA      PConc        Gd        Gd
# 4           0.0         Gd         TA     CBlock        TA        TA
# 5         247.0         TA         TA     CBlock        Gd        TA
#
#   bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  \
# 1            No            Unf             0            Unf             0
# 2            No            Unf             0            Unf             0
# 3            Av            GLQ           554            Unf             0
# 4            No            Unf             0            Unf             0
# 5            No            BLQ           609            Unf             0
#
#    bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air electrical  \
# 1         1020           1020    GasA         Gd           N      FuseP
# 2         1967           1967    GasA         TA           Y      SBrkr
# 3          100            654    GasA         Ex           Y      SBrkr
# 4          968            968    GasA         TA           Y      SBrkr
# 5          785           1394    GasA         Gd           Y      SBrkr
#
#    first_flr_sf  second_flr_sf  low_qual_fin_sf  gr_liv_area  bsmt_full_bath  \
# 1           908           1020                0         1928               0
# 2          1967              0                0         1967               0
# 3           664            832                0         1496               1
# 4           968              0                0          968               0
# 5          1394              0                0         1394               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#   kitchen_qual  totrms_abvgrd functional  fireplaces fireplace_qu garage_type  \
# 1           Fa              9        Typ           0          NaN      Detchd
# 2           TA             10        Typ           0          NaN      Attchd
# 3           Gd              7        Typ           1           Gd      Attchd
# 4           TA              5        Typ           0          NaN      Detchd
# 5           TA              6        Typ           2           Gd      Attchd
#
#    garage_yr_blt garage_finish  garage_cars  garage_area garage_qual  \
# 1         1910.0           Unf            1          440          Po
# 2         1977.0           Fin            2          580          TA
# 3         2006.0           RFn            2          426          TA
# 4         1935.0           Unf            2          480          Fa
# 5         1963.0           RFn            2          514          TA
#
#   garage_cond paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  \
# 1          Po           Y             0             60             112
# 2          TA           Y           170              0               0
# 3          TA           Y           100             24               0
# 4          TA           N             0              0             184
# 5          TA           Y             0             76               0
#
#    threessn_porch  screen_porch  pool_area pool_qc fence misc_feature  \
# 1               0             0          0     NaN   NaN          NaN
# 2               0             0          0     NaN   NaN          NaN
# 3               0             0          0     NaN   NaN          NaN
# 4               0             0          0     NaN   NaN          NaN
# 5               0           185          0     NaN   NaN          NaN
#
#    misc_val  mo_sold  yr_sold sale_type
# 1         0        4     2006       WD
# 2         0        8     2006       WD
# 3         0        9     2006       New
# 4         0        7     2007       WD
# 5         0        7     2009       WD

# %%
# COLUMN:		mas_vnr_area                                          
# DEFINITION:	Masonry veneer area in square feet
# DATA TYPE:	float64
# MISSING VALUES:	22
# UNIQUE VALUES:	
df.mas_vnr_area.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE, MISSING
# VALUES, COLUMN TO BE DROPPED!
# Out:
# array([   0.,  247.,   23.,   98.,  104.,  156.,  180.,   44.,   76.,
#          70.,  352.,  162.,  444.,  495.,  340.,  634.,  182.,  147.,
#         108.,   20.,  423.,  178.,  359.,  762.,   75.,  161.,  674.,
#         100.,  306.,  509.,  653.,  450.,  360.,  680.,  112.,   72.,
#         440., 1378.,  304.,  364.,  754.,  788.,  230.,  368.,  120.,
#         113.,  216.,  371.,  153.,  151.,  396.,  215.,  472.,  500.,
#         468.,   14.,   50.,   96.,   99.,  342.,  174.,  310.,  114.,
#          74.,  270.,  260.,  123.,  218.,  415.,  921.,  771.,  726.,
#          16.,  362.,  473.,  870., 1224.,  285.,  420.,  137.,  259.,
#          82.,  632.,  170.,  408.,   53.,  532.,  286.,  206.,  308.,
#         405.,  128.,  236.,  350.,  302.,  256.,  657.,  194.,  567.,
#         116.,   65.,  305.,  188.,  281.,  300.,  198.,   95.,  481.,
#         226.,  459.,  480.,  422.,  877.,  166.,  149.,  190.,  189.,
#         492.,  205.,  130.,  250.,  223.,  280.,  435.,  229.,  438.,
#         975.,   67.,  150.,  196.,   80.,  380.,   94.,  594.,  288.,
#         209.,   54.,  266., 1170.,  227.,  240.,   89.,  246.,  263.,
#         169.,  621.,  252.,   18.,  232.,  200.,   90.,  432.,  144.,
#         284.,  143.,  456.,  176.,  134.,  388.,   52.,  297., 1290.,
#         140.,  187.,  356.,  248.,  212.,  136.,  584.,  378.,   45.,
#          88.,  261.,  320.,   66.,  430., 1159.,  448.,  399.,  233.,
#          34.,  265.,  515.,  258.,  142.,  171.,  600.,  615.,  293.,
#         768.,  220.,  268.,  318.,   91.,  145.,   68.,  366.,  525.,
#         208.,  264.,  115.,   51.,  106.,   32.,   58.,   84.,   60.,
#         513.,  550.,   81.,  295.,   85.,  504.,  549.,  164.,  501.,
#         328.,   48.,  141.,  568.,  117.,  172.,   11.,  175.,  238.,
#         287.,  207.,  101.,  312.,  217.,   nan,  203.,  464.,  410.])

# %%
df = df.drop(columns=['mas_vnr_area'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual exter_qual  \
# 1            14            0          4            1             6         TA
# 2            11            0          3            0             5         TA
# 3             1            0          0            1             7         Gd
# 4            14            0          0            0             5         Gd
# 5             0            0          0            0             6         TA
#
#   exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  \
# 1         Fa      Stone        Fa        TA            No            Unf
# 2         TA     CBlock        Gd        TA            No            Unf
# 3         TA      PConc        Gd        Gd            Av            GLQ
# 4         TA     CBlock        TA        TA            No            Unf
# 5         TA     CBlock        Gd        TA            No            BLQ
#
#    bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf  \
# 1             0            Unf             0         1020           1020
# 2             0            Unf             0         1967           1967
# 3           554            Unf             0          100            654
# 4             0            Unf             0          968            968
# 5           609            Unf             0          785           1394
#
#   heating heating_qc central_air electrical  first_flr_sf  second_flr_sf  \
# 1    GasA         Gd           N      FuseP           908           1020
# 2    GasA         TA           Y      SBrkr          1967              0
# 3    GasA         Ex           Y      SBrkr           664            832
# 4    GasA         TA           Y      SBrkr           968              0
# 5    GasA         Gd           Y      SBrkr          1394              0
#
#    low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1                0         1928               0               0          2
# 2                0         1967               0               0          2
# 3                0         1496               1               0          2
# 4                0          968               0               0          1
# 5                0         1394               1               0          1
#
#    half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1          0              4              2           Fa              9
# 2          0              6              2           TA             10
# 3          1              3              1           Gd              7
# 4          0              2              1           TA              5
# 5          1              3              1           TA              6
#
#   functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 1        Typ           0          NaN      Detchd         1910.0
# 2        Typ           0          NaN      Attchd         1977.0
# 3        Typ           1           Gd      Attchd         2006.0
# 4        Typ           0          NaN      Detchd         1935.0
# 5        Typ           2           Gd      Attchd         1963.0
#
#   garage_finish  garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 1           Unf            1          440          Po          Po           Y
# 2           Fin            2          580          TA          TA           Y
# 3           RFn            2          426          TA          TA           Y
# 4           Unf            2          480          Fa          TA           N
# 5           RFn            2          514          TA          TA           Y
#
#    wood_deck_sf  open_porch_sf  enclosed_porch  threessn_porch  screen_porch  \
# 1             0             60             112               0             0
# 2           170              0               0               0             0
# 3           100             24               0               0             0
# 4             0              0             184               0             0
# 5             0             76               0               0           185
#
#    pool_area pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1          0     NaN   NaN          NaN         0        4     2006       WD
# 2          0     NaN   NaN          NaN         0        8     2006       WD
# 3          0     NaN   NaN          NaN         0        9     2006       New
# 4          0     NaN   NaN          NaN         0        7     2007       WD
# 5          0     NaN   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		exter_qual                                                   
# DEFINITION:	Evaluates the quality of the material on the
# exterior
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.exter_qual.unique()
# COLUMN NEEDS TO BE CONVERTED TO INTERGER, NO
# MISSING VALUES!
# Out:
# array(['TA', 'Gd', 'Fa', 'Ex'], dtype=object)

# %%
exter_qual = {'TA':'0', 'Gd':'1', 'Ex':'2', 'Fa':'3'}
df.exter_qual = [exter_qual[item] for item in df.exter_qual] 
df.exter_qual.unique()
# Out:
# array(['0', '1', '3', '2'], dtype=object)

# %%
df["exter_qual"] = df["exter_qual"].astype(dtype=np.int)
df['exter_qual'].dtype
# Out:
# dtype('int64')

# %%
# COLUMN:		exter_cond                                                           
# DEFINITION:	Evaluates the present condition of the material on the exterior
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.exter_cond.unique()
# COLUMN NEEDS TO BE CONVERTED TO INTERGER, NO
# MISSING VALUES, SIMILIAR TO exter_qual! DROPPING IN FAVOR OF
# exter_qual!
# Out:
# array(['Fa', 'TA', 'Gd', 'Ex', 'Po'], dtype=object)

# %%
df = df.drop(columns=['exter_cond'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual foundation bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  \
# 1           0      Stone        Fa        TA            No            Unf
# 2           0     CBlock        Gd        TA            No            Unf
# 3           1      PConc        Gd        Gd            Av            GLQ
# 4           1     CBlock        TA        TA            No            Unf
# 5           0     CBlock        Gd        TA            No            BLQ
#
#    bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf  \
# 1             0            Unf             0         1020           1020
# 2             0            Unf             0         1967           1967
# 3           554            Unf             0          100            654
# 4             0            Unf             0          968            968
# 5           609            Unf             0          785           1394
#
#   heating heating_qc central_air electrical  first_flr_sf  second_flr_sf  \
# 1    GasA         Gd           N      FuseP           908           1020
# 2    GasA         TA           Y      SBrkr          1967              0
# 3    GasA         Ex           Y      SBrkr           664            832
# 4    GasA         TA           Y      SBrkr           968              0
# 5    GasA         Gd           Y      SBrkr          1394              0
#
#    low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1                0         1928               0               0          2
# 2                0         1967               0               0          2
# 3                0         1496               1               0          2
# 4                0          968               0               0          1
# 5                0         1394               1               0          1
#
#    half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1          0              4              2           Fa              9
# 2          0              6              2           TA             10
# 3          1              3              1           Gd              7
# 4          0              2              1           TA              5
# 5          1              3              1           TA              6
#
#   functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 1        Typ           0          NaN      Detchd         1910.0
# 2        Typ           0          NaN      Attchd         1977.0
# 3        Typ           1           Gd      Attchd         2006.0
# 4        Typ           0          NaN      Detchd         1935.0
# 5        Typ           2           Gd      Attchd         1963.0
#
#   garage_finish  garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 1           Unf            1          440          Po          Po           Y
# 2           Fin            2          580          TA          TA           Y
# 3           RFn            2          426          TA          TA           Y
# 4           Unf            2          480          Fa          TA           N
# 5           RFn            2          514          TA          TA           Y
#
#    wood_deck_sf  open_porch_sf  enclosed_porch  threessn_porch  screen_porch  \
# 1             0             60             112               0             0
# 2           170              0               0               0             0
# 3           100             24               0               0             0
# 4             0              0             184               0             0
# 5             0             76               0               0           185
#
#    pool_area pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1          0     NaN   NaN          NaN         0        4     2006       WD
# 2          0     NaN   NaN          NaN         0        8     2006       WD
# 3          0     NaN   NaN          NaN         0        9     2006       New
# 4          0     NaN   NaN          NaN         0        7     2007       WD
# 5          0     NaN   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		foundation                                                                    
# DEFINITION:	Type of foundation
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.foundation.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE,
# COLUMN TO BE DROPPED!
# Out:
# array(['Stone', 'CBlock', 'PConc', 'BrkTil', 'Slab', 'Wood'], dtype=object)

# %%
foundation  = {'CBlock':'0', 'PConc':'1', 'Slab':'2', 'BrkTil':'3', 'Stone':'4', 'Wood':'5'}
df.foundation  = [foundation [item] for item in df.foundation ] 
df.foundation .unique()
# Out:
# array(['4', '0', '1', '3', '2', '5'], dtype=object)

# %%
df["foundation"] = df["foundation"].astype(dtype=np.int)
df['foundation'].dtype
# Out:
# dtype('int64')

# %%
# COLUMN:		bsmt_qual                                                                              
# DEFINITION:	Evaluates the height of the basement
# DATA TYPE:	object
# MISSING VALUES:	55
# UNIQUE VALUES:	
df. bsmt_qual.unique()
# COLUMN NEEDS TO BE CONVERTED TO INTERGER, CONVERT
# MISSING VALUES!
# Out:
# array(['Fa', 'Gd', 'TA', 'Ex', nan, 'Po'], dtype=object)

# %%
df = df.drop(columns=['bsmt_qual'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation bsmt_cond bsmt_exposure bsmtfin_type_1  \
# 1           0           4        TA            No            Unf
# 2           0           0        TA            No            Unf
# 3           1           1        Gd            Av            GLQ
# 4           1           0        TA            No            Unf
# 5           0           0        TA            No            BLQ
#
#    bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf  \
# 1             0            Unf             0         1020           1020
# 2             0            Unf             0         1967           1967
# 3           554            Unf             0          100            654
# 4             0            Unf             0          968            968
# 5           609            Unf             0          785           1394
#
#   heating heating_qc central_air electrical  first_flr_sf  second_flr_sf  \
# 1    GasA         Gd           N      FuseP           908           1020
# 2    GasA         TA           Y      SBrkr          1967              0
# 3    GasA         Ex           Y      SBrkr           664            832
# 4    GasA         TA           Y      SBrkr           968              0
# 5    GasA         Gd           Y      SBrkr          1394              0
#
#    low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1                0         1928               0               0          2
# 2                0         1967               0               0          2
# 3                0         1496               1               0          2
# 4                0          968               0               0          1
# 5                0         1394               1               0          1
#
#    half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1          0              4              2           Fa              9
# 2          0              6              2           TA             10
# 3          1              3              1           Gd              7
# 4          0              2              1           TA              5
# 5          1              3              1           TA              6
#
#   functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 1        Typ           0          NaN      Detchd         1910.0
# 2        Typ           0          NaN      Attchd         1977.0
# 3        Typ           1           Gd      Attchd         2006.0
# 4        Typ           0          NaN      Detchd         1935.0
# 5        Typ           2           Gd      Attchd         1963.0
#
#   garage_finish  garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 1           Unf            1          440          Po          Po           Y
# 2           Fin            2          580          TA          TA           Y
# 3           RFn            2          426          TA          TA           Y
# 4           Unf            2          480          Fa          TA           N
# 5           RFn            2          514          TA          TA           Y
#
#    wood_deck_sf  open_porch_sf  enclosed_porch  threessn_porch  screen_porch  \
# 1             0             60             112               0             0
# 2           170              0               0               0             0
# 3           100             24               0               0             0
# 4             0              0             184               0             0
# 5             0             76               0               0           185
#
#    pool_area pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1          0     NaN   NaN          NaN         0        4     2006       WD
# 2          0     NaN   NaN          NaN         0        8     2006       WD
# 3          0     NaN   NaN          NaN         0        9     2006       New
# 4          0     NaN   NaN          NaN         0        7     2007       WD
# 5          0     NaN   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		bsmt_cond                                                                                        
# DEFINITION:	Evaluates the general condition of the basement
# DATA TYPE:	object
# MISSING VALUES:	55
# UNIQUE VALUES:	
df.bsmt_cond.unique()
# EVALUATION: COLUMN NEEDS TO BE CONVERTED TO INTERGER
# MISSING VALUES!
# Out:
# array(['TA', 'Gd', nan, 'Fa'], dtype=object)

# %%
bsmt_cond = {np.nan:'0', 'Gd':'1', 'TA':'2', 'Po':'3', 'Fa':'4', 'Ex':'5'}
df.bsmt_cond = [bsmt_cond[item] for item in df.bsmt_cond] 
df.bsmt_cond.unique()
# Out:
# array(['2', '1', '0', '4'], dtype=object)

# %%
df['bsmt_cond'] = pd.to_numeric(df['bsmt_cond'], errors='coerce')
df['bsmt_cond'].dtype
# Out:
# dtype('int64')

# %%
# COLUMN:		bsmt_exposure                                                                                              
# DEFINITION:	Refers to walkout or garden level walls
# DATA TYPE:	object
# MISSING VALUES:	58
# UNIQUE VALUES:	
df.bsmt_exposure.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE, MISSING
# VALUES, COLUMN TO BE DROPPED!
# Out:
# array(['No', 'Av', nan, 'Mn', 'Gd'], dtype=object)

# %%
df=df.drop(columns=['bsmt_exposure'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond bsmtfin_type_1  bsmtfin_sf_1  \
# 1           0           4          2            Unf             0
# 2           0           0          2            Unf             0
# 3           1           1          1            GLQ           554
# 4           1           0          2            Unf             0
# 5           0           0          2            BLQ           609
#
#   bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc  \
# 1            Unf             0         1020           1020    GasA         Gd
# 2            Unf             0         1967           1967    GasA         TA
# 3            Unf             0          100            654    GasA         Ex
# 4            Unf             0          968            968    GasA         TA
# 5            Unf             0          785           1394    GasA         Gd
#
#   central_air electrical  first_flr_sf  second_flr_sf  low_qual_fin_sf  \
# 1           N      FuseP           908           1020                0
# 2           Y      SBrkr          1967              0                0
# 3           Y      SBrkr           664            832                0
# 4           Y      SBrkr           968              0                0
# 5           Y      SBrkr          1394              0                0
#
#    gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  \
# 1         1928               0               0          2          0
# 2         1967               0               0          2          0
# 3         1496               1               0          2          1
# 4          968               0               0          1          0
# 5         1394               1               0          1          1
#
#    bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd functional  \
# 1              4              2           Fa              9        Typ
# 2              6              2           TA             10        Typ
# 3              3              1           Gd              7        Typ
# 4              2              1           TA              5        Typ
# 5              3              1           TA              6        Typ
#
#    fireplaces fireplace_qu garage_type  garage_yr_blt garage_finish  \
# 1           0          NaN      Detchd         1910.0           Unf
# 2           0          NaN      Attchd         1977.0           Fin
# 3           1           Gd      Attchd         2006.0           RFn
# 4           0          NaN      Detchd         1935.0           Unf
# 5           2           Gd      Attchd         1963.0           RFn
#
#    garage_cars  garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 1            1          440          Po          Po           Y             0
# 2            2          580          TA          TA           Y           170
# 3            2          426          TA          TA           Y           100
# 4            2          480          Fa          TA           N             0
# 5            2          514          TA          TA           Y             0
#
#    open_porch_sf  enclosed_porch  threessn_porch  screen_porch  pool_area  \
# 1             60             112               0             0          0
# 2              0               0               0             0          0
# 3             24               0               0             0          0
# 4              0             184               0             0          0
# 5             76               0               0           185          0
#
#   pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1     NaN   NaN          NaN         0        4     2006       WD
# 2     NaN   NaN          NaN         0        8     2006       WD
# 3     NaN   NaN          NaN         0        9     2006       New
# 4     NaN   NaN          NaN         0        7     2007       WD
# 5     NaN   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		bsmtfin_type_1                                                                                                   
# DEFINITION:	Rating of basement finished areawalls
# DATA TYPE:	object
# MISSING VALUES:	55
# UNIQUE VALUES:	
df.bsmtfin_type_1.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE, MISSING
# VALUES, COLUMN TO BE DROPPED!
# Out:
# array(['Unf', 'GLQ', 'BLQ', 'Rec', 'ALQ', nan, 'LwQ'], dtype=object)

# %%
df=df.drop(columns=['bsmtfin_type_1'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  bsmtfin_sf_1 bsmtfin_type_2  \
# 1           0           4          2             0            Unf
# 2           0           0          2             0            Unf
# 3           1           1          1           554            Unf
# 4           1           0          2             0            Unf
# 5           0           0          2           609            Unf
#
#    bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air  \
# 1             0         1020           1020    GasA         Gd           N
# 2             0         1967           1967    GasA         TA           Y
# 3             0          100            654    GasA         Ex           Y
# 4             0          968            968    GasA         TA           Y
# 5             0          785           1394    GasA         Gd           Y
#
#   electrical  first_flr_sf  second_flr_sf  low_qual_fin_sf  gr_liv_area  \
# 1      FuseP           908           1020                0         1928
# 2      SBrkr          1967              0                0         1967
# 3      SBrkr           664            832                0         1496
# 4      SBrkr           968              0                0          968
# 5      SBrkr          1394              0                0         1394
#
#    bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  \
# 1               0               0          2          0              4
# 2               0               0          2          0              6
# 3               1               0          2          1              3
# 4               0               0          1          0              2
# 5               1               0          1          1              3
#
#    kitchen_abvgr kitchen_qual  totrms_abvgrd functional  fireplaces  \
# 1              2           Fa              9        Typ           0
# 2              2           TA             10        Typ           0
# 3              1           Gd              7        Typ           1
# 4              1           TA              5        Typ           0
# 5              1           TA              6        Typ           2
#
#   fireplace_qu garage_type  garage_yr_blt garage_finish  garage_cars  \
# 1          NaN      Detchd         1910.0           Unf            1
# 2          NaN      Attchd         1977.0           Fin            2
# 3           Gd      Attchd         2006.0           RFn            2
# 4          NaN      Detchd         1935.0           Unf            2
# 5           Gd      Attchd         1963.0           RFn            2
#
#    garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 1          440          Po          Po           Y             0
# 2          580          TA          TA           Y           170
# 3          426          TA          TA           Y           100
# 4          480          Fa          TA           N             0
# 5          514          TA          TA           Y             0
#
#    open_porch_sf  enclosed_porch  threessn_porch  screen_porch  pool_area  \
# 1             60             112               0             0          0
# 2              0               0               0             0          0
# 3             24               0               0             0          0
# 4              0             184               0             0          0
# 5             76               0               0           185          0
#
#   pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1     NaN   NaN          NaN         0        4     2006       WD
# 2     NaN   NaN          NaN         0        8     2006       WD
# 3     NaN   NaN          NaN         0        9     2006       New
# 4     NaN   NaN          NaN         0        7     2007       WD
# 5     NaN   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		bsmtfin_sf_1                                                                                                        
# DEFINITION:	Type 1 finished square feet
# DATA TYPE:	float64
# MISSING VALUES:	1
# UNIQUE VALUES:	
df.bsmtfin_sf_1.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE, MISSING
# VALUES, COLUMN TO BE DROPPED!
# Out:
# array([   0,  554,  609,  294,  196,  641,  278,  820,  590,  257,  913,
#         216,  188,  660,  165,  938,  390,  763,  144,  322,  152, 1084,
#          24,  284,  405,  650,  949,  486,  248,  824,  324,  220,  439,
#         329,  457,  636,  735, 1660, 1300,  190,  583,  387,  236,  614,
#        1030,  544,  697, 1230,  540,  500,  528, 2260,  701, 1383,  308,
#         316,  173,  462,  480,  962,  120,  588,  767,  306,  870,  472,
#         643, 1252,  658, 2257,  777,  518,  687,  704,  844, 1443, 1387,
#        1104,  602, 1572, 1191,  182, 1249,  360,   68,  502,  828,  267,
#         944,  550,  426,  866,  596,  982,   49,  378,  121,  491,  769,
#         902,  873,   48,  994,  352, 2288,   33,  814,   16,  788, 2096,
#         746,  612,  600,  483,  252,  739,  552,  125,  204,  652,  474,
#         194,  915,  210,  489,  773,  729,  646,  271,  456,   70,  871,
#         442,  224, 1236, 1141,  397,  810,  749,  574,  450, 1056,  400,
#         238,  793, 1035,  150, 1036,  592, 1360, 1721,  256,  564,  734,
#        1573,  388,  584, 1005,  347, 1410,  192,  372,  356,  922,  513,
#         624,  547, 1046,  726,  847,  659,  680,  812,  156,  212,  375,
#         595,  503,  309,  988,  816, 1029,  484,  800,  560,  203,  288,
#        1152,  712,  760,  616, 1096, 1445, 1646,  656,  185,  241,  218,
#         958,  860,  354,  504, 1009,  336,  728, 1112,  505, 1129,  340,
#         724,  779,  169,  317, 1220,  799,  445,  403,  811, 1159, 1283,
#        1182,  187,   80, 1373,  904, 1142,  642,  262,  664,  406,  593,
#         300, 1126,  455,  714,  685,  427,  864,  666,  520,  736,  546,
#         852,  168,  370, 1079,  854, 1216,  524,  353, 1436,  960,  706,
#        1059,  490,  404,  402,  695,  850, 1324,  719,  671,  454, 1294,
#         733,  225, 1111,  908,  789,   77,  471,  846,  512, 1455,  197,
#         623,  747,   20,  700,  339,  493,   28,  553,  414,  428,  892,
#         662,  890,  374,  859,  998, 1026,  562,  399, 1576,  297,  280,
#         260, 1073, 1304,  536,  755,  435,  509,  421,  970,  975,  148,
#        1012,  351,  249,  116,  283,  412,  334,  559,  114,  332,  299,
#         119,   60,  782,   54,  899,  932, 1359,  833,  796,  572, 1260,
#         104, 1151,  663, 1070,  576,  804,   36,  832, 1150, 1308,  315,
#         920,  250,  180, 1965,  460,  466,  632, 1022,  672, 1414,  973,
#         604,  459,  415,  338,  633, 1000,  605,  301,  795, 1420,  670,
#         281, 1224, 1464,  601,  175,  337,  320,  292, 1181,  346, 1138,
#        1416,  154, 1274, 1082,  781,  880, 1024,  468, 1732, 1065,  539,
#         110,  771,  996,   75,  965,  649,  831,  946,  231,  655,  585,
#         822,  122,  936, 1127,  732,  381,  383,  176,  310, 1460,  276,
#         311, 1812,  611, 1186, 1350,  709,  862,   40,  865,  498,  371,
#         420,  384, 1064,  366, 1351, 1053,  885,  986, 1258,  766,  881,
#         577, 1334,  758,  343,   73,  379,  521,  856,  380,  438, 1500,
#         876,  784,  331,  853, 1836,  698,  565,   53, 1422,  408,  523,
#         567,  910,  912,  251,  943,  341,  515,  625,  765, 1094,  931,
#         575])

# %%
df=df.drop(columns=['bsmtfin_sf_1'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond bsmtfin_type_2  bsmtfin_sf_2  \
# 1           0           4          2            Unf             0
# 2           0           0          2            Unf             0
# 3           1           1          1            Unf             0
# 4           1           0          2            Unf             0
# 5           0           0          2            Unf             0
#
#    bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air electrical  \
# 1         1020           1020    GasA         Gd           N      FuseP
# 2         1967           1967    GasA         TA           Y      SBrkr
# 3          100            654    GasA         Ex           Y      SBrkr
# 4          968            968    GasA         TA           Y      SBrkr
# 5          785           1394    GasA         Gd           Y      SBrkr
#
#    first_flr_sf  second_flr_sf  low_qual_fin_sf  gr_liv_area  bsmt_full_bath  \
# 1           908           1020                0         1928               0
# 2          1967              0                0         1967               0
# 3           664            832                0         1496               1
# 4           968              0                0          968               0
# 5          1394              0                0         1394               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#   kitchen_qual  totrms_abvgrd functional  fireplaces fireplace_qu garage_type  \
# 1           Fa              9        Typ           0          NaN      Detchd
# 2           TA             10        Typ           0          NaN      Attchd
# 3           Gd              7        Typ           1           Gd      Attchd
# 4           TA              5        Typ           0          NaN      Detchd
# 5           TA              6        Typ           2           Gd      Attchd
#
#    garage_yr_blt garage_finish  garage_cars  garage_area garage_qual  \
# 1         1910.0           Unf            1          440          Po
# 2         1977.0           Fin            2          580          TA
# 3         2006.0           RFn            2          426          TA
# 4         1935.0           Unf            2          480          Fa
# 5         1963.0           RFn            2          514          TA
#
#   garage_cond paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  \
# 1          Po           Y             0             60             112
# 2          TA           Y           170              0               0
# 3          TA           Y           100             24               0
# 4          TA           N             0              0             184
# 5          TA           Y             0             76               0
#
#    threessn_porch  screen_porch  pool_area pool_qc fence misc_feature  \
# 1               0             0          0     NaN   NaN          NaN
# 2               0             0          0     NaN   NaN          NaN
# 3               0             0          0     NaN   NaN          NaN
# 4               0             0          0     NaN   NaN          NaN
# 5               0           185          0     NaN   NaN          NaN
#
#    misc_val  mo_sold  yr_sold sale_type
# 1         0        4     2006       WD
# 2         0        8     2006       WD
# 3         0        9     2006       New
# 4         0        7     2007       WD
# 5         0        7     2009       WD

# %%
# COLUMN:		bsmtfin_type_2                                                                                                             
# DEFINITION:	Rating of basement finished area (if multiple types)
# DATA TYPE:	object
# MISSING VALUES:	56
# UNIQUE VALUES:	
df.bsmtfin_type_2.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE, MISSING
# VALUES, COLUMN TO BE DROPPED!
# Out:
# array(['Unf', 'LwQ', nan, 'ALQ', 'GLQ', 'Rec', 'BLQ'], dtype=object)

# %%
df=df.drop(columns=['bsmtfin_type_2'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  bsmtfin_sf_2  bsmt_unf_sf  \
# 1           0           4          2             0         1020
# 2           0           0          2             0         1967
# 3           1           1          1             0          100
# 4           1           0          2             0          968
# 5           0           0          2             0          785
#
#    total_bsmt_sf heating heating_qc central_air electrical  first_flr_sf  \
# 1           1020    GasA         Gd           N      FuseP           908
# 2           1967    GasA         TA           Y      SBrkr          1967
# 3            654    GasA         Ex           Y      SBrkr           664
# 4            968    GasA         TA           Y      SBrkr           968
# 5           1394    GasA         Gd           Y      SBrkr          1394
#
#    second_flr_sf  low_qual_fin_sf  gr_liv_area  bsmt_full_bath  \
# 1           1020                0         1928               0
# 2              0                0         1967               0
# 3            832                0         1496               1
# 4              0                0          968               0
# 5              0                0         1394               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#   kitchen_qual  totrms_abvgrd functional  fireplaces fireplace_qu garage_type  \
# 1           Fa              9        Typ           0          NaN      Detchd
# 2           TA             10        Typ           0          NaN      Attchd
# 3           Gd              7        Typ           1           Gd      Attchd
# 4           TA              5        Typ           0          NaN      Detchd
# 5           TA              6        Typ           2           Gd      Attchd
#
#    garage_yr_blt garage_finish  garage_cars  garage_area garage_qual  \
# 1         1910.0           Unf            1          440          Po
# 2         1977.0           Fin            2          580          TA
# 3         2006.0           RFn            2          426          TA
# 4         1935.0           Unf            2          480          Fa
# 5         1963.0           RFn            2          514          TA
#
#   garage_cond paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  \
# 1          Po           Y             0             60             112
# 2          TA           Y           170              0               0
# 3          TA           Y           100             24               0
# 4          TA           N             0              0             184
# 5          TA           Y             0             76               0
#
#    threessn_porch  screen_porch  pool_area pool_qc fence misc_feature  \
# 1               0             0          0     NaN   NaN          NaN
# 2               0             0          0     NaN   NaN          NaN
# 3               0             0          0     NaN   NaN          NaN
# 4               0             0          0     NaN   NaN          NaN
# 5               0           185          0     NaN   NaN          NaN
#
#    misc_val  mo_sold  yr_sold sale_type
# 1         0        4     2006       WD
# 2         0        8     2006       WD
# 3         0        9     2006       New
# 4         0        7     2007       WD
# 5         0        7     2009       WD

# %%
# COLUMN:		bsmtfin_sf_2                                                                                                                   
# DEFINITION:	Type 2 finished square feet
# DATA TYPE:	float64
# MISSING VALUES:	1
# UNIQUE VALUES:	
df.bsmtfin_sf_2.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE, MISSING
# VALUES, COLUMN TO BE DROPPED!
# Out:
# array([   0,  279,  668,  841,  180,  240,  472,  374,  873, 1526, 1020,
#         337,  210,  136,   46,  453,  252, 1029,  634,  468, 1164, 1031,
#         884,  606,  820,  826,   63,  480,  184,  336,  391,  147,  398,
#         182,  250,  165,  627,  393,  723,  449,  319,  682,  912,  530,
#         276,  831,  121,   93,  288,  287,   48,   32,  193,  684,  456,
#         904,  764,  755,  544,  402,  491,  691,  243,   40,  344,  543,
#          42,  712,   78,  352,  350,  438,  690,  679,  216,  362,  694,
#         435,  972,  144,  360,  791,  448,  264,  168,  981,  176,  174,
#         396,  799,  400,  630,  139,  512,  153,  492])

# %%
df=df.drop(columns=['bsmtfin_sf_2'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  bsmt_unf_sf  total_bsmt_sf heating  \
# 1           0           4          2         1020           1020    GasA
# 2           0           0          2         1967           1967    GasA
# 3           1           1          1          100            654    GasA
# 4           1           0          2          968            968    GasA
# 5           0           0          2          785           1394    GasA
#
#   heating_qc central_air electrical  first_flr_sf  second_flr_sf  \
# 1         Gd           N      FuseP           908           1020
# 2         TA           Y      SBrkr          1967              0
# 3         Ex           Y      SBrkr           664            832
# 4         TA           Y      SBrkr           968              0
# 5         Gd           Y      SBrkr          1394              0
#
#    low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1                0         1928               0               0          2
# 2                0         1967               0               0          2
# 3                0         1496               1               0          2
# 4                0          968               0               0          1
# 5                0         1394               1               0          1
#
#    half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1          0              4              2           Fa              9
# 2          0              6              2           TA             10
# 3          1              3              1           Gd              7
# 4          0              2              1           TA              5
# 5          1              3              1           TA              6
#
#   functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 1        Typ           0          NaN      Detchd         1910.0
# 2        Typ           0          NaN      Attchd         1977.0
# 3        Typ           1           Gd      Attchd         2006.0
# 4        Typ           0          NaN      Detchd         1935.0
# 5        Typ           2           Gd      Attchd         1963.0
#
#   garage_finish  garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 1           Unf            1          440          Po          Po           Y
# 2           Fin            2          580          TA          TA           Y
# 3           RFn            2          426          TA          TA           Y
# 4           Unf            2          480          Fa          TA           N
# 5           RFn            2          514          TA          TA           Y
#
#    wood_deck_sf  open_porch_sf  enclosed_porch  threessn_porch  screen_porch  \
# 1             0             60             112               0             0
# 2           170              0               0               0             0
# 3           100             24               0               0             0
# 4             0              0             184               0             0
# 5             0             76               0               0           185
#
#    pool_area pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1          0     NaN   NaN          NaN         0        4     2006       WD
# 2          0     NaN   NaN          NaN         0        8     2006       WD
# 3          0     NaN   NaN          NaN         0        9     2006       New
# 4          0     NaN   NaN          NaN         0        7     2007       WD
# 5          0     NaN   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		bsmt_unf_sf                                                                                                                         
# DEFINITION:	Unfinished square feet of basement area
# DATA TYPE:	float64
# MISSING VALUES:	1
# UNIQUE VALUES:	
df.bsmt_unf_sf.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE, MISSING
# VALUES, COLUMN TO BE DROPPED!
# Out:
# array([1020, 1967,  100,  968,  785,  252,  869, 1072,  840,  276,  939,
#        1040, 1367,  348,  848,    0,  294,  816,  400,  700,  204,  598,
#        1218,  474,  715,  636,  173,  226,  536,  628, 1240,   92, 1468,
#         608,  863,  105, 1339,  612,  930,  658,  178,  552,  546,  434,
#         187,  448,  216,  588,  346, 1615,  803,  248,  115,  697,  193,
#         540,  257,  322,   95,  242,  374,  262,  244,  272,  151,  600,
#         278,  384,  543, 1152,  878,  397, 1459,  321,  371,  166,  154,
#        2042,  396,  270, 1686,  744,  411,  560,  827,  461,  422,  639,
#        1530,  355,  167,  306,  998,  218,  467,  357,  179,  491, 1921,
#        1128,  590, 1058, 1140,   39,  360,  630,  616,  324,  394, 1085,
#         523,  795,  165,  504,  365,  497,  513,  136,  194,  850, 1369,
#        1114,  436,  220,  756, 1632,  960, 1048,  311,  592, 1619,  860,
#         901,  768,  196,   63, 1055,  484,  416,  108,  342, 1451,  300,
#        1129,  172, 1421,  712,  312,  691, 1466,  503,  894,  280,   36,
#         738, 1064,  356,  130,  634,   28,  638,   30,  375,  783,  533,
#        1629, 1226,  456,  406,  483,  297, 1346,   52,  459,  725,   80,
#         439,  229,  651,   46,  466,  241,  380,  684,  618,  720,  982,
#         480, 1264,  545,  661,  224,  140,   99,  844, 1352, 1079, 1028,
#        1181, 1150, 2002, 1643,  318,  160, 1869,  544,  912,  387,  381,
#         576,  438,  605,  585,  192,  316,  594,  868,  780,  392,  227,
#         288,  168,  770,  596,  138,  329,  189,  289,  124,  893,  516,
#         762,  378,  449,  174,  784,  405,  728,  200,  254,  403,  495,
#        1084,  420,  897,  672,  718,  103, 1286,  408,  722,  482, 1052,
#         284, 1008,  975,  524,  808, 1544,  117,  132, 1126,  704, 1866,
#         332,  708,   44,  451,  441,  624,  925,  746,   48,  801,  457,
#         299,  261,  821,   64,  285,  851,  440,  710,  741,  871,  412,
#         793,  238,  689, 1584, 1234,  413,  906, 1248,  764,  358, 1652,
#         221,  410,  104,  632, 1108,  273,  197,  290,  595,  225,  650,
#         455, 1330,   88,  469,  731, 1709,  409,  188,  120,  458,  512,
#         739,  398,  141,  935,  666,  554, 1541,  570,  266,  150,   98,
#         567,  572,  625,  846, 1158, 1368,  304,  530, 1392,  519,  113,
#         723,  577,  660,  952,  471,  119,   90,  210,  148,  989,  999,
#         847,  649, 1257, 1594,  107, 1568,  525, 1288,  964,   77,  277,
#         537,  186,  183,  487,  994, 1498, 1100,  177, 1375,  884,   29,
#         615,  742,   56,  899,  260,  556,  264, 1088,  363,  407,  510,
#         569, 1622,  927,  686,  176,  702,  698, 1198,  472, 1337,  506,
#         864,  121,  386,  133, 1173, 1417,  498,  648,  251,  137, 1726,
#         832, 1344,  301,  437,  555,  602,  404,  892,  641, 1640,  240,
#         599,  479,  659,  578,  966,  944,  201,   84,  286, 1176,  110,
#         453, 1316,  170,  134,  508,  676, 1065,  243, 1131,  657,  804,
#         970, 1444,   54, 1571, 1284,  841,  237,  418,  993,   14,  325,
#         339,  223,  427, 1105, 1439,  430, 1308,  470, 1376,  158,  849,
#         575,  476,  212,  817,  778,  941, 1550,  494,  792,  256, 1012,
#         372,  644,  315, 1045,  490, 1005, 1588,  736,   60,  230,   72,
#         907,  245,  161,  929, 1053,  390,  399,  856,  564,  938, 1618,
#         364,  936, 1068,  833,  370,  825,   93,  350, 1696,  563,  431,
#         740,  123, 1300,  135,  291, 1046,  460,  611,  255, 1424,  340,
#        1625,  796,  336, 1390,  319,   83,  195,  668,   40,  656, 1502,
#          22, 1035,  279,  949,  265,  169,  313,  234,  228, 1372,   91,
#         345,  535, 1328,  534,  818,  462, 1318,  591,   74,   96,  385,
#          78,  338,  450, 1163, 1077,  208,  622, 1491,  180, 1216,  812,
#        2046,  529])

# %%
df=df.drop(columns=['bsmt_unf_sf'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  total_bsmt_sf heating heating_qc  \
# 1           0           4          2           1020    GasA         Gd
# 2           0           0          2           1967    GasA         TA
# 3           1           1          1            654    GasA         Ex
# 4           1           0          2            968    GasA         TA
# 5           0           0          2           1394    GasA         Gd
#
#   central_air electrical  first_flr_sf  second_flr_sf  low_qual_fin_sf  \
# 1           N      FuseP           908           1020                0
# 2           Y      SBrkr          1967              0                0
# 3           Y      SBrkr           664            832                0
# 4           Y      SBrkr           968              0                0
# 5           Y      SBrkr          1394              0                0
#
#    gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  \
# 1         1928               0               0          2          0
# 2         1967               0               0          2          0
# 3         1496               1               0          2          1
# 4          968               0               0          1          0
# 5         1394               1               0          1          1
#
#    bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd functional  \
# 1              4              2           Fa              9        Typ
# 2              6              2           TA             10        Typ
# 3              3              1           Gd              7        Typ
# 4              2              1           TA              5        Typ
# 5              3              1           TA              6        Typ
#
#    fireplaces fireplace_qu garage_type  garage_yr_blt garage_finish  \
# 1           0          NaN      Detchd         1910.0           Unf
# 2           0          NaN      Attchd         1977.0           Fin
# 3           1           Gd      Attchd         2006.0           RFn
# 4           0          NaN      Detchd         1935.0           Unf
# 5           2           Gd      Attchd         1963.0           RFn
#
#    garage_cars  garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 1            1          440          Po          Po           Y             0
# 2            2          580          TA          TA           Y           170
# 3            2          426          TA          TA           Y           100
# 4            2          480          Fa          TA           N             0
# 5            2          514          TA          TA           Y             0
#
#    open_porch_sf  enclosed_porch  threessn_porch  screen_porch  pool_area  \
# 1             60             112               0             0          0
# 2              0               0               0             0          0
# 3             24               0               0             0          0
# 4              0             184               0             0          0
# 5             76               0               0           185          0
#
#   pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1     NaN   NaN          NaN         0        4     2006       WD
# 2     NaN   NaN          NaN         0        8     2006       WD
# 3     NaN   NaN          NaN         0        9     2006       New
# 4     NaN   NaN          NaN         0        7     2007       WD
# 5     NaN   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		total_bsmt_sf                                                                                                                             
# DEFINITION:	Total square feet of basement areaarea
# DATA TYPE:	float64
# MISSING VALUES:	1
# UNIQUE VALUES:	
df.total_bsmt_sf.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE, MISSING
# VALUES, COLUMN TO BE DROPPED!
# Out:
# array([1020, 1967,  654,  968, 1394,  546,  869, 1268,  840, 1196, 1217,
#        1040, 1367, 1168,  848,    0,  884, 1073, 1313,  916, 1060,  864,
#        1604,  938, 1218,  715,  636,  936,  370,  858,  780, 1240, 1176,
#        1492,  608, 1147,  105, 1339,  612,  930, 1063, 1008, 1501,  920,
#         828,  912,  346, 1615,  803,  468, 1026, 1024,  992, 1982, 1300,
#        1158,  825,  761, 2024, 1302,  544,  600, 1508, 1560,  384, 1043,
#        1680, 3138, 1135, 1780, 1459,  629,  687,  676,  616, 2042,  876,
#        1232, 1686,  999,  560,  827, 1228,  728, 1509, 1554,  810, 1694,
#         998, 2535, 1244,  686,  697, 1224, 1921, 1832, 1434, 1058, 1140,
#        1482, 1930,  360,  630, 1720,  926, 1966, 1085, 1714,  794,  795,
#        1414,  565, 1530, 1015,  943,  720, 1080,  744, 1528, 1369, 1114,
#         816, 1161, 1078,  756, 1632,  960, 1048,  689,  592, 1740,  860,
#         988,  901,  768, 1098, 1104, 1055, 1478, 1056, 2630, 1451, 1563,
#        1145, 1445, 2396,  990, 1776,  712,  691, 1949, 1242,  894,  832,
#        1192,  738, 1064,  782, 1108,  980,  945,  783,  888,  955,  533,
#         301, 1629, 1226,  483,  855,  621, 1370,  923,  949, 2136, 1557,
#         836, 1865,  651,  684,  856, 1128,  982, 1273, 1264, 1580,  709,
#        1360,  844, 2077, 1352, 1079, 1284, 1181, 1150, 2002, 1643,  882,
#        1869, 1573,  940, 1392,  576, 1848,  585,  672, 1094,  868, 1314,
#         740, 1248,  547, 1214,  770,  596,  893,  974,  735,  973,  952,
#         784, 1144, 1188, 1070, 1432,  979, 1884, 1100, 1006, 1499, 1286,
#        1152, 1338, 1578, 1052, 1856, 1664,  975,  861, 1544,  958, 1142,
#         976,  704, 1866,  928, 1235,  451,  793,  624,  925, 1082, 1160,
#         801,  804, 1390,  821,  788, 1660,  967,  710,  741, 1431, 1107,
#         806, 1396, 1584, 1234, 1572, 1430, 1162,  764, 1540,  814, 1732,
#        1594, 1049, 1774,  915, 1182,  954,  798,  525, 1726,  650,  910,
#        1330,  802,  559, 1782,  731, 1709, 1075, 1027,  941,  907, 1220,
#        1225, 1216, 1134, 1288,  666,  554, 1541, 2006,  852, 1626, 1062,
#         845,  846, 1368,  708,  530,  996, 1208, 1437,  723,  765, 1379,
#        1702, 1358,  972, 1417,  908,  561,  660, 2444,  847, 1449, 1257,
#        1614,  707,  700, 1568, 1316,  964,  965, 1136, 1211,  994, 1498,
#        1175, 1375, 1212, 1014,  742,  392,  835, 1199, 1836,  853,  264,
#        1088,  407, 1292,  569, 1622,  927, 1415, 1934, 1036,  702,  416,
#         698, 1103, 1222, 1022, 1337, 1010,  807, 1582, 1173, 1013, 1038,
#         648,  950,  625, 1200, 1141, 1069, 1344,  870, 1395, 1258,  671,
#         440,  892, 1700, 1130, 1261, 1109, 1838,  240,  796,  883,  752,
#         572, 1790,  966,  944, 1356, 1466, 1418, 1340, 1090,  890, 1065,
#        2208, 1131, 1032,  970, 1444, 1620, 1468, 1571,  641,  696,  841,
#         833,  993, 1054,  663, 1223, 1362, 1105, 1850, 1308, 2000, 1363,
#        1376, 1086,  817, 1779, 1124, 1574, 1408, 1910, 1112,  792, 1012,
#        1453, 1153, 1524, 1657, 1132, 2110, 1029, 1005, 1698, 1553,  736,
#        1096, 1210,  929, 1436, 1053,  985, 1441, 1386, 1618,  570, 1068,
#        1617,  904, 1059, 1206, 1494,  680,  878,  818, 1868, 1696, 1127,
#        2552,  356,  734, 1324,  902, 1051, 1477, 1728, 1169, 1117, 1205,
#        1625, 1296,  747, 1383,  516, 1654, 1298, 1231, 1422, 1057, 1004,
#        1502,  984, 1035,  644, 1290, 1350, 1372, 1310, 1388, 1156, 2036,
#        1118, 1822, 1342, 1091, 1814,  971, 1165, 1332,  635, 1295, 1947,
#         900,  995, 1204, 1163, 1896, 1491, 1190, 1624, 2046, 1084])

# %%
df=df.drop(columns=['total_bsmt_sf'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond heating heating_qc central_air  \
# 1           0           4          2    GasA         Gd           N
# 2           0           0          2    GasA         TA           Y
# 3           1           1          1    GasA         Ex           Y
# 4           1           0          2    GasA         TA           Y
# 5           0           0          2    GasA         Gd           Y
#
#   electrical  first_flr_sf  second_flr_sf  low_qual_fin_sf  gr_liv_area  \
# 1      FuseP           908           1020                0         1928
# 2      SBrkr          1967              0                0         1967
# 3      SBrkr           664            832                0         1496
# 4      SBrkr           968              0                0          968
# 5      SBrkr          1394              0                0         1394
#
#    bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  \
# 1               0               0          2          0              4
# 2               0               0          2          0              6
# 3               1               0          2          1              3
# 4               0               0          1          0              2
# 5               1               0          1          1              3
#
#    kitchen_abvgr kitchen_qual  totrms_abvgrd functional  fireplaces  \
# 1              2           Fa              9        Typ           0
# 2              2           TA             10        Typ           0
# 3              1           Gd              7        Typ           1
# 4              1           TA              5        Typ           0
# 5              1           TA              6        Typ           2
#
#   fireplace_qu garage_type  garage_yr_blt garage_finish  garage_cars  \
# 1          NaN      Detchd         1910.0           Unf            1
# 2          NaN      Attchd         1977.0           Fin            2
# 3           Gd      Attchd         2006.0           RFn            2
# 4          NaN      Detchd         1935.0           Unf            2
# 5           Gd      Attchd         1963.0           RFn            2
#
#    garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 1          440          Po          Po           Y             0
# 2          580          TA          TA           Y           170
# 3          426          TA          TA           Y           100
# 4          480          Fa          TA           N             0
# 5          514          TA          TA           Y             0
#
#    open_porch_sf  enclosed_porch  threessn_porch  screen_porch  pool_area  \
# 1             60             112               0             0          0
# 2              0               0               0             0          0
# 3             24               0               0             0          0
# 4              0             184               0             0          0
# 5             76               0               0           185          0
#
#   pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1     NaN   NaN          NaN         0        4     2006       WD
# 2     NaN   NaN          NaN         0        8     2006       WD
# 3     NaN   NaN          NaN         0        9     2006       New
# 4     NaN   NaN          NaN         0        7     2007       WD
# 5     NaN   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		heating                                                                                                                                         
# DEFINITION:	Type of heating
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.heating.unique()
# COLUMN NEEDS TO BE CONVERTED TO INTERGER, NO
# MISSING VALUES!
# Out:
# array(['GasA', 'GasW', 'Grav', 'Floor'], dtype=object)

# %% [markdown]
# - COLUMN HAS DIFFERENT VALUES THAN TEST.CSV

# %%
df = df.drop(columns=['heating'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond heating_qc central_air electrical  \
# 1           0           4          2         Gd           N      FuseP
# 2           0           0          2         TA           Y      SBrkr
# 3           1           1          1         Ex           Y      SBrkr
# 4           1           0          2         TA           Y      SBrkr
# 5           0           0          2         Gd           Y      SBrkr
#
#    first_flr_sf  second_flr_sf  low_qual_fin_sf  gr_liv_area  bsmt_full_bath  \
# 1           908           1020                0         1928               0
# 2          1967              0                0         1967               0
# 3           664            832                0         1496               1
# 4           968              0                0          968               0
# 5          1394              0                0         1394               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#   kitchen_qual  totrms_abvgrd functional  fireplaces fireplace_qu garage_type  \
# 1           Fa              9        Typ           0          NaN      Detchd
# 2           TA             10        Typ           0          NaN      Attchd
# 3           Gd              7        Typ           1           Gd      Attchd
# 4           TA              5        Typ           0          NaN      Detchd
# 5           TA              6        Typ           2           Gd      Attchd
#
#    garage_yr_blt garage_finish  garage_cars  garage_area garage_qual  \
# 1         1910.0           Unf            1          440          Po
# 2         1977.0           Fin            2          580          TA
# 3         2006.0           RFn            2          426          TA
# 4         1935.0           Unf            2          480          Fa
# 5         1963.0           RFn            2          514          TA
#
#   garage_cond paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  \
# 1          Po           Y             0             60             112
# 2          TA           Y           170              0               0
# 3          TA           Y           100             24               0
# 4          TA           N             0              0             184
# 5          TA           Y             0             76               0
#
#    threessn_porch  screen_porch  pool_area pool_qc fence misc_feature  \
# 1               0             0          0     NaN   NaN          NaN
# 2               0             0          0     NaN   NaN          NaN
# 3               0             0          0     NaN   NaN          NaN
# 4               0             0          0     NaN   NaN          NaN
# 5               0           185          0     NaN   NaN          NaN
#
#    misc_val  mo_sold  yr_sold sale_type
# 1         0        4     2006       WD
# 2         0        8     2006       WD
# 3         0        9     2006       New
# 4         0        7     2007       WD
# 5         0        7     2009       WD

# %%
# COLUMN:		heating_qc                                                                                                                                                  
# DEFINITION:	Heating quality and condition
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.heating_qc.unique()
# COLUMN NEEDS TO BE CONVERTED TO INTERGER, NO
# MISSING VALUES!
# Out:
# array(['Gd', 'TA', 'Ex', 'Fa'], dtype=object)

# %%
heating_qc = {'Fa':'0', 'TA':'1', 'Gd':'2', 'Ex':'3', 'Po':'4'}
df.heating_qc = [heating_qc[item] for item in df.heating_qc] 
df.heating_qc.unique()
# Out:
# array(['2', '1', '3', '0'], dtype=object)

# %%
df["heating_qc"] = df["heating_qc"].astype(dtype=np.int)
df['heating_qc'].dtype
# Out:
# dtype('int64')

# %%
# COLUMN:		central_air                                                                                                                                                          
# DEFINITION:	Central air conditioning
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.central_air.unique()
# COLUMN NEEDS TO BE CONVERTED TO INTERGER, NO
# MISSING VALUES!
# Out:
# array(['N', 'Y'], dtype=object)

# %%
central_air = {'Y':'0', 'N':'1'}
df.central_air = [central_air[item] for item in df.central_air] 
df.central_air.unique()
# Out:
# array(['1', '0'], dtype=object)

# %%
df["central_air"] = df["central_air"].astype(dtype=np.int)
df['central_air'].dtype
# Out:
# dtype('int64')

# %%
# COLUMN:		electrical                                                                                                                                                                   
# DEFINITION:	Electrical system
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df. electrical.unique()
# Out:
# array(['FuseP', 'SBrkr', 'FuseA', 'FuseF', nan], dtype=object)

# %% [markdown]
# - COLUMN HAS DIFFERENT VALUES THAN TEST.CSV

# %%
df = df.drop(columns=['electrical'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  heating_qc  central_air  first_flr_sf  \
# 1           0           4          2           2            1           908
# 2           0           0          2           1            0          1967
# 3           1           1          1           3            0           664
# 4           1           0          2           1            0           968
# 5           0           0          2           2            0          1394
#
#    second_flr_sf  low_qual_fin_sf  gr_liv_area  bsmt_full_bath  \
# 1           1020                0         1928               0
# 2              0                0         1967               0
# 3            832                0         1496               1
# 4              0                0          968               0
# 5              0                0         1394               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#   kitchen_qual  totrms_abvgrd functional  fireplaces fireplace_qu garage_type  \
# 1           Fa              9        Typ           0          NaN      Detchd
# 2           TA             10        Typ           0          NaN      Attchd
# 3           Gd              7        Typ           1           Gd      Attchd
# 4           TA              5        Typ           0          NaN      Detchd
# 5           TA              6        Typ           2           Gd      Attchd
#
#    garage_yr_blt garage_finish  garage_cars  garage_area garage_qual  \
# 1         1910.0           Unf            1          440          Po
# 2         1977.0           Fin            2          580          TA
# 3         2006.0           RFn            2          426          TA
# 4         1935.0           Unf            2          480          Fa
# 5         1963.0           RFn            2          514          TA
#
#   garage_cond paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  \
# 1          Po           Y             0             60             112
# 2          TA           Y           170              0               0
# 3          TA           Y           100             24               0
# 4          TA           N             0              0             184
# 5          TA           Y             0             76               0
#
#    threessn_porch  screen_porch  pool_area pool_qc fence misc_feature  \
# 1               0             0          0     NaN   NaN          NaN
# 2               0             0          0     NaN   NaN          NaN
# 3               0             0          0     NaN   NaN          NaN
# 4               0             0          0     NaN   NaN          NaN
# 5               0           185          0     NaN   NaN          NaN
#
#    misc_val  mo_sold  yr_sold sale_type
# 1         0        4     2006       WD
# 2         0        8     2006       WD
# 3         0        9     2006       New
# 4         0        7     2007       WD
# 5         0        7     2009       WD

# %%
# COLUMN:		first_flr_sf                                                                                                                                                                                     
# DEFINITION:	First Floor square feet
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.first_flr_sf.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE,
# COLUMN TO BE DROPPED!
# Out:
# array([ 908, 1967,  664,  968, 1394,  546, 1093, 1268,  840, 1279, 1217,
#        1040, 1375, 1168, 1017, 1340,  884, 1073, 1773,  916, 1060,  864,
#        1617,  988, 1218, 1281, 1089, 1054,  442,  858,  848, 1320, 1178,
#        1492,  608, 1147,  998,  910, 1358,  612,  956, 1327, 1363, 1501,
#         798,  920,  965,  936,  912, 1157, 1615,  803,  822, 1026, 1133,
#        1344, 1193,  992, 2006, 1140, 1176,  845,  810, 2063, 1302,  774,
#         747, 1508, 1560,  802, 1050, 1724, 3138, 1771, 1207,  882, 1780,
#        1459,  727,  687,  760,  616, 2042,  876, 1707, 1064,  999,  796,
#         827, 1228,  728,  914, 1509, 1554, 1694, 1790,  923, 2470, 1244,
#         866,  697, 1287, 1921, 1832, 1434, 1058, 1382, 1494, 1831, 1032,
#         630, 1720,  926, 1966, 1120, 1714,  794,  954, 1414, 1008,  565,
#        1530, 1025,  943,  720, 1128,  757, 1225, 1369, 1114,  816, 1381,
#        1078,  756, 1474,  929,  960, 1048,  689,  432, 1740,  860, 1088,
#         900,  792, 1098, 1055, 1493,  768, 1056, 2674, 1456, 1563, 1145,
#        1445, 2411,  990,  520, 1086, 1085,  691, 1949, 1242,  894, 1516,
#         738, 1350,  698,  806, 1160,  980,  944,  832,  945,  838,  783,
#         955, 1021, 1645, 1226,  934,  741,  855,  621, 1370,  947,  949,
#        2036, 1557,  844, 1830,  707,  892,  713,  983,  684,  856,  846,
#        1149,  982, 1273, 1277, 1518, 1360, 1794, 2097, 1352, 1079, 1284,
#        1234, 1164, 2018, 1651, 1007, 1869, 1625, 1192, 1142, 1412, 1848,
#        2279,  744,  672, 1094,  887,  993, 1314, 1006, 1072, 1260,  778,
#        1968, 1432,  901,  974,  709,  869,  979, 1170,  483,  784, 1144,
#         888, 1286,  925, 1437, 1440,  819, 1884, 1619, 1294, 1152, 1024,
#        1278, 1338, 1578, 1052,  862, 1856, 1940, 1682, 1005,  961, 1544,
#         958, 1306,  976, 1866,  851,  928, 1235,  759, 1000, 1082,  788,
#        1676,  801, 1036,  804, 1402,  975,  821,  978, 1660, 1898,  780,
#        1431,  997, 1608,  725, 1776, 1572, 1647, 1163, 1248, 1540,  913,
#        1646, 1049,  964, 1808, 1148,  933, 1643, 1766, 1188,  948,  525,
#        1726, 1330, 1080, 1782,  820, 1717, 1507, 1027,  941,  952, 1131,
#        1539, 1764, 1220, 1276, 1298, 1803, 2422, 1308,  736, 1541, 2020,
#         918, 1668, 1126, 1062,  893, 1158, 1368,  708,  530, 1392, 1014,
#        1214, 1208, 1102, 1473,  723,  765, 1383,  902, 1702, 1022,  972,
#        1417,  927,  561,  660, 2444, 1196,  847, 1290,  752, 1614,  897,
#        1122, 1568, 1012, 1316, 1136, 1211, 1256,  861, 1378, 1498, 1100,
#        1107, 1182, 1212,  742, 1487, 1119, 1199, 1846, 1549,  407, 1580,
#        1292,  854, 1630, 1301,  995, 1067, 1150, 1455, 1943, 1664,  842,
#         599,  836, 1103, 1222, 1337, 1175, 1108, 1582,  903,  808, 1428,
#        1038,  734, 1104,  950,  625, 1200, 1141, 1069,  938,  628, 1570,
#         919, 1258, 1567,  682, 1254, 1700, 1374, 1261, 1155, 1838, 1285,
#        1816,  790, 1500,  789,  585, 1466, 1418,  800, 1090, 1232, 1535,
#         890, 1065, 2522, 1699,  754,  970, 1444, 1620, 1468, 1571,  641,
#         696,  833, 1223, 1105, 1850, 1929, 1224, 2000, 1372, 1376,  940,
#        1779, 1610, 1574,  930, 1679, 1112, 1453, 1177, 1132,  896, 2362,
#        2110, 1698, 1553, 1216, 1096, 1307, 1238, 1661, 2039, 1436, 1053,
#         985, 1411, 1043, 1618,  761,  962, 1068, 1004, 1797,  904,  735,
#        1206, 1526,  680, 2071, 1403,  818, 2028, 1696, 2552,  671, 1324,
#        1044, 1839, 1960, 1190, 1482, 1127, 1472, 1728, 2117,  932, 1296,
#        1390,  596,  516, 1173, 1654, 1251, 1675, 1295, 1020, 1502, 1604,
#        1339,  984,  942, 1015, 1305, 1906, 1047, 1388, 1827, 1084, 1187,
#        1118, 1828, 1342, 1091, 1826, 1154,  971, 1051, 1165,  764, 1332,
#         646, 2207, 1282, 1204, 1478, 1944,  767, 1313, 1229, 1491, 2046])

# %%
df = df.drop(columns=['first_flr_sf'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  heating_qc  central_air  second_flr_sf  \
# 1           0           4          2           2            1           1020
# 2           0           0          2           1            0              0
# 3           1           1          1           3            0            832
# 4           1           0          2           1            0              0
# 5           0           0          2           2            0              0
#
#    low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1                0         1928               0               0          2
# 2                0         1967               0               0          2
# 3                0         1496               1               0          2
# 4                0          968               0               0          1
# 5                0         1394               1               0          1
#
#    half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1          0              4              2           Fa              9
# 2          0              6              2           TA             10
# 3          1              3              1           Gd              7
# 4          0              2              1           TA              5
# 5          1              3              1           TA              6
#
#   functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 1        Typ           0          NaN      Detchd         1910.0
# 2        Typ           0          NaN      Attchd         1977.0
# 3        Typ           1           Gd      Attchd         2006.0
# 4        Typ           0          NaN      Detchd         1935.0
# 5        Typ           2           Gd      Attchd         1963.0
#
#   garage_finish  garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 1           Unf            1          440          Po          Po           Y
# 2           Fin            2          580          TA          TA           Y
# 3           RFn            2          426          TA          TA           Y
# 4           Unf            2          480          Fa          TA           N
# 5           RFn            2          514          TA          TA           Y
#
#    wood_deck_sf  open_porch_sf  enclosed_porch  threessn_porch  screen_porch  \
# 1             0             60             112               0             0
# 2           170              0               0               0             0
# 3           100             24               0               0             0
# 4             0              0             184               0             0
# 5             0             76               0               0           185
#
#    pool_area pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1          0     NaN   NaN          NaN         0        4     2006       WD
# 2          0     NaN   NaN          NaN         0        8     2006       WD
# 3          0     NaN   NaN          NaN         0        9     2006       New
# 4          0     NaN   NaN          NaN         0        7     2007       WD
# 5          0     NaN   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		second_flr_sf              
# DEFINITION:	Second floor square feet
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.second_flr_sf .unique()
# COLUMN DOES NOT PERTAIN TO HOUSING PRICE,
# COLUMN TO BE DROPPED!
# Out:
# array([1020,    0,  832,  546,  840, 1619,  810,  552,  826,  457,  661,
#         228, 1320,  850,  510,  612,  930,  866,  336, 1111,  557,  320,
#         687,  873,  825,  793, 1012,  670, 1538,  380,  671,  676, 1072,
#         550,  424,  728,  855,  804,  604,  816, 1796,  780,  672,  678,
#         795,  917,  651,  695,  720,  792,  908,  713,  208, 1000,  703,
#         432,  860,  638,  110, 1215, 1208, 1358, 2065,  623,  809,  649,
#         772,  880,  754,  560,  683,  701,  919,  473,  580,  830,  878,
#         686,  601,  648, 1039,  767,  933,  343,  893,  682,  739,  813,
#         876, 1141,  995, 1067, 1360,  807,  978, 1140, 1150,  403, 1182,
#         434,  348,  800,  630,  768, 1134,  769, 1031,  798,  764, 1479,
#         900,  308,  349,  871, 1175,  504,  368,  812,  967,  784,  979,
#         167, 1037, 1321, 1788, 1286,  224,  240,  406,  665,  976,  704,
#         858,  992,  901,  544,  646,  823,  955,  702,  886,  714, 1080,
#         741,  520,  620,  499,  942, 1296, 1315,  514,  925, 1402,  975,
#         375,  567,  611,  709,  523,  744,  888,  846,  564,  870, 1336,
#         551, 1216, 1778,  554,  854,  748,  218, 1218,  708,  730,  330,
#         363, 1015,  918,  752,  797,  839,  988,  668,  688, 1872, 1112,
#         815, 1121, 1243,  862, 1254,  994, 1164,  983, 1142,  180,  464,
#         742, 1178,  558,  600,  588, 1116,  472, 1048,  595,  943, 1332,
#         989,  378, 1017,  966,  384,  697,  625, 1087,  548,  182,  512,
#         496,  517,  782,  656,  412,  926,  436,  468, 1362,  501, 1124,
#         738, 1075,  640,  756,  581,  885,  783,  821, 1081,  972,  904,
#         717,  898,  568,  532,  960, 1629,  594,  610,  715,  896,  814,
#         716, 1051, 1281,  939, 1053,  566,  660,  185,  790, 1008,  442,
#         674, 1054, 1405,  596,  456,  516,  631, 1098,  845, 1240,  644,
#        1189,  959,  867,  530,  192,  662,  920,  511,  765,  828,  884])

# %%
df = df.drop(columns=['second_flr_sf'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  heating_qc  central_air  \
# 1           0           4          2           2            1
# 2           0           0          2           1            0
# 3           1           1          1           3            0
# 4           1           0          2           1            0
# 5           0           0          2           2            0
#
#    low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1                0         1928               0               0          2
# 2                0         1967               0               0          2
# 3                0         1496               1               0          2
# 4                0          968               0               0          1
# 5                0         1394               1               0          1
#
#    half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1          0              4              2           Fa              9
# 2          0              6              2           TA             10
# 3          1              3              1           Gd              7
# 4          0              2              1           TA              5
# 5          1              3              1           TA              6
#
#   functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 1        Typ           0          NaN      Detchd         1910.0
# 2        Typ           0          NaN      Attchd         1977.0
# 3        Typ           1           Gd      Attchd         2006.0
# 4        Typ           0          NaN      Detchd         1935.0
# 5        Typ           2           Gd      Attchd         1963.0
#
#   garage_finish  garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 1           Unf            1          440          Po          Po           Y
# 2           Fin            2          580          TA          TA           Y
# 3           RFn            2          426          TA          TA           Y
# 4           Unf            2          480          Fa          TA           N
# 5           RFn            2          514          TA          TA           Y
#
#    wood_deck_sf  open_porch_sf  enclosed_porch  threessn_porch  screen_porch  \
# 1             0             60             112               0             0
# 2           170              0               0               0             0
# 3           100             24               0               0             0
# 4             0              0             184               0             0
# 5             0             76               0               0           185
#
#    pool_area pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1          0     NaN   NaN          NaN         0        4     2006       WD
# 2          0     NaN   NaN          NaN         0        8     2006       WD
# 3          0     NaN   NaN          NaN         0        9     2006       New
# 4          0     NaN   NaN          NaN         0        7     2007       WD
# 5          0     NaN   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		low_qual_fin_sf              
# DEFINITION:	Low quality finished square feet (all floors)
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.low_qual_fin_sf.unique()
# COLUMN DOES NOT PERTAIN TO HOUSING PRICE,
# COLUMN TO BE DROPPED!
# Out:
# array([  0, 360, 431, 481,  80, 392, 232, 420])

# %%
df = df.drop(columns=['low_qual_fin_sf'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  heating_qc  central_air  gr_liv_area  \
# 1           0           4          2           2            1         1928
# 2           0           0          2           1            0         1967
# 3           1           1          1           3            0         1496
# 4           1           0          2           1            0          968
# 5           0           0          2           2            0         1394
#
#    bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  \
# 1               0               0          2          0              4
# 2               0               0          2          0              6
# 3               1               0          2          1              3
# 4               0               0          1          0              2
# 5               1               0          1          1              3
#
#    kitchen_abvgr kitchen_qual  totrms_abvgrd functional  fireplaces  \
# 1              2           Fa              9        Typ           0
# 2              2           TA             10        Typ           0
# 3              1           Gd              7        Typ           1
# 4              1           TA              5        Typ           0
# 5              1           TA              6        Typ           2
#
#   fireplace_qu garage_type  garage_yr_blt garage_finish  garage_cars  \
# 1          NaN      Detchd         1910.0           Unf            1
# 2          NaN      Attchd         1977.0           Fin            2
# 3           Gd      Attchd         2006.0           RFn            2
# 4          NaN      Detchd         1935.0           Unf            2
# 5           Gd      Attchd         1963.0           RFn            2
#
#    garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 1          440          Po          Po           Y             0
# 2          580          TA          TA           Y           170
# 3          426          TA          TA           Y           100
# 4          480          Fa          TA           N             0
# 5          514          TA          TA           Y             0
#
#    open_porch_sf  enclosed_porch  threessn_porch  screen_porch  pool_area  \
# 1             60             112               0             0          0
# 2              0               0               0             0          0
# 3             24               0               0             0          0
# 4              0             184               0             0          0
# 5             76               0               0           185          0
#
#   pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1     NaN   NaN          NaN         0        4     2006       WD
# 2     NaN   NaN          NaN         0        8     2006       WD
# 3     NaN   NaN          NaN         0        9     2006       New
# 4     NaN   NaN          NaN         0        7     2007       WD
# 5     NaN   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		gr_liv_area                       
# DEFINITION:	Above grade (ground) living area square feet
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.gr_liv_area.unique()
# COLUMN DOES NOT PERTAIN TO HOUSING PRICE,
# COLUMN TO BE DROPPED!
# Out:
# array([1928, 1967, 1496,  968, 1394, 1092, 1093, 1268, 1680, 1279, 1217,
#        1040, 1375, 2787, 1827, 1340, 1436, 1073, 1773, 1742, 1060,  864,
#        1617,  988, 1218, 1738, 1750, 1054,  670,  858, 1208, 2640, 1178,
#        1492, 1458, 1657,  998,  910, 1358, 1224, 1886, 1327, 1363, 1501,
#        1344, 1786,  965,  936, 1248, 2268, 1615, 1360, 1142, 1026, 1820,
#        1193, 1865, 2006, 1140, 1176, 1670, 1603, 2063, 1302,  774,  848,
#         747, 2520, 1560, 1472, 1050, 1724, 4676, 1771, 1207,  882, 1780,
#        1459, 1107, 1688, 2042,  876, 1320, 1707, 1495,  999, 1346, 1251,
#        1228, 1274, 1642, 1509, 1554, 1677, 1665, 1694, 1790,  923, 2470,
#        1244,  866, 1891, 1921, 1832, 1434, 1874, 1382, 1494, 3627, 1812,
#        1720, 1604, 1966, 1970, 1714, 1470, 2230, 2331, 1008, 1216, 1530,
#        1025, 1638, 1440, 1128, 1549, 2133, 1369, 1114,  816, 1381, 1078,
#        1469, 1474, 1137, 1960, 1768, 1392, 1740, 1626, 1198,  900,  792,
#        1098, 2127, 2263, 1493, 1200, 1056, 2674, 1456, 1563, 1145, 2318,
#        1445, 4476,  990, 1223, 1895, 1734,  691, 1949, 1242, 1666, 1978,
#        2167, 1350, 1258, 1489, 2068,  980,  944, 1664,  945,  838, 1484,
#         912, 1465, 1601, 2475, 2104,  934, 1710, 1427, 1269, 1370, 1933,
#        1876, 1292, 2036, 1557, 1737, 1830, 1389,  892, 1452, 1796,  856,
#         846, 2290, 1977, 1273, 2344, 1518,  630, 1844,  768, 3112, 1498,
#         844, 2772, 2097, 1352, 1919, 1284, 2374, 2314, 2018, 1651,  894,
#        1800, 1869, 1625, 1595, 2020, 2094, 1412, 1162, 2728, 1879, 2279,
#        1374, 1536, 1094, 2021, 1806, 1314, 1775, 1072, 2291, 1576, 1762,
#        3447, 1432, 1048, 1801, 1482,  974, 1017, 1850, 2345,  987,  784,
#        1144,  888, 1654,  925, 1437, 1596, 2061, 1958, 1884, 1902,  672,
#        1006, 1294, 1152, 1024, 2315, 1338, 1578, 2373, 2650, 1856, 1940,
#        1682, 1203, 1367, 1691, 1544,  958, 1306, 1952, 1728, 1866, 1709,
#        1920, 1235,  759, 1802, 1082,  788, 1676, 1447, 2225, 1848, 1776,
#        1490, 1064, 1864, 1398, 1660, 2978, 1521, 1431, 2052, 1517, 1608,
#        1234, 1572, 1647, 2014, 1163, 2544, 1824, 2855,  913, 1426, 1646,
#        1049, 1889, 1808, 2550, 1908, 1643, 2414, 1512, 1188, 1323, 1726,
#        1564, 1226, 1330, 1511, 1752, 1782, 1343, 1717, 1507, 1027, 1829,
#        1904,  952, 1131, 1588, 2673, 1764, 2090, 2612, 1271, 2514, 1803,
#        2422, 3086, 1290, 1541,  918, 1668, 1126, 1062,  893, 1594, 2376,
#        1368, 1416, 1080, 1744, 1214, 1090, 1102, 1473, 1086,  765, 2398,
#        1702, 1774, 1553, 1811, 1417, 1915,  960, 1229, 1348, 4316, 1196,
#        1959, 1759, 2161,  752,  884, 1614, 1516,  897, 2243, 1568, 1620,
#        1012, 1316,  845, 2236, 3194, 1136, 1211, 1256, 1285, 2372, 2264,
#        2324, 1414, 1968, 1149, 2499, 1119, 1199, 1846, 2727, 1304, 1610,
#        1365, 1308,  407, 1580, 1630, 2417,  995, 1539, 1836, 1455, 2656,
#        1036,  599,  836, 1746, 1103, 1222, 2192, 1022, 1337, 1052, 1982,
#        2468, 1582, 1281, 2199,  808, 2126, 1428,  840, 1038, 1548, 1118,
#         950, 1250, 1141, 1069,  938,  832, 1570,  919, 2654, 1230, 2212,
#        1261, 1155, 1120, 1838,  796, 1505, 2067, 1540, 1816, 1870, 1574,
#        1500,  789, 1212, 1053, 2828, 1418,  800, 2214, 1430, 1232, 1535,
#         890, 1476, 1065, 2522, 2177, 2447, 1444,  860, 1468, 1571,  641,
#        2169, 1675, 1175,  833,  720, 1944, 1032, 1822, 2748, 2461, 2000,
#        1372, 3005, 1755,  970, 1716, 1550,  780, 2551, 1644, 1645, 1679,
#        1112, 1837, 1453, 1177, 1692, 2358, 1132, 1882,  896, 2362, 2110,
#        1005, 1698, 1096, 1210, 2519, 1739, 1661, 2039, 1992,  985, 2198,
#        1411, 1043, 1618, 1792, 2184, 1004, 1797, 1362, 1499, 1395, 1068,
#        1206, 1868, 1526, 1245, 2071, 2411, 2028, 1696, 2552, 1408, 1324,
#         926, 2098, 1839, 1984, 1628, 1190, 2262, 2013, 2117, 1612, 2592,
#        2795, 1192, 1383, 2149, 1173, 1298, 2349, 1295, 1020, 1502, 1930,
#        1339,  984, 2322, 1015,  949, 2494, 1386, 1906, 1047, 1400, 1388,
#        2786, 1951, 1404, 1828, 1342, 1091, 1826, 1154,  971, 1051, 1524,
#        2207, 1852, 1282, 1204,  943, 1674, 1605, 1478,  767, 1313, 1725,
#        1491, 2432, 2046, 1390, 1877, 1988])

# %%
df = df.drop(columns=['gr_liv_area'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  heating_qc  central_air  bsmt_full_bath  \
# 1           0           4          2           2            1               0
# 2           0           0          2           1            0               0
# 3           1           1          1           3            0               1
# 4           1           0          2           1            0               0
# 5           0           0          2           2            0               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#   kitchen_qual  totrms_abvgrd functional  fireplaces fireplace_qu garage_type  \
# 1           Fa              9        Typ           0          NaN      Detchd
# 2           TA             10        Typ           0          NaN      Attchd
# 3           Gd              7        Typ           1           Gd      Attchd
# 4           TA              5        Typ           0          NaN      Detchd
# 5           TA              6        Typ           2           Gd      Attchd
#
#    garage_yr_blt garage_finish  garage_cars  garage_area garage_qual  \
# 1         1910.0           Unf            1          440          Po
# 2         1977.0           Fin            2          580          TA
# 3         2006.0           RFn            2          426          TA
# 4         1935.0           Unf            2          480          Fa
# 5         1963.0           RFn            2          514          TA
#
#   garage_cond paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  \
# 1          Po           Y             0             60             112
# 2          TA           Y           170              0               0
# 3          TA           Y           100             24               0
# 4          TA           N             0              0             184
# 5          TA           Y             0             76               0
#
#    threessn_porch  screen_porch  pool_area pool_qc fence misc_feature  \
# 1               0             0          0     NaN   NaN          NaN
# 2               0             0          0     NaN   NaN          NaN
# 3               0             0          0     NaN   NaN          NaN
# 4               0             0          0     NaN   NaN          NaN
# 5               0           185          0     NaN   NaN          NaN
#
#    misc_val  mo_sold  yr_sold sale_type
# 1         0        4     2006       WD
# 2         0        8     2006       WD
# 3         0        9     2006       New
# 4         0        7     2007       WD
# 5         0        7     2009       WD

# %%
# COLUMN:		bsmt_full_bath                           
# DEFINITION:	Basement full bathrooms
# DATA TYPE:	float64
# MISSING VALUES:	2
# UNIQUE VALUES:	
df.bsmt_full_bath.unique()
# COLUMN NEEDS TO BE CONVERTED TO INTERGER, CONVERT
# MISSING VALUES!
# Out:
# array([0, 1, 2])

# %%
df = df.dropna(subset=['bsmt_full_bath'])

# %%
df["bsmt_full_bath"] = df["bsmt_full_bath"].astype(dtype=np.int)
df['bsmt_full_bath'].dtype
# Out:
# dtype('int64')

# %%
df.bsmt_full_bath.unique()
# Out:
# array([0, 1, 2])

# %%
# COLUMN:		bsmt_half_bath                              
# DEFINITION:	Basement half bathrooms
# DATA TYPE:	float64
# MISSING VALUES:	2
# UNIQUE VALUES:	
df.bsmt_half_bath.unique()
# COLUMN NEEDS TO BE CONVERTED TO INTERGER, CONVERT
# MISSING VALUES!
# Out:
# array([0, 1])

# %%
df = df.dropna(subset=['bsmt_half_bath'])

# %%
df["bsmt_half_bath"] = df["bsmt_half_bath"].astype(dtype=np.int)
df['bsmt_half_bath'].dtype
# Out:
# dtype('int64')

# %%
df.bsmt_half_bath.unique()
# Out:
# array([0, 1])

# %%
# COLUMN:		full_bath                                        
# DEFINITION:	Full bathrooms above grade
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.full_bath.unique()
# EVALUATION: COLUMN READY TO GO... DATA TYPE GOOD, NO MISSING
# VALUES!
# Out:
# array([2, 1, 4, 3, 0])

# %% [markdown]
# - total_rms DOES NOT INCLUDE BATHROOMS! BELOW IS THE ADDITION OF BATHROOMS TO total_rms.

# %%
df['totrms_abvgrd'] = df['totrms_abvgrd'] + df['full_bath']

# %%
# COLUMN:		half_bath                                                  
# DEFINITION:	Half baths above grade
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.half_bath.unique()
# EVALUATION: COLUMN READY TO GO... DATA TYPE GOOD, NO MISSING
# VALUES!
# Out:
# array([0, 1, 2])

# %% [markdown]
# - total_rms DOES NOT INCLUDE BATHROOMS! BELOW IS THE ADDITION OF BATHROOMS TO total_rms.

# %%
df['totrms_abvgrd'] = df['totrms_abvgrd'] + df['half_bath']

# %%
# COLUMN:		bedroom_abvgr                                                  
# DEFINITION:	Bedrooms above grade (does NOT include basement bedrooms)
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.bedroom_abvgr.unique()
# EVALUATION: COLUMN READY TO GO... DATA TYPE GOOD, NO MISSING
# VALUES!
# Out:
# array([4, 6, 3, 2, 1, 5, 0])

# %%
# COLUMN:		kitchen_abvgr                                                        
# DEFINITION:	Kitchens above grade
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df. kitchen_abvgr.unique()
# EVALUATION: COLUMN READY TO GO... DATA TYPE GOOD, NO MISSING
# VALUES!
# Out:
# array([2, 1, 0, 3])

# %%
# COLUMN:		kitchen_qual                                                              
# DEFINITION:	Kitchen quality
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.kitchen_qual.unique()
# EVALUATION: COLUMN DATA TYPE NEEDS TO BE CHANGED, NO MISSING
# VALUES!
# Out:
# array(['Fa', 'TA', 'Gd', 'Ex', 'Po'], dtype=object)

# %% [markdown]
# - COLUMN HAS DIFFERENT VALUES THAN TEST.CSV

# %%
df = df.drop(columns=['kitchen_qual'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  heating_qc  central_air  bsmt_full_bath  \
# 1           0           4          2           2            1               0
# 2           0           0          2           1            0               0
# 3           1           1          1           3            0               1
# 4           1           0          2           1            0               0
# 5           0           0          2           2            0               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#    totrms_abvgrd functional  fireplaces fireplace_qu garage_type  \
# 1             11        Typ           0          NaN      Detchd
# 2             12        Typ           0          NaN      Attchd
# 3             10        Typ           1           Gd      Attchd
# 4              6        Typ           0          NaN      Detchd
# 5              8        Typ           2           Gd      Attchd
#
#    garage_yr_blt garage_finish  garage_cars  garage_area garage_qual  \
# 1         1910.0           Unf            1          440          Po
# 2         1977.0           Fin            2          580          TA
# 3         2006.0           RFn            2          426          TA
# 4         1935.0           Unf            2          480          Fa
# 5         1963.0           RFn            2          514          TA
#
#   garage_cond paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  \
# 1          Po           Y             0             60             112
# 2          TA           Y           170              0               0
# 3          TA           Y           100             24               0
# 4          TA           N             0              0             184
# 5          TA           Y             0             76               0
#
#    threessn_porch  screen_porch  pool_area pool_qc fence misc_feature  \
# 1               0             0          0     NaN   NaN          NaN
# 2               0             0          0     NaN   NaN          NaN
# 3               0             0          0     NaN   NaN          NaN
# 4               0             0          0     NaN   NaN          NaN
# 5               0           185          0     NaN   NaN          NaN
#
#    misc_val  mo_sold  yr_sold sale_type
# 1         0        4     2006       WD
# 2         0        8     2006       WD
# 3         0        9     2006       New
# 4         0        7     2007       WD
# 5         0        7     2009       WD

# %%
# COLUMN:		totrms_abvgrd                                                                     
# DEFINITION:	Total rooms above grade (does not include bathrooms)
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.totrms_abvgrd.unique()
# EVALUATION: COLUMN DATA TYPE IS ACCEPTABLE, NO MISSING VALUES.
# WILL INCLUDE FULL AND HALF BATH ROOMS.
# Out:
# array([11, 12, 10,  6,  8,  7, 14,  5,  9, 13,  4, 15, 16])

# %%
# COLUMN:		functional                                                                             
# DEFINITION:	Home functionality (Assume typical unless deductions are warranted)
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.functional.unique()
# Out:
# array(['Typ', 'Min2', 'Min1', 'Mod', 'Maj1', 'Maj2'], dtype=object)

# %%
functional  = {'Typ':'0', 'Mod':'1', 'Min2':'2', 'Maj1':'3', 'Min1':'4', 'Sev':'5', 'Sal':'6', 'Maj2':'7'}
df.functional  = [functional [item] for item in df.functional] 
df.functional.unique()
# Out:
# array(['0', '2', '4', '1', '3', '7'], dtype=object)

# %%
df["functional"] = df["functional"].astype(dtype=np.int)
df['functional'].dtype
# Out:
# dtype('int64')

# %%
# COLUMN:		fireplaces                                                                                       
# DEFINITION:	Number of fireplaces
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.fireplaces.unique()
# EVALUATION: COLUMN READY TO GO... DATA TYPE GOOD, NO MISSING
# VALUES!
# Out:
# array([0, 1, 2, 3])

# %%
# COLUMN:		fireplace_qu                                                                                              
# DEFINITION:	Fireplace quality
# DATA TYPE:	object
# MISSING VALUES:	1000
# UNIQUE VALUES:	
df.fireplace_qu.unique()
# Out:
# array([nan, 'Gd', 'Fa', 'TA', 'Po', 'Ex'], dtype=object)

# %%
df = df.drop(columns=['fireplace_qu'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  heating_qc  central_air  bsmt_full_bath  \
# 1           0           4          2           2            1               0
# 2           0           0          2           1            0               0
# 3           1           1          1           3            0               1
# 4           1           0          2           1            0               0
# 5           0           0          2           2            0               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#    totrms_abvgrd  functional  fireplaces garage_type  garage_yr_blt  \
# 1             11           0           0      Detchd         1910.0
# 2             12           0           0      Attchd         1977.0
# 3             10           0           1      Attchd         2006.0
# 4              6           0           0      Detchd         1935.0
# 5              8           0           2      Attchd         1963.0
#
#   garage_finish  garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 1           Unf            1          440          Po          Po           Y
# 2           Fin            2          580          TA          TA           Y
# 3           RFn            2          426          TA          TA           Y
# 4           Unf            2          480          Fa          TA           N
# 5           RFn            2          514          TA          TA           Y
#
#    wood_deck_sf  open_porch_sf  enclosed_porch  threessn_porch  screen_porch  \
# 1             0             60             112               0             0
# 2           170              0               0               0             0
# 3           100             24               0               0             0
# 4             0              0             184               0             0
# 5             0             76               0               0           185
#
#    pool_area pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1          0     NaN   NaN          NaN         0        4     2006       WD
# 2          0     NaN   NaN          NaN         0        8     2006       WD
# 3          0     NaN   NaN          NaN         0        9     2006       New
# 4          0     NaN   NaN          NaN         0        7     2007       WD
# 5          0     NaN   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		garage_type                                                                                                      
# DEFINITION:	Garage location
# DATA TYPE:	object
# MISSING VALUES:	113
# UNIQUE VALUES:	
df.garage_type.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE, MISSING
# VALUES, COLUMN TO BE DROPPED!
# Out:
# array(['Detchd', 'Attchd', 'BuiltIn', nan, '2Types', 'CarPort', 'Basment'],
#       dtype=object)

# %%
garage_type = {np.nan:'0', 'Attchd':'1', 'Detchd':'2', 'BuiltIn':'3', 'CarPort':'4', 'Basment':'5', '2Types':'6'}
df.garage_type = [garage_type[item] for item in df.garage_type] 
df.garage_type.unique()
# Out:
# array(['2', '1', '3', '0', '6', '4', '5'], dtype=object)

# %%
df['garage_type'] = pd.to_numeric(df['garage_type'], errors='garage_type')
df['garage_type'].dtype
# Out:
# dtype('int64')

# %%
# COLUMN:		garage_yr_blt                                                                                                           
# DEFINITION:	Year garage was built
# DATA TYPE:	float64
# MISSING VALUES:	114
# UNIQUE VALUES:	
df.garage_yr_blt.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE, MISSING
# VALUES, COLUMN TO BE DROPPED!
# Out:
# array([1910., 1977., 2006., 1935., 1963., 1972., 1959., 1978., 2004.,
#        1980., 1991., 1993., 1954., 2000., 1943., 1957., 1940., 1956.,
#        1961., 1925., 1968., 1982., 1969., 2007., 1989., 1920., 1937.,
#          nan, 1979., 1962., 1950., 1973., 2001., 1952., 1953., 1999.,
#        2009., 1998., 1974., 1951., 1987., 2003., 1924., 1970., 1975.,
#        1958., 1971., 1992., 1994., 2005., 1960., 1967., 2002., 1997.,
#        1981., 1938., 1988., 1939., 1927., 1984., 1964., 1995., 2008.,
#        1966., 1941., 1983., 1906., 1930., 1955., 1946., 1996., 1928.,
#        1976., 1915., 1923., 1965., 1947., 1900., 1918., 1934., 1932.,
#        1986., 2010., 1985., 1949., 1948., 1917., 1990., 1921., 1926.,
#        1931., 1916., 1922., 1908.])

# %%
df = df.drop(columns=['garage_yr_blt'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  heating_qc  central_air  bsmt_full_bath  \
# 1           0           4          2           2            1               0
# 2           0           0          2           1            0               0
# 3           1           1          1           3            0               1
# 4           1           0          2           1            0               0
# 5           0           0          2           2            0               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#    totrms_abvgrd  functional  fireplaces  garage_type garage_finish  \
# 1             11           0           0            2           Unf
# 2             12           0           0            1           Fin
# 3             10           0           1            1           RFn
# 4              6           0           0            2           Unf
# 5              8           0           2            1           RFn
#
#    garage_cars  garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 1            1          440          Po          Po           Y             0
# 2            2          580          TA          TA           Y           170
# 3            2          426          TA          TA           Y           100
# 4            2          480          Fa          TA           N             0
# 5            2          514          TA          TA           Y             0
#
#    open_porch_sf  enclosed_porch  threessn_porch  screen_porch  pool_area  \
# 1             60             112               0             0          0
# 2              0               0               0             0          0
# 3             24               0               0             0          0
# 4              0             184               0             0          0
# 5             76               0               0           185          0
#
#   pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1     NaN   NaN          NaN         0        4     2006       WD
# 2     NaN   NaN          NaN         0        8     2006       WD
# 3     NaN   NaN          NaN         0        9     2006       New
# 4     NaN   NaN          NaN         0        7     2007       WD
# 5     NaN   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		garage_finish                                                                                                                
# DEFINITION:	Interior finish of the garage
# DATA TYPE:	object
# MISSING VALUES:	114
# UNIQUE VALUES:	
df.garage_finish.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE, MISSING
# VALUES, COLUMN TO BE DROPPED!
# Out:
# array(['Unf', 'Fin', 'RFn', nan], dtype=object)

# %%
df = df.drop(columns=['garage_finish'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  heating_qc  central_air  bsmt_full_bath  \
# 1           0           4          2           2            1               0
# 2           0           0          2           1            0               0
# 3           1           1          1           3            0               1
# 4           1           0          2           1            0               0
# 5           0           0          2           2            0               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#    totrms_abvgrd  functional  fireplaces  garage_type  garage_cars  \
# 1             11           0           0            2            1
# 2             12           0           0            1            2
# 3             10           0           1            1            2
# 4              6           0           0            2            2
# 5              8           0           2            1            2
#
#    garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 1          440          Po          Po           Y             0
# 2          580          TA          TA           Y           170
# 3          426          TA          TA           Y           100
# 4          480          Fa          TA           N             0
# 5          514          TA          TA           Y             0
#
#    open_porch_sf  enclosed_porch  threessn_porch  screen_porch  pool_area  \
# 1             60             112               0             0          0
# 2              0               0               0             0          0
# 3             24               0               0             0          0
# 4              0             184               0             0          0
# 5             76               0               0           185          0
#
#   pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1     NaN   NaN          NaN         0        4     2006       WD
# 2     NaN   NaN          NaN         0        8     2006       WD
# 3     NaN   NaN          NaN         0        9     2006       New
# 4     NaN   NaN          NaN         0        7     2007       WD
# 5     NaN   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		garage_cars                                                                                                                      
# DEFINITION:	Size of garage in car capacity
# DATA TYPE:	float64
# MISSING VALUES:	1
# UNIQUE VALUES:	
df.garage_cars.unique()
# Out:
# array([1, 2, 4, 0, 3])

# %%
df = df.dropna(subset=['garage_cars'])

# %%
df["garage_cars"] = df["garage_cars"].astype(dtype=np.int)
df['garage_cars'].dtype
# Out:
# dtype('int64')

# %%
df.garage_cars.unique()
# Out:
# array([1, 2, 4, 0, 3])

# %%
# COLUMN:		garage_area                                                                                                                             
# DEFINITION:	Size of garage in square feet
# DATA TYPE:	float64
# MISSING VALUES:	1
# UNIQUE VALUES:	
df.garage_area.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE, MISSING
# VALUES, COLUMN TO BE DROPPED!
# Out:
# array([ 440,  580,  426,  480,  514,  286,  308,  252,  588,  473,  484,
#         320,  451,  820,  240,  828,  340,  418,  424,  270,  732,  533,
#         540,  576,  352,  368,    0,  684,  539,  864,  439,  608,  454,
#         162,  460,  414,  625,  528,  431,  624,  288,  512,  300,  160,
#         297,  506,  839,  938,  400,  303,  464,  815,  631,  420,  640,
#         402,  336,  884,  264,  294,  816,  527,  603, 1390,  495,  511,
#         384,  472,  224,  374,  322,  627,  642,  789,  678,  807,  672,
#         846,  470, 1092,  753,  517,  388, 1003,  355,  984,  370,  315,
#         312,  605,  676,  216,  299,  565,  332,  260,  833,  905,  508,
#         762,  758,  437,  541,  813,  409,  586,  324,  486,  518,  478,
#         280,  253,  275,  276,  393,  880,  962,  432,  379,  668,  205,
#         513,  521,  483,  399,  779,  574,  307,  889,  795,  754, 1134,
#         466,  685,  656,  502,  746,  870,  396,  463,  617,  615,  258,
#         706,  461,  422,  425,  520,  525,  614, 1014,  360,  800,  467,
#         596,  610,  647,  599,  492,  649,  256,  529,  662,  342,  582,
#         632,  834,  606,  429,  868,  600,  756,  234,  416,  287,  523,
#         713,  592,  443,  500,  504,  564,  666,  444,  180,  888,  538,
#         995,  621,  220,  907,  774,  712,  482,  626,  266,  850,  670,
#         493,  438,  786,  476,  597,  740,  413, 1248,  551,  186,  908,
#         404,  450,  613,  736,  840,  441,  301,  556,  693, 1200,  200,
#         843,  900,  548,  702,  434,  853,  474,  776,  496,  457,  318,
#         546,  452,  844,  468,  392,  462,  453,  832,  570,  865,  397,
#         290,  380,  641,  675,  408,  398,  530,  544,  390,  192, 1025,
#         860,  644, 1040,  250,  345,  350,  747,  575,  872,  583,  516,
#         164,  554,  365,  568,  561,  215,  686,  195,  638, 1488,  773,
#         184,  433,  524,  456,  765,  784,  730,  230,  566,  648, 1052,
#         558,  646,  410,  630,  552,  338,  912,  722,  272,  326,  515,
#         848,  704,  490,  281,  925,  824,  688,  366,  430,  445,  650,
#         612,  522,  244,  628,  377,  791,  328,  836,  273,  963,  869,
#         497,  364,  210,  972,  645,  932,  489,  550,  351,  459,  714,
#         578,  749,  455,  225,  660,  189,  305,  354,  403,  571,  509,
#         481,  369,  803,  465,  636,  792,  292,  344,  498,  412,  708,
#         367,  577,  616,  545,  488])

# %%
df = df.drop(columns=['garage_area'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  heating_qc  central_air  bsmt_full_bath  \
# 1           0           4          2           2            1               0
# 2           0           0          2           1            0               0
# 3           1           1          1           3            0               1
# 4           1           0          2           1            0               0
# 5           0           0          2           2            0               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#    totrms_abvgrd  functional  fireplaces  garage_type  garage_cars  \
# 1             11           0           0            2            1
# 2             12           0           0            1            2
# 3             10           0           1            1            2
# 4              6           0           0            2            2
# 5              8           0           2            1            2
#
#   garage_qual garage_cond paved_drive  wood_deck_sf  open_porch_sf  \
# 1          Po          Po           Y             0             60
# 2          TA          TA           Y           170              0
# 3          TA          TA           Y           100             24
# 4          Fa          TA           N             0              0
# 5          TA          TA           Y             0             76
#
#    enclosed_porch  threessn_porch  screen_porch  pool_area pool_qc fence  \
# 1             112               0             0          0     NaN   NaN
# 2               0               0             0          0     NaN   NaN
# 3               0               0             0          0     NaN   NaN
# 4             184               0             0          0     NaN   NaN
# 5               0               0           185          0     NaN   NaN
#
#   misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1          NaN         0        4     2006       WD
# 2          NaN         0        8     2006       WD
# 3          NaN         0        9     2006       New
# 4          NaN         0        7     2007       WD
# 5          NaN         0        7     2009       WD

# %%
# COLUMN:		garage_qual                                                                                                                                     
# DEFINITION:	Garage quality
# DATA TYPE:	object
# MISSING VALUES:	114
# UNIQUE VALUES:	
df.garage_qual.unique()
# COLUMN APPEARS TO BE THE SAME AS garage_cond. DROPPING
# garage_cond AND KEEPING garage_qual. CHANGE DATA TYPE,
# ADDRESS MISSING VALUES!
# Out:
# array(['Po', 'TA', 'Fa', nan, 'Gd'], dtype=object)

# %%
garage_qual = {np.nan:'0', 'TA':'1', 'Fa':'2', 'Ex':'3', 'Gd':'4', 'Po':'5'}
df.garage_qual = [garage_qual[item] for item in df.garage_qual] 
df.garage_qual.unique()
# Out:
# array(['5', '1', '2', '0', '4'], dtype=object)

# %%
df['garage_qual'] = pd.to_numeric(df['garage_qual'], errors='coerce')
df['garage_qual'].dtype
# Out:
# dtype('int64')

# %%
# COLUMN:		garage_cond                                                                                                                                            
# DEFINITION:	Garage condition
# DATA TYPE:	object
# MISSING VALUES:	114
# UNIQUE VALUES:	
df.garage_cond.unique()
# Out:
# array(['Po', 'TA', nan, 'Fa', 'Gd', 'Ex'], dtype=object)

# %%
df = df.drop(columns=['garage_cond'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  heating_qc  central_air  bsmt_full_bath  \
# 1           0           4          2           2            1               0
# 2           0           0          2           1            0               0
# 3           1           1          1           3            0               1
# 4           1           0          2           1            0               0
# 5           0           0          2           2            0               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#    totrms_abvgrd  functional  fireplaces  garage_type  garage_cars  \
# 1             11           0           0            2            1
# 2             12           0           0            1            2
# 3             10           0           1            1            2
# 4              6           0           0            2            2
# 5              8           0           2            1            2
#
#    garage_qual paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  \
# 1            5           Y             0             60             112
# 2            1           Y           170              0               0
# 3            1           Y           100             24               0
# 4            2           N             0              0             184
# 5            1           Y             0             76               0
#
#    threessn_porch  screen_porch  pool_area pool_qc fence misc_feature  \
# 1               0             0          0     NaN   NaN          NaN
# 2               0             0          0     NaN   NaN          NaN
# 3               0             0          0     NaN   NaN          NaN
# 4               0             0          0     NaN   NaN          NaN
# 5               0           185          0     NaN   NaN          NaN
#
#    misc_val  mo_sold  yr_sold sale_type
# 1         0        4     2006       WD
# 2         0        8     2006       WD
# 3         0        9     2006       New
# 4         0        7     2007       WD
# 5         0        7     2009       WD

# %%
# COLUMN:		paved_drive                                                                                                                                                  
# DEFINITION:	Paved driveway
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.paved_drive.unique()
# Out:
# array(['Y', 'N', 'P'], dtype=object)

# %%
paved_drive = {'P':'1', 'Y':'1', 'N':'0'}
df.paved_drive = [paved_drive[item] for item in df.paved_drive] 
df.paved_drive.unique()
# Out:
# array(['1', '0'], dtype=object)

# %%
df["paved_drive"] = df["paved_drive"].astype(dtype=np.int)
df['paved_drive'].dtype
# Out:
# dtype('int64')

# %%
# COLUMN:		wood_deck_sf                                                                                                                                                       
# DEFINITION:	Wood deck area in square feet
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.wood_deck_sf.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE, MISSING
# VALUES, COLUMN TO BE DROPPED!
# Out:
# array([  0, 170, 100, 173, 238, 312,  27, 116, 355, 406,  55, 120, 181,
#        224, 196, 176,  89, 324, 240, 421, 168, 171, 316,  40, 144, 182,
#        110, 149, 192, 164, 208, 147, 403, 574, 180, 158, 156, 501, 362,
#        154,  58, 190,  80,  36, 402, 361, 344, 360,  76, 177, 212, 127,
#        248, 330, 366,  57, 228, 175,  72, 140, 390, 453, 143,  32, 220,
#        174, 280,  23,  77, 256, 124, 264, 483,  96,  84, 315,  50, 135,
#        104, 210, 123, 400, 274, 250, 234, 314,  44, 304, 296, 185, 231,
#        670, 113, 215,  90, 285, 245, 133, 690, 198, 286, 322, 237, 152,
#        142, 411, 247, 128, 172, 200, 339,  85, 261, 199,  95, 325, 467,
#        169,  56, 179, 178, 216,  38, 468, 257, 300, 132, 370, 239, 155,
#         60, 225, 188, 382, 150, 353, 121, 186, 426, 351, 235, 305, 141,
#        233, 112,  68, 268, 295, 262, 136, 184, 253, 209,  25, 486, 108,
#        145, 328,  71, 490, 160,  74, 277, 129, 270, 297, 106, 306, 161,
#         42, 125, 197, 272,  70,  49, 474, 502, 202, 460, 204, 252, 320,
#        115, 139, 294, 448, 232, 131, 326,  26, 130, 319, 331,  64,  48,
#        511, 213, 165, 335,  20, 290, 194,  66,  63, 405, 301, 279, 386,
#        219,  81])

# %%
df = df.drop(columns=['wood_deck_sf'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  heating_qc  central_air  bsmt_full_bath  \
# 1           0           4          2           2            1               0
# 2           0           0          2           1            0               0
# 3           1           1          1           3            0               1
# 4           1           0          2           1            0               0
# 5           0           0          2           2            0               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#    totrms_abvgrd  functional  fireplaces  garage_type  garage_cars  \
# 1             11           0           0            2            1
# 2             12           0           0            1            2
# 3             10           0           1            1            2
# 4              6           0           0            2            2
# 5              8           0           2            1            2
#
#    garage_qual  paved_drive  open_porch_sf  enclosed_porch  threessn_porch  \
# 1            5            1             60             112               0
# 2            1            1              0               0               0
# 3            1            1             24               0               0
# 4            2            0              0             184               0
# 5            1            1             76               0               0
#
#    screen_porch  pool_area pool_qc fence misc_feature  misc_val  mo_sold  \
# 1             0          0     NaN   NaN          NaN         0        4
# 2             0          0     NaN   NaN          NaN         0        8
# 3             0          0     NaN   NaN          NaN         0        9
# 4             0          0     NaN   NaN          NaN         0        7
# 5           185          0     NaN   NaN          NaN         0        7
#
#    yr_sold sale_type
# 1     2006       WD
# 2     2006       WD
# 3     2006       New
# 4     2007       WD
# 5     2009       WD

# %%
# COLUMN:		open_porch_sf                                                                                                                                                         
# DEFINITION:	Open porch area in square feet
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.open_porch_sf.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE, MISSING
# VALUES, COLUMN TO BE DROPPED!
# Out:
# array([ 60,   0,  24,  76, 111,  83,  64, 132,  30,  36,  98, 169,  90,
#        312,  69, 130, 178,  21,  23, 114,  33, 174, 234,  42, 108,  65,
#         48, 100,  28, 184, 124,  56,  50, 273,  75, 406, 240,  68,  39,
#         32,  20, 120,  73,  45,  40,  63, 180,  58, 134,  25, 104,  52,
#         74,  55, 188,  18, 136,  38, 203, 102,  70, 144, 192,  99,  78,
#        116, 246,  35, 253, 166,  46, 156,  43,  47,  72, 126,  34, 172,
#        341,  29, 236,  49, 113,  85, 115,  53,  16,  44,  81, 267, 241,
#         51, 274,  54, 155, 182, 160, 216,  12,  92,  27,  95, 217, 139,
#         26,  77,  91, 263,  62, 105, 133, 138,  84, 208, 112,  61,  96,
#        154,  22, 150, 193,  59, 266, 287, 152, 204, 189, 382,  82,  15,
#        162, 170, 131, 254, 570, 122, 222, 137, 110,  80,  57,  87, 103,
#        195, 250, 177, 165, 262,  88,  66,  41, 742,  89, 140, 201,   6,
#        265, 224, 194, 247, 175, 198, 230])

# %%
df = df.drop(columns=['open_porch_sf'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  heating_qc  central_air  bsmt_full_bath  \
# 1           0           4          2           2            1               0
# 2           0           0          2           1            0               0
# 3           1           1          1           3            0               1
# 4           1           0          2           1            0               0
# 5           0           0          2           2            0               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#    totrms_abvgrd  functional  fireplaces  garage_type  garage_cars  \
# 1             11           0           0            2            1
# 2             12           0           0            1            2
# 3             10           0           1            1            2
# 4              6           0           0            2            2
# 5              8           0           2            1            2
#
#    garage_qual  paved_drive  enclosed_porch  threessn_porch  screen_porch  \
# 1            5            1             112               0             0
# 2            1            1               0               0             0
# 3            1            1               0               0             0
# 4            2            0             184               0             0
# 5            1            1               0               0           185
#
#    pool_area pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1          0     NaN   NaN          NaN         0        4     2006       WD
# 2          0     NaN   NaN          NaN         0        8     2006       WD
# 3          0     NaN   NaN          NaN         0        9     2006       New
# 4          0     NaN   NaN          NaN         0        7     2007       WD
# 5          0     NaN   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		enclosed_porch                                                                                                                                                              
# DEFINITION:	Enclosed porch area in square feet
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.enclosed_porch.unique()
# EVALUATION: DATA TYPE GOOD, NO MISSING VALUES! 
# COMBINE threessn_porch WITH enclosed_porch TO FORM NEW
# enclosed_porch.
# Out:
# array([ 112,    0,  184,   64,   42,  126,  293,  386,  140,  150,   80,
#         220,  192,  190,   98,  286,   32,  584,  185,   40,  180,   86,
#         239,  144,  160,  218,  120,  224,   94,   60,   56,   88,  183,
#         168,  105,  196,  552,  123,  108,  169,  221,  254,  139,   91,
#         209,   55,  170,  248,  242,   81,  244,  102,  238,  252,  264,
#          41,  290,  240,  205,   35,  132,  228,  208,   51,   84,  116,
#         128,  100,   20,   96,   68,   70,  231, 1012,  121,  429,   90,
#         334,  137,  164,   48,   28,  202])

# %%
# df.sort_values(["enclosed_porch"], axis=0, ascending=True, inplace=True)

# %%
# print(df['enclosed_porch'])

# %%
# COLUMN:		threessn_porch                                                                                                                                                                       
# DEFINITION:	Three season porch area in square feet
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.threessn_porch.unique()
# EVALUATION: DATA TYPE GOOD, NO MISSING VALUES! DATA APPEARS
# TO BE THE SAME AS screen_porch. WILL DROP threessn_porch AND
# COMBINE screen_porch WITH enclosed_porch TO FORM NEW
# enclosed_porch.
#
# Out:
# array([  0, 180, 130, 225, 219, 360, 238,  23, 174, 196, 216, 320])

# %%
# df.sort_values(["threessn_porch"], axis=0, ascending=True, inplace=True)

# %%
# print(df['threessn_porch'])

# %% [markdown]
# - AFTER INVESTIGATION OF THE VALUES IN enclosed_porch & threessn_porch, IT WAS DISCOVERED DATA COULD BE ENGINEERED INTO ONE, enclosed_porch NOW CONTIANS threessn_porch.

# %%
df['enclosed_porch']=df['enclosed_porch']+df['threessn_porch']

# %%
# print(df['enclosed_porch'])

# %%
df = df.drop(columns=['threessn_porch'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  heating_qc  central_air  bsmt_full_bath  \
# 1           0           4          2           2            1               0
# 2           0           0          2           1            0               0
# 3           1           1          1           3            0               1
# 4           1           0          2           1            0               0
# 5           0           0          2           2            0               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#    totrms_abvgrd  functional  fireplaces  garage_type  garage_cars  \
# 1             11           0           0            2            1
# 2             12           0           0            1            2
# 3             10           0           1            1            2
# 4              6           0           0            2            2
# 5              8           0           2            1            2
#
#    garage_qual  paved_drive  enclosed_porch  screen_porch  pool_area pool_qc  \
# 1            5            1             112             0          0     NaN
# 2            1            1               0             0          0     NaN
# 3            1            1               0             0          0     NaN
# 4            2            0             184             0          0     NaN
# 5            1            1               0           185          0     NaN
#
#   fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1   NaN          NaN         0        4     2006       WD
# 2   NaN          NaN         0        8     2006       WD
# 3   NaN          NaN         0        9     2006       New
# 4   NaN          NaN         0        7     2007       WD
# 5   NaN          NaN         0        7     2009       WD

# %%
# COLUMN:		screen_porch                                                                                                                                                                             
# DEFINITION:	Screen porch area in square feet
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.screen_porch.unique()
# EVALUATION: DATA TYPE GOOD, NO MISSING VALUES! DATA APPEARS
# TO BE THE SAME AS threessn_porch. WILL DROP screen_porch!!!
# Out:
# array([  0, 185, 144, 168, 160, 200, 576, 216, 189, 128, 259, 108, 192,
#        256, 166, 115, 153, 138, 287,  99, 112, 263, 155, 266, 204, 156,
#        119,  60, 273, 117,  90,  40,  92, 110, 126, 225, 195, 288, 228,
#        116,  80, 123, 184, 120, 175, 178, 227, 100,  63, 198, 221, 196,
#        197, 121])

# %%
# df.sort_values(["screen_porch"], axis=0, ascending=True, inplace=True)

# %%
# print(df['screen_porch'])

# %%
df = df.drop(columns=['screen_porch'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  heating_qc  central_air  bsmt_full_bath  \
# 1           0           4          2           2            1               0
# 2           0           0          2           1            0               0
# 3           1           1          1           3            0               1
# 4           1           0          2           1            0               0
# 5           0           0          2           2            0               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#    totrms_abvgrd  functional  fireplaces  garage_type  garage_cars  \
# 1             11           0           0            2            1
# 2             12           0           0            1            2
# 3             10           0           1            1            2
# 4              6           0           0            2            2
# 5              8           0           2            1            2
#
#    garage_qual  paved_drive  enclosed_porch  pool_area pool_qc fence  \
# 1            5            1             112          0     NaN   NaN
# 2            1            1               0          0     NaN   NaN
# 3            1            1               0          0     NaN   NaN
# 4            2            0             184          0     NaN   NaN
# 5            1            1               0          0     NaN   NaN
#
#   misc_feature  misc_val  mo_sold  yr_sold sale_type
# 1          NaN         0        4     2006       WD
# 2          NaN         0        8     2006       WD
# 3          NaN         0        9     2006       New
# 4          NaN         0        7     2007       WD
# 5          NaN         0        7     2009       WD

# %%
# COLUMN:		pool_area                                                                                                                                                                                       
# DEFINITION:	Pool area in square feet
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.pool_area.unique()
# EVALUATION: COLUMN READY TO GO... DATA TYPE GOOD, NO MISSING
# VALUES!
# Out:
# array([  0, 144, 555, 512, 444])

# %%
# COLUMN:		pool_qc                                                                                                                                                                                                   
# DEFINITION:	Pool quality
# DATA TYPE:	object
# MISSING VALUES:	2042
# UNIQUE VALUES:	
df.pool_qc.unique()
# EVALUATION: COLUMN DATA TYPE NEEDS TO BE CONVERTED. MISSING
# VALUES, COLUMN TO BE DROPPED!
# Out:
# array([nan, 'Ex', 'TA'], dtype=object)

# %%
df = df.drop(columns=['pool_qc'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  heating_qc  central_air  bsmt_full_bath  \
# 1           0           4          2           2            1               0
# 2           0           0          2           1            0               0
# 3           1           1          1           3            0               1
# 4           1           0          2           1            0               0
# 5           0           0          2           2            0               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#    totrms_abvgrd  functional  fireplaces  garage_type  garage_cars  \
# 1             11           0           0            2            1
# 2             12           0           0            1            2
# 3             10           0           1            1            2
# 4              6           0           0            2            2
# 5              8           0           2            1            2
#
#    garage_qual  paved_drive  enclosed_porch  pool_area fence misc_feature  \
# 1            5            1             112          0   NaN          NaN
# 2            1            1               0          0   NaN          NaN
# 3            1            1               0          0   NaN          NaN
# 4            2            0             184          0   NaN          NaN
# 5            1            1               0          0   NaN          NaN
#
#    misc_val  mo_sold  yr_sold sale_type
# 1         0        4     2006       WD
# 2         0        8     2006       WD
# 3         0        9     2006       New
# 4         0        7     2007       WD
# 5         0        7     2009       WD

# %%
# COLUMN:		fence              
# DEFINITION:	Fence quality
# DATA TYPE:	object
# MISSING VALUES:	1651
# UNIQUE VALUES:	
df.fence.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE, MISSING
# VALUES, COLUMN TO BE DROPPED!
# Out:
# array([nan, 'MnPrv', 'GdPrv', 'GdWo', 'MnWw'], dtype=object)

# %%
df = df.drop(columns=['fence'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  heating_qc  central_air  bsmt_full_bath  \
# 1           0           4          2           2            1               0
# 2           0           0          2           1            0               0
# 3           1           1          1           3            0               1
# 4           1           0          2           1            0               0
# 5           0           0          2           2            0               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#    totrms_abvgrd  functional  fireplaces  garage_type  garage_cars  \
# 1             11           0           0            2            1
# 2             12           0           0            1            2
# 3             10           0           1            1            2
# 4              6           0           0            2            2
# 5              8           0           2            1            2
#
#    garage_qual  paved_drive  enclosed_porch  pool_area misc_feature  misc_val  \
# 1            5            1             112          0          NaN         0
# 2            1            1               0          0          NaN         0
# 3            1            1               0          0          NaN         0
# 4            2            0             184          0          NaN         0
# 5            1            1               0          0          NaN         0
#
#    mo_sold  yr_sold sale_type
# 1        4     2006       WD
# 2        8     2006       WD
# 3        9     2006       New
# 4        7     2007       WD
# 5        7     2009       WD

# %%
# COLUMN:		misc_feature       
# DEFINITION:	Miscellaneous feature not covered in other
#               categories
# DATA TYPE:	object
# MISSING VALUES:	1986
# UNIQUE VALUES:	
df.misc_feature.unique()
# EVALUATION: DATA TYPE NEEDS TO BE CONVERTED. LOTS OF MISSING
# VALUES. MISC_VAL DOES NOT EQUAL VALUES FROM MISC_FEATURE.
# COLUMNS APPEAR TO NOT CORILATE. COLUMN TO BE DROPPED!
# Out:
# array([nan, 'Shed', 'Othr', 'Gar2'], dtype=object)

# %%
df = df.drop(columns=['misc_feature'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  heating_qc  central_air  bsmt_full_bath  \
# 1           0           4          2           2            1               0
# 2           0           0          2           1            0               0
# 3           1           1          1           3            0               1
# 4           1           0          2           1            0               0
# 5           0           0          2           2            0               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#    totrms_abvgrd  functional  fireplaces  garage_type  garage_cars  \
# 1             11           0           0            2            1
# 2             12           0           0            1            2
# 3             10           0           1            1            2
# 4              6           0           0            2            2
# 5              8           0           2            1            2
#
#    garage_qual  paved_drive  enclosed_porch  pool_area  misc_val  mo_sold  \
# 1            5            1             112          0         0        4
# 2            1            1               0          0         0        8
# 3            1            1               0          0         0        9
# 4            2            0             184          0         0        7
# 5            1            1               0          0         0        7
#
#    yr_sold sale_type
# 1     2006       WD
# 2     2006       WD
# 3     2006       New
# 4     2007       WD
# 5     2009       WD

# %%
# COLUMN:		misc_val            
# DEFINITION:	Value of miscellaneous feature
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.misc_val.unique()
# EVALUATION: COLUMN READY TO GO... DATA TYPE GOOD, NO MISSING
# VALUES! MISC_VAL DOES NOT EQUAL VALUES FROM MISC_FEATURE.
# COLUMNS APPEAR TO NOT CORILATE. COLUMN TO BE DROPPED!
# Out:
# array([    0,  2000,  1200,   420,   400,  1500,   750,   450,   500,
#          650,   600,   700,   560,   350,  1400,   480,  1000,   490,
#        15500,  1512,   620])

# %%
df = df.drop(columns=['misc_val'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  heating_qc  central_air  bsmt_full_bath  \
# 1           0           4          2           2            1               0
# 2           0           0          2           1            0               0
# 3           1           1          1           3            0               1
# 4           1           0          2           1            0               0
# 5           0           0          2           2            0               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#    totrms_abvgrd  functional  fireplaces  garage_type  garage_cars  \
# 1             11           0           0            2            1
# 2             12           0           0            1            2
# 3             10           0           1            1            2
# 4              6           0           0            2            2
# 5              8           0           2            1            2
#
#    garage_qual  paved_drive  enclosed_porch  pool_area  mo_sold  yr_sold  \
# 1            5            1             112          0        4     2006
# 2            1            1               0          0        8     2006
# 3            1            1               0          0        9     2006
# 4            2            0             184          0        7     2007
# 5            1            1               0          0        7     2009
#
#   sale_type
# 1       WD
# 2       WD
# 3       New
# 4       WD
# 5       WD

# %%
# COLUMN:		mo_sold             
# DEFINITION:	Month Sold
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.mo_sold.unique()
# EVALUATION: COLUMN READY TO GO... DATA TYPE GOOD, NO MISSING
# VALUES!
# Out:
# array([ 4,  8,  9,  7,  6,  5, 10,  1,  2, 11, 12,  3])

# %%
# COLUMN:		yr_sold             
# DEFINITION:	Year Sold
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.yr_sold.unique()
# EVALUATION: COLUMN READY TO GO... DATA TYPE GOOD, NO MISSING
# VALUES!
# Out:
# array([2006, 2007, 2009, 2010, 2008])

# %%
# COLUMN:		sale_type          
# DEFINITION:	Type of sale
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.sale_type.unique()
# EVALUATION: DATA TYPE NEEDS TO BE CONVERTED. NO MISSING
# VALUES!
# Out:
# array(['WD ', 'New', 'Con', 'COD', 'VWD', 'CWD', 'ConLD', 'ConLI', 'Oth',
#        'ConLw'], dtype=object)

# %% [markdown]
# - COLUMN HAS DIFFERENT VALUES THAN TEST.CSV

# %%
df = df.drop(columns=['sale_type'])
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  heating_qc  central_air  bsmt_full_bath  \
# 1           0           4          2           2            1               0
# 2           0           0          2           1            0               0
# 3           1           1          1           3            0               1
# 4           1           0          2           1            0               0
# 5           0           0          2           2            0               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#    totrms_abvgrd  functional  fireplaces  garage_type  garage_cars  \
# 1             11           0           0            2            1
# 2             12           0           0            1            2
# 3             10           0           1            1            2
# 4              6           0           0            2            2
# 5              8           0           2            1            2
#
#    garage_qual  paved_drive  enclosed_porch  pool_area  mo_sold  yr_sold
# 1            5            1             112          0        4     2006
# 2            1            1               0          0        8     2006
# 3            1            1               0          0        9     2006
# 4            2            0             184          0        7     2007
# 5            1            1               0          0        7     2009

# %% [markdown]
# **Describe the basic format:**

# %%
df.dtypes
# Out:
# ms_subclass       int64
# ms_zoning         int64
# street            int64
# alley             int64
# land_contour      int64
# utilities         int64
# lot_config        int64
# neighborhood      int64
# condition_1       int64
# bldg_type         int64
# house_style       int64
# overall_qual      int64
# exter_qual        int64
# foundation        int64
# bsmt_cond         int64
# heating_qc        int64
# central_air       int64
# bsmt_full_bath    int64
# bsmt_half_bath    int64
# full_bath         int64
# half_bath         int64
# bedroom_abvgr     int64
# kitchen_abvgr     int64
# totrms_abvgrd     int64
# functional        int64
# fireplaces        int64
# garage_type       int64
# garage_cars       int64
# garage_qual       int64
# paved_drive       int64
# enclosed_porch    int64
# pool_area         int64
# mo_sold           int64
# yr_sold           int64
# dtype: object

# %%
df.head(5)
# Out:
#    ms_subclass  ms_zoning  street  alley  land_contour  utilities  lot_config  \
# 1          190          3       0      1             0          0           1
# 2           90          0       0      0             0          0           1
# 3           60          0       0      0             0          0           1
# 4           30          3       0      0             0          0           1
# 5           20          0       0      0             0          0           1
#
#    neighborhood  condition_1  bldg_type  house_style  overall_qual  \
# 1            14            0          4            1             6
# 2            11            0          3            0             5
# 3             1            0          0            1             7
# 4            14            0          0            0             5
# 5             0            0          0            0             6
#
#    exter_qual  foundation  bsmt_cond  heating_qc  central_air  bsmt_full_bath  \
# 1           0           4          2           2            1               0
# 2           0           0          2           1            0               0
# 3           1           1          1           3            0               1
# 4           1           0          2           1            0               0
# 5           0           0          2           2            0               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 1               0          2          0              4              2
# 2               0          2          0              6              2
# 3               0          2          1              3              1
# 4               0          1          0              2              1
# 5               0          1          1              3              1
#
#    totrms_abvgrd  functional  fireplaces  garage_type  garage_cars  \
# 1             11           0           0            2            1
# 2             12           0           0            1            2
# 3             10           0           1            1            2
# 4              6           0           0            2            2
# 5              8           0           2            1            2
#
#    garage_qual  paved_drive  enclosed_porch  pool_area  mo_sold  yr_sold
# 1            5            1             112          0        4     2006
# 2            1            1               0          0        8     2006
# 3            1            1               0          0        9     2006
# 4            2            0             184          0        7     2007
# 5            1            1               0          0        7     2009

# %%
df.shape
# Out:
# (879, 34)

# %% [markdown]
# **Export Dataframe:**

# %%
df.to_csv('../data/test_clean.csv')
